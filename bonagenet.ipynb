# %% [markdown]
# # Data preprocessing

# %%
import pandas as pd
import tensorflow as tf
import numpy as np
from tensorflow.python.keras.engine import data_adapter
from tensorflow.keras import backend as K
import os, sys
os.mkdir('/kaggle/working/ckpts/')
sys.path.append('../input/boneage-ckpts')
sys.path.append('../input/hdaproject2021-codes/')
sys.path.append('../input/temppp/')

# %%
train_csv_directory = '../input/hdadataset2021/Bone Age Datasets/Bone Age Training Set/'
train_directory = '../input/hdadataset2021/Bone Age Datasets/Bone Age Training Set/boneage-training-dataset/'
df_train = pd.read_csv(train_csv_directory + 'train.csv')

val_csv_directory = '../input/hdadataset2021/'
val_directory = '../input/hdadataset2021/boneage-validation-dataset/'
df_val = pd.read_csv(val_csv_directory + 'Validation Dataset.csv')

# %%
ids = df_train['id'].values.astype(str)
labels = df_train['male'].values.astype(float)
ages = df_train['boneage'].values.astype(float)
train_ds = tf.data.Dataset.from_tensor_slices((ids, labels, ages))


ids = df_val['Image ID'].values.astype(str)
labels = df_val['male'].values.astype(float)
ages = df_val['Bone Age (months)'].values.astype(float)
val_ds = tf.data.Dataset.from_tensor_slices((ids, labels, ages))

IMG_SIZE = (300, 300, 1)
BATCH_SIZE = 32

# %%
def read_train_image(image_file, label, age):
    image = tf.io.read_file(train_directory + image_file+ '.png')
    image = tf.io.decode_png(image, channels=1)
    return image, [label], [age] #lists are necessary for training the model (otherwise dims are unknown)

def read_val_image(image_file, label, age):
    image = tf.io.read_file(val_directory + image_file + '.png')
    image = tf.io.decode_png(image, channels=1)
    return image, [label], [age] #lists are necessary for training the model (otherwise dims are unknown)

resize_layer = tf.keras.layers.experimental.preprocessing.Resizing(height=IMG_SIZE[0], width=IMG_SIZE[1])
normalization_layer = tf.keras.layers.experimental.preprocessing.Rescaling(1/255.)
zoom_layer = tf.keras.layers.experimental.preprocessing.RandomZoom(height_factor=(0.2,-0.3),
                                                                   width_factor=(0.2,-0.3),
                                                                  fill_mode='constant')
flip_layer = tf.keras.layers.experimental.preprocessing.RandomFlip(mode='horizontal')

def augment(image, label, age):
    # data augmentation here
    image = zoom_layer(image)
    image = flip_layer(image)
    return image, label, age

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE #tf.data.AUTOTUNE
train_ds = train_ds.map(read_train_image).map(lambda image,label,age: (normalization_layer((resize_layer(image))), label, age)).cache('../input/hdaproject2021-codes/train_cache_300')
train_ds = train_ds.shuffle(buffer_size=1000).batch(BATCH_SIZE).map(augment,num_parallel_calls=AUTOTUNE)
train_ds = train_ds.prefetch(buffer_size=AUTOTUNE)

val_ds = val_ds.map(read_val_image).map(lambda image,label,age: (normalization_layer(resize_layer(image)), label, age)).cache('../input/hdaproject2021-codes/val_cache_300')
val_ds = val_ds.prefetch(buffer_size=AUTOTUNE).batch(BATCH_SIZE)

# %% [markdown]
# # BoneAgeNet Training

# %%
from InceptionV3_2_initializer import InceptionV3

class BoneAgeInception(tf.keras.Model):  
    def __init__(self, gender=True, beta=1, initializer=tf.keras.initializers.HeNormal()):
        super(BoneAgeInception, self).__init__()
        
        model = InceptionV3(
                                include_top=False,
                                weights=None,
                                input_shape=IMG_SIZE,
                                beta=beta, initializer=initializer)
                
        
        if gender:
            gender_input = tf.keras.Input(shape=(1))
            gender_output = tf.keras.layers.Dense(100, activation='relu', kernel_initializer=initializer)(gender_input)
            
            model_global_avg = tf.keras.layers.GlobalAveragePooling2D()(model.output)
            
            #model_global_avg = tf.keras.layers.Dropout(0.3)(model_global_avg) #NO DROP!, it doesn't help (worse)
            
            concat_output = tf.keras.layers.Concatenate(name='gender_and_feat._concat')([model_global_avg, gender_output])
            
            #dense_output = tf.keras.layers.Dense(2000,activation='relu', kernel_regularizer='l2', kernel_initializer=initializer)(concat_output)
            
            overall_output = tf.keras.layers.Dense(1,activation='relu', kernel_regularizer='l2', kernel_initializer=initializer)(concat_output)
            
            self.model = tf.keras.Model(inputs=[model.input, gender_input], outputs = overall_output)
        else:
            pass #COMPLETE!
                
        
        
    def call(self, x, training=False):
        imgs, labels = x
        
        y = self.model([imgs, labels],training)
       
        return y

    def train_step(self, data):
        
        data = data_adapter.expand_1d(data)
        imgs, labels, ages = data
        
        with tf.GradientTape() as tape:
            y_pred = self((imgs, labels), training=True)  # Forward pass

            loss = self.compiled_loss(ages, y_pred)

        trainable_vars = self.trainable_variables
        gradients = tape.gradient(loss, trainable_vars)
        
        # Update weights
        self.optimizer.apply_gradients(zip(gradients, trainable_vars))

        self.compiled_metrics.update_state(ages, y_pred)
        _dict = {m.name: m.result() for m in self.metrics}
        
        return _dict

    def test_step(self, data):
        
        data = data_adapter.expand_1d(data)
        imgs, labels, ages = data

        y_pred = self((imgs, labels), training=False)  # Forward pass

        loss = self.compiled_loss(ages, y_pred)

        self.compiled_metrics.update_state(ages, y_pred)
        _dict = {m.name: m.result() for m in self.metrics}
        
        return _dict
    
    def summary(self):
        print(self.model.summary())

# %%
class BoneAgeNet(tf.keras.Model):  
    def __init__(self, gender=True):
        super(BoneAgeNet, self).__init__()
        
        model = BoneAgeInception(beta=1.4)
        
        #model.compile(optimizer='adam',loss='mse')
        #_ = model.fit(val_ds.take(1), verbose=2)
        #model.load_weights('./ckpts/inception_modified/best_val_inception_80ep.h5')
        #model.trainable=False
        
        for layer in model.model.layers:
            if layer.name.startswith('global_average'):
                global_avg_output = layer.output
                break
                
        
        if gender:
            initializer = tf.keras.initializers.HeNormal()
            gender_input = model.model.inputs[-1]
            gender_output = tf.keras.layers.Dense(100, activation='relu', kernel_initializer=initializer)(gender_input)
            
            global_avg_output = tf.keras.layers.Dropout(0.3)(global_avg_output)
            
            concat_output = tf.keras.layers.Concatenate(name='gender_and_feat._concat')([global_avg_output, gender_output])
            
            dense_output = tf.keras.layers.Dense(3000,activation='relu', kernel_regularizer='l2', kernel_initializer=initializer)(concat_output)
            
            overall_output = tf.keras.layers.Dense(1,activation='relu', kernel_regularizer='l2', kernel_initializer=initializer)(dense_output)
            
            self.model = tf.keras.Model(inputs=model.model.inputs, outputs = overall_output)
        else:
            pass #COMPLETE!
                
        
        
    def call(self, x, training=False):
        imgs, labels = x
        
        y = self.model([imgs, labels],training)
       
        return y

    def train_step(self, data):
        
        data = data_adapter.expand_1d(data)
        imgs, labels, ages = data
        
        with tf.GradientTape() as tape:
            y_pred = self((imgs, labels), training=True)  # Forward pass

            loss = self.compiled_loss(ages, y_pred)

        trainable_vars = self.trainable_variables
        gradients = tape.gradient(loss, trainable_vars)
        
        # Update weights
        self.optimizer.apply_gradients(zip(gradients, trainable_vars))

        self.compiled_metrics.update_state(ages, y_pred)
        _dict = {m.name: m.result() for m in self.metrics}
        
        return _dict

    def test_step(self, data):
        
        data = data_adapter.expand_1d(data)
        imgs, labels, ages = data

        y_pred = self((imgs, labels), training=False)  # Forward pass

        loss = self.compiled_loss(ages, y_pred)

        self.compiled_metrics.update_state(ages, y_pred)
        _dict = {m.name: m.result() for m in self.metrics}
        
        return _dict
    
    def summary(self):
        print(self.model.summary())

# %%
bonagenet = BoneAgeNet()
ckpt_callback = tf.keras.callbacks.ModelCheckpoint(
                filepath='./best_val_bonagenet_80ep.h5', monitor='val_mae', verbose=1, save_best_only=True,
                save_weights_only=True, mode='min')

def scheduler(epoch, lr):
    if epoch < 30:
        return lr
    elif epoch < 60:
        return 1e-3
    elif epoch < 80:
        return 1e-4
    else:
        return 1e-5

lr_scheduler_callback = tf.keras.callbacks.LearningRateScheduler(scheduler, verbose=1)

optimizer = tf.keras.optimizers.Adam(learning_rate=1e-2)
metric = tf.keras.metrics.MeanAbsoluteError()
bonagenet.compile(optimizer=optimizer, loss='mse', metrics=['mae'])

bonagenet.fit(train_ds, validation_data=val_ds,callbacks = [ckpt_callback,lr_scheduler_callback],
                    epochs=100, verbose=2)
# Out:
# Epoch 1/100
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# 395/395 - 266s - loss: 2240.4402 - mae: 33.6362 - val_loss: 1602.1307 - val_mae: 31.8943
#
# Epoch 00001: val_mae improved from inf to 31.89434, saving model to ./best_val_bonagenet_80ep.h5
# Epoch 2/100
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# 395/395 - 235s - loss: 1564.8201 - mae: 31.3159 - val_loss: 7523.5122 - val_mae: 76.7535
#
# Epoch 00002: val_mae did not improve from 31.89434
# Epoch 3/100
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# 395/395 - 235s - loss: 1501.3521 - mae: 30.6727 - val_loss: 1675.1188 - val_mae: 33.2059
#
# Epoch 00003: val_mae did not improve from 31.89434
# Epoch 4/100
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# 395/395 - 235s - loss: 1420.6342 - mae: 29.6003 - val_loss: 2158.0510 - val_mae: 39.0937
#
# Epoch 00004: val_mae did not improve from 31.89434
# Epoch 5/100
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# 395/395 - 235s - loss: 1271.7958 - mae: 27.8054 - val_loss: 2660.3306 - val_mae: 41.1879
#
# Epoch 00005: val_mae did not improve from 31.89434
# Epoch 6/100
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# 395/395 - 235s - loss: 1004.6380 - mae: 23.9651 - val_loss: 852.7997 - val_mae: 21.9359
#
# Epoch 00006: val_mae improved from 31.89434 to 21.93590, saving model to ./best_val_bonagenet_80ep.h5
# Epoch 7/100
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# 395/395 - 235s - loss: 716.6313 - mae: 19.7583 - val_loss: 726.2941 - val_mae: 19.7168
#
# Epoch 00007: val_mae improved from 21.93590 to 19.71675, saving model to ./best_val_bonagenet_80ep.h5
# Epoch 8/100
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# 395/395 - 234s - loss: 483.7267 - mae: 16.5518 - val_loss: 785.7300 - val_mae: 22.6628
#
# Epoch 00008: val_mae did not improve from 19.71675
# Epoch 9/100
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# 395/395 - 235s - loss: 380.5105 - mae: 14.8351 - val_loss: 898.0554 - val_mae: 24.6037
#
# Epoch 00009: val_mae did not improve from 19.71675
# Epoch 10/100
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# 395/395 - 235s - loss: 329.3927 - mae: 13.9613 - val_loss: 402.1153 - val_mae: 16.4427
#
# Epoch 00010: val_mae improved from 19.71675 to 16.44270, saving model to ./best_val_bonagenet_80ep.h5
# Epoch 11/100
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# 395/395 - 235s - loss: 348.4458 - mae: 14.2217 - val_loss: 332.8650 - val_mae: 13.7659
#
# Epoch 00011: val_mae improved from 16.44270 to 13.76588, saving model to ./best_val_bonagenet_80ep.h5
# Epoch 12/100
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# 395/395 - 234s - loss: 308.1412 - mae: 13.4793 - val_loss: 196.0045 - val_mae: 10.4740
#
# Epoch 00012: val_mae improved from 13.76588 to 10.47399, saving model to ./best_val_bonagenet_80ep.h5
# Epoch 13/100
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# 395/395 - 234s - loss: 273.0020 - mae: 12.7863 - val_loss: 233.6711 - val_mae: 11.8897
#
# Epoch 00013: val_mae did not improve from 10.47399
# Epoch 14/100
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# 395/395 - 234s - loss: 253.5832 - mae: 12.2398 - val_loss: 301.6038 - val_mae: 12.7598
#
# Epoch 00014: val_mae did not improve from 10.47399
# Epoch 15/100
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# 395/395 - 235s - loss: 262.3941 - mae: 12.4805 - val_loss: 369.6824 - val_mae: 16.0358
#
# Epoch 00015: val_mae did not improve from 10.47399
# Epoch 16/100
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# 395/395 - 234s - loss: 240.9449 - mae: 11.9448 - val_loss: 412.4187 - val_mae: 15.1277
#
# Epoch 00016: val_mae did not improve from 10.47399
# Epoch 17/100
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# 395/395 - 234s - loss: 225.9235 - mae: 11.6218 - val_loss: 272.3564 - val_mae: 13.4584
#
# Epoch 00017: val_mae did not improve from 10.47399
# Epoch 18/100
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# 395/395 - 234s - loss: 227.7172 - mae: 11.5984 - val_loss: 243.4079 - val_mae: 12.3700
#
# Epoch 00018: val_mae did not improve from 10.47399
# Epoch 19/100
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# 395/395 - 234s - loss: 219.6743 - mae: 11.3288 - val_loss: 249.2278 - val_mae: 12.1852
#
# Epoch 00019: val_mae did not improve from 10.47399
# Epoch 20/100
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# 395/395 - 234s - loss: 223.4735 - mae: 11.4895 - val_loss: 159.5330 - val_mae: 9.2343
#
# Epoch 00020: val_mae improved from 10.47399 to 9.23430, saving model to ./best_val_bonagenet_80ep.h5
# Epoch 21/100
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# 395/395 - 235s - loss: 199.5301 - mae: 10.8968 - val_loss: 337.1712 - val_mae: 15.4791
#
# Epoch 00021: val_mae did not improve from 9.23430
# Epoch 22/100
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# 395/395 - 234s - loss: 216.7298 - mae: 11.3400 - val_loss: 261.8330 - val_mae: 12.7500
#
# Epoch 00022: val_mae did not improve from 9.23430
# Epoch 23/100
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# 395/395 - 234s - loss: 199.8365 - mae: 10.8594 - val_loss: 224.5298 - val_mae: 11.4796
#
# Epoch 00023: val_mae did not improve from 9.23430
# Epoch 24/100
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# 395/395 - 234s - loss: 180.1167 - mae: 10.3679 - val_loss: 163.2416 - val_mae: 9.8179
#
# Epoch 00024: val_mae did not improve from 9.23430
# Epoch 25/100
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# 395/395 - 234s - loss: 180.0485 - mae: 10.2117 - val_loss: 274.3568 - val_mae: 13.2247
#
# Epoch 00025: val_mae did not improve from 9.23430
# Epoch 26/100
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# 395/395 - 234s - loss: 181.9085 - mae: 10.3760 - val_loss: 148.2131 - val_mae: 8.9672
#
# Epoch 00026: val_mae improved from 9.23430 to 8.96723, saving model to ./best_val_bonagenet_80ep.h5
# Epoch 27/100
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# 395/395 - 234s - loss: 171.2380 - mae: 10.0319 - val_loss: 149.9468 - val_mae: 9.0078
#
# Epoch 00027: val_mae did not improve from 8.96723
# Epoch 28/100
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# 395/395 - 234s - loss: 169.4520 - mae: 10.0289 - val_loss: 251.6362 - val_mae: 12.3853
#
# Epoch 00028: val_mae did not improve from 8.96723
# Epoch 29/100
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# 395/395 - 235s - loss: 164.1975 - mae: 9.7947 - val_loss: 328.0214 - val_mae: 15.1330
#
# Epoch 00029: val_mae did not improve from 8.96723
# Epoch 30/100
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# 395/395 - 235s - loss: 156.6176 - mae: 9.6522 - val_loss: 208.8143 - val_mae: 10.2203
#
# Epoch 00030: val_mae did not improve from 8.96723
# Epoch 31/100
#
# Epoch 00031: LearningRateScheduler reducing learning rate to 0.001.
# 395/395 - 234s - loss: 119.8870 - mae: 8.3640 - val_loss: 134.6199 - val_mae: 8.5707
#
# Epoch 00031: val_mae improved from 8.96723 to 8.57069, saving model to ./best_val_bonagenet_80ep.h5
# Epoch 32/100
#
# Epoch 00032: LearningRateScheduler reducing learning rate to 0.001.
# 395/395 - 234s - loss: 110.5124 - mae: 8.0072 - val_loss: 117.2847 - val_mae: 7.9232
#
# Epoch 00032: val_mae improved from 8.57069 to 7.92321, saving model to ./best_val_bonagenet_80ep.h5
# Epoch 33/100
#
# Epoch 00033: LearningRateScheduler reducing learning rate to 0.001.
# 395/395 - 234s - loss: 106.8668 - mae: 7.9675 - val_loss: 115.8135 - val_mae: 7.8594
#
# Epoch 00033: val_mae improved from 7.92321 to 7.85936, saving model to ./best_val_bonagenet_80ep.h5
# Epoch 34/100
#
# Epoch 00034: LearningRateScheduler reducing learning rate to 0.001.
# 395/395 - 234s - loss: 105.9220 - mae: 7.8974 - val_loss: 113.9133 - val_mae: 7.8689
#
# Epoch 00034: val_mae did not improve from 7.85936
# Epoch 35/100
#
# Epoch 00035: LearningRateScheduler reducing learning rate to 0.001.
# 395/395 - 234s - loss: 105.1975 - mae: 7.8725 - val_loss: 110.1209 - val_mae: 7.6039
#
# Epoch 00035: val_mae improved from 7.85936 to 7.60391, saving model to ./best_val_bonagenet_80ep.h5
# Epoch 36/100
#
# Epoch 00036: LearningRateScheduler reducing learning rate to 0.001.
# 395/395 - 234s - loss: 101.9717 - mae: 7.7384 - val_loss: 135.8667 - val_mae: 8.6756
#
# Epoch 00036: val_mae did not improve from 7.60391
# Epoch 37/100
#
# Epoch 00037: LearningRateScheduler reducing learning rate to 0.001.
# 395/395 - 235s - loss: 102.8053 - mae: 7.7562 - val_loss: 135.8974 - val_mae: 8.6899
#
# Epoch 00037: val_mae did not improve from 7.60391
# Epoch 38/100
#
# Epoch 00038: LearningRateScheduler reducing learning rate to 0.001.
# 395/395 - 234s - loss: 101.7343 - mae: 7.6954 - val_loss: 113.6437 - val_mae: 7.7455
#
# Epoch 00038: val_mae did not improve from 7.60391
# Epoch 39/100
#
# Epoch 00039: LearningRateScheduler reducing learning rate to 0.001.
# 395/395 - 234s - loss: 99.0387 - mae: 7.6220 - val_loss: 109.2371 - val_mae: 7.5074
#
# Epoch 00039: val_mae improved from 7.60391 to 7.50740, saving model to ./best_val_bonagenet_80ep.h5
# Epoch 40/100
#
# Epoch 00040: LearningRateScheduler reducing learning rate to 0.001.
# 395/395 - 234s - loss: 99.7373 - mae: 7.6700 - val_loss: 129.6658 - val_mae: 8.4030
#
# Epoch 00040: val_mae did not improve from 7.50740
# Epoch 41/100
#
# Epoch 00041: LearningRateScheduler reducing learning rate to 0.001.
# 395/395 - 234s - loss: 97.5889 - mae: 7.5694 - val_loss: 132.9858 - val_mae: 8.5593
#
# Epoch 00041: val_mae did not improve from 7.50740
# Epoch 42/100
#
# Epoch 00042: LearningRateScheduler reducing learning rate to 0.001.
# 395/395 - 234s - loss: 96.7505 - mae: 7.5567 - val_loss: 110.0994 - val_mae: 7.5284
#
# Epoch 00042: val_mae did not improve from 7.50740
# Epoch 43/100
#
# Epoch 00043: LearningRateScheduler reducing learning rate to 0.001.
# 395/395 - 234s - loss: 96.2460 - mae: 7.5354 - val_loss: 109.0552 - val_mae: 7.6191
#
# Epoch 00043: val_mae did not improve from 7.50740
# Epoch 44/100
#
# Epoch 00044: LearningRateScheduler reducing learning rate to 0.001.
# 395/395 - 234s - loss: 95.7919 - mae: 7.5029 - val_loss: 106.0461 - val_mae: 7.4360
#
# Epoch 00044: val_mae improved from 7.50740 to 7.43595, saving model to ./best_val_bonagenet_80ep.h5
# Epoch 45/100
#
# Epoch 00045: LearningRateScheduler reducing learning rate to 0.001.
# 395/395 - 234s - loss: 94.9545 - mae: 7.4678 - val_loss: 117.5543 - val_mae: 7.8253
#
# Epoch 00045: val_mae did not improve from 7.43595
# Epoch 46/100
#
# Epoch 00046: LearningRateScheduler reducing learning rate to 0.001.
# 395/395 - 234s - loss: 95.2501 - mae: 7.4861 - val_loss: 122.9201 - val_mae: 8.1131
#
# Epoch 00046: val_mae did not improve from 7.43595
# Epoch 47/100
#
# Epoch 00047: LearningRateScheduler reducing learning rate to 0.001.
# 395/395 - 234s - loss: 93.4347 - mae: 7.3943 - val_loss: 109.6704 - val_mae: 7.5623
#
# Epoch 00047: val_mae did not improve from 7.43595
# Epoch 48/100
#
# Epoch 00048: LearningRateScheduler reducing learning rate to 0.001.
# 395/395 - 234s - loss: 92.3754 - mae: 7.4025 - val_loss: 121.3142 - val_mae: 8.0362
#
# Epoch 00048: val_mae did not improve from 7.43595
# Epoch 49/100
#
# Epoch 00049: LearningRateScheduler reducing learning rate to 0.001.
# 395/395 - 234s - loss: 92.4547 - mae: 7.3823 - val_loss: 110.6506 - val_mae: 7.5970
#
# Epoch 00049: val_mae did not improve from 7.43595
# Epoch 50/100
#
# Epoch 00050: LearningRateScheduler reducing learning rate to 0.001.
# 395/395 - 234s - loss: 97.5132 - mae: 7.5212 - val_loss: 109.6693 - val_mae: 7.6258
#
# Epoch 00050: val_mae did not improve from 7.43595
# Epoch 51/100
#
# Epoch 00051: LearningRateScheduler reducing learning rate to 0.001.
# 395/395 - 234s - loss: 91.8963 - mae: 7.3329 - val_loss: 123.6599 - val_mae: 8.2267
#
# Epoch 00051: val_mae did not improve from 7.43595
# Epoch 52/100
#
# Epoch 00052: LearningRateScheduler reducing learning rate to 0.001.
# 395/395 - 234s - loss: 90.6663 - mae: 7.3082 - val_loss: 104.5700 - val_mae: 7.3696
#
# Epoch 00052: val_mae improved from 7.43595 to 7.36959, saving model to ./best_val_bonagenet_80ep.h5
# Epoch 53/100
#
# Epoch 00053: LearningRateScheduler reducing learning rate to 0.001.
# 395/395 - 234s - loss: 90.5778 - mae: 7.2842 - val_loss: 135.1039 - val_mae: 8.6985
#
# Epoch 00053: val_mae did not improve from 7.36959
# Epoch 54/100
#
# Epoch 00054: LearningRateScheduler reducing learning rate to 0.001.
# 395/395 - 234s - loss: 89.9872 - mae: 7.2964 - val_loss: 118.5352 - val_mae: 7.9566
#
# Epoch 00054: val_mae did not improve from 7.36959
# Epoch 55/100
#
# Epoch 00055: LearningRateScheduler reducing learning rate to 0.001.
# 395/395 - 234s - loss: 88.8090 - mae: 7.2313 - val_loss: 109.7893 - val_mae: 7.5879
#
# Epoch 00055: val_mae did not improve from 7.36959
# Epoch 56/100
#
# Epoch 00056: LearningRateScheduler reducing learning rate to 0.001.
# 395/395 - 234s - loss: 89.3018 - mae: 7.2661 - val_loss: 107.4856 - val_mae: 7.5007
#
# Epoch 00056: val_mae did not improve from 7.36959
# Epoch 57/100
#
# Epoch 00057: LearningRateScheduler reducing learning rate to 0.001.
# 395/395 - 235s - loss: 89.6528 - mae: 7.2700 - val_loss: 136.9710 - val_mae: 8.7554
#
# Epoch 00057: val_mae did not improve from 7.36959
# Epoch 58/100
#
# Epoch 00058: LearningRateScheduler reducing learning rate to 0.001.
# 395/395 - 234s - loss: 88.8013 - mae: 7.2371 - val_loss: 106.7718 - val_mae: 7.4661
#
# Epoch 00058: val_mae did not improve from 7.36959
# Epoch 59/100
#
# Epoch 00059: LearningRateScheduler reducing learning rate to 0.001.
# 395/395 - 234s - loss: 89.1438 - mae: 7.2663 - val_loss: 102.5371 - val_mae: 7.2927
#
# Epoch 00059: val_mae improved from 7.36959 to 7.29270, saving model to ./best_val_bonagenet_80ep.h5
# Epoch 60/100
#
# Epoch 00060: LearningRateScheduler reducing learning rate to 0.001.
# 395/395 - 234s - loss: 87.6999 - mae: 7.1722 - val_loss: 105.0048 - val_mae: 7.4045
#
# Epoch 00060: val_mae did not improve from 7.29270
# Epoch 61/100
#
# Epoch 00061: LearningRateScheduler reducing learning rate to 0.0001.
# 395/395 - 234s - loss: 83.4392 - mae: 6.9857 - val_loss: 101.3999 - val_mae: 7.2731
#
# Epoch 00061: val_mae improved from 7.29270 to 7.27315, saving model to ./best_val_bonagenet_80ep.h5
# Epoch 62/100
#
# Epoch 00062: LearningRateScheduler reducing learning rate to 0.0001.
# 395/395 - 234s - loss: 82.8977 - mae: 6.9823 - val_loss: 105.4762 - val_mae: 7.4245
#
# Epoch 00062: val_mae did not improve from 7.27315
# Epoch 63/100
#
# Epoch 00063: LearningRateScheduler reducing learning rate to 0.0001.
# 395/395 - 234s - loss: 82.4809 - mae: 6.9674 - val_loss: 102.2038 - val_mae: 7.2817
#
# Epoch 00063: val_mae did not improve from 7.27315
# Epoch 64/100
#
# Epoch 00064: LearningRateScheduler reducing learning rate to 0.0001.
# 395/395 - 235s - loss: 81.7052 - mae: 6.9513 - val_loss: 102.3273 - val_mae: 7.3049
#
# Epoch 00064: val_mae did not improve from 7.27315
# Epoch 65/100
#
# Epoch 00065: LearningRateScheduler reducing learning rate to 0.0001.
# 395/395 - 234s - loss: 82.3039 - mae: 6.9672 - val_loss: 100.5111 - val_mae: 7.2176
#
# Epoch 00065: val_mae improved from 7.27315 to 7.21763, saving model to ./best_val_bonagenet_80ep.h5
# Epoch 66/100
#
# Epoch 00066: LearningRateScheduler reducing learning rate to 0.0001.
# 395/395 - 234s - loss: 82.1804 - mae: 6.9400 - val_loss: 102.3204 - val_mae: 7.3080
#
# Epoch 00066: val_mae did not improve from 7.21763
# Epoch 67/100
#
# Epoch 00067: LearningRateScheduler reducing learning rate to 0.0001.
# 395/395 - 234s - loss: 81.8855 - mae: 6.9234 - val_loss: 102.6747 - val_mae: 7.3040
#
# Epoch 00067: val_mae did not improve from 7.21763
# Epoch 68/100
#
# Epoch 00068: LearningRateScheduler reducing learning rate to 0.0001.
# 395/395 - 234s - loss: 81.8422 - mae: 6.9128 - val_loss: 100.9628 - val_mae: 7.2271
#
# Epoch 00068: val_mae did not improve from 7.21763
# Epoch 69/100
#
# Epoch 00069: LearningRateScheduler reducing learning rate to 0.0001.
# 395/395 - 234s - loss: 80.3390 - mae: 6.8814 - val_loss: 102.2844 - val_mae: 7.3187
#
# Epoch 00069: val_mae did not improve from 7.21763
# Epoch 70/100
#
# Epoch 00070: LearningRateScheduler reducing learning rate to 0.0001.
# 395/395 - 234s - loss: 81.8083 - mae: 6.9242 - val_loss: 103.8161 - val_mae: 7.3755
#
# Epoch 00070: val_mae did not improve from 7.21763
# Epoch 71/100
#
# Epoch 00071: LearningRateScheduler reducing learning rate to 0.0001.
# 395/395 - 234s - loss: 82.1910 - mae: 6.9518 - val_loss: 102.0190 - val_mae: 7.2828
#
# Epoch 00071: val_mae did not improve from 7.21763
# Epoch 72/100
#
# Epoch 00072: LearningRateScheduler reducing learning rate to 0.0001.
# 395/395 - 235s - loss: 81.8096 - mae: 6.9234 - val_loss: 101.7862 - val_mae: 7.2545
#
# Epoch 00072: val_mae did not improve from 7.21763
# Epoch 73/100
#
# Epoch 00073: LearningRateScheduler reducing learning rate to 0.0001.
# 395/395 - 234s - loss: 81.2624 - mae: 6.9081 - val_loss: 102.7074 - val_mae: 7.3080
#
# Epoch 00073: val_mae did not improve from 7.21763
# Epoch 74/100
#
# Epoch 00074: LearningRateScheduler reducing learning rate to 0.0001.
# 395/395 - 234s - loss: 81.8431 - mae: 6.9126 - val_loss: 103.3206 - val_mae: 7.3379
#
# Epoch 00074: val_mae did not improve from 7.21763
# Epoch 75/100
#
# Epoch 00075: LearningRateScheduler reducing learning rate to 0.0001.
# 395/395 - 235s - loss: 82.0079 - mae: 6.9508 - val_loss: 103.1848 - val_mae: 7.3085
#
# Epoch 00075: val_mae did not improve from 7.21763
# Epoch 76/100
#
# Epoch 00076: LearningRateScheduler reducing learning rate to 0.0001.
# 395/395 - 235s - loss: 81.9286 - mae: 6.9160 - val_loss: 108.0393 - val_mae: 7.5676
#
# Epoch 00076: val_mae did not improve from 7.21763
# Epoch 77/100
#
# Epoch 00077: LearningRateScheduler reducing learning rate to 0.0001.
# 395/395 - 235s - loss: 80.5025 - mae: 6.8796 - val_loss: 104.1699 - val_mae: 7.3556
#
# Epoch 00077: val_mae did not improve from 7.21763
# Epoch 78/100
#
# Epoch 00078: LearningRateScheduler reducing learning rate to 0.0001.
# 395/395 - 234s - loss: 80.2296 - mae: 6.9017 - val_loss: 102.0055 - val_mae: 7.2566
#
# Epoch 00078: val_mae did not improve from 7.21763
# Epoch 79/100
#
# Epoch 00079: LearningRateScheduler reducing learning rate to 0.0001.
# 395/395 - 234s - loss: 80.6677 - mae: 6.8841 - val_loss: 103.0917 - val_mae: 7.2901
#
# Epoch 00079: val_mae did not improve from 7.21763
# Epoch 80/100
#
# Epoch 00080: LearningRateScheduler reducing learning rate to 0.0001.
# 395/395 - 234s - loss: 80.1253 - mae: 6.8529 - val_loss: 101.5287 - val_mae: 7.2230
#
# Epoch 00080: val_mae did not improve from 7.21763
# Epoch 81/100
#
# Epoch 00081: LearningRateScheduler reducing learning rate to 1e-05.
# 395/395 - 234s - loss: 79.7813 - mae: 6.8849 - val_loss: 102.1186 - val_mae: 7.2419
#
# Epoch 00081: val_mae did not improve from 7.21763
# Epoch 82/100
#
# Epoch 00082: LearningRateScheduler reducing learning rate to 1e-05.
# 395/395 - 234s - loss: 79.9755 - mae: 6.8905 - val_loss: 102.2873 - val_mae: 7.2487
#
# Epoch 00082: val_mae did not improve from 7.21763
# Epoch 83/100
#
# Epoch 00083: LearningRateScheduler reducing learning rate to 1e-05.
# 395/395 - 234s - loss: 79.8836 - mae: 6.8354 - val_loss: 102.3758 - val_mae: 7.2545
#
# Epoch 00083: val_mae did not improve from 7.21763
# Epoch 84/100
#
# Epoch 00084: LearningRateScheduler reducing learning rate to 1e-05.
# 395/395 - 234s - loss: 79.7689 - mae: 6.8524 - val_loss: 101.6804 - val_mae: 7.2164
#
# Epoch 00084: val_mae improved from 7.21763 to 7.21638, saving model to ./best_val_bonagenet_80ep.h5
# Epoch 85/100
#
# Epoch 00085: LearningRateScheduler reducing learning rate to 1e-05.
# 395/395 - 234s - loss: 79.4520 - mae: 6.8410 - val_loss: 102.6093 - val_mae: 7.2607
#
# Epoch 00085: val_mae did not improve from 7.21638
# Epoch 86/100
#
# Epoch 00086: LearningRateScheduler reducing learning rate to 1e-05.
# 395/395 - 234s - loss: 79.9503 - mae: 6.8323 - val_loss: 101.9955 - val_mae: 7.2246
#
# Epoch 00086: val_mae did not improve from 7.21638
# Epoch 87/100
#
# Epoch 00087: LearningRateScheduler reducing learning rate to 1e-05.
# 395/395 - 234s - loss: 80.2119 - mae: 6.8512 - val_loss: 102.3976 - val_mae: 7.2493
#
# Epoch 00087: val_mae did not improve from 7.21638
# Epoch 88/100
#
# Epoch 00088: LearningRateScheduler reducing learning rate to 1e-05.
# 395/395 - 234s - loss: 79.5718 - mae: 6.8138 - val_loss: 102.0561 - val_mae: 7.2337
#
# Epoch 00088: val_mae did not improve from 7.21638
# Epoch 89/100
#
# Epoch 00089: LearningRateScheduler reducing learning rate to 1e-05.
# 395/395 - 234s - loss: 79.5495 - mae: 6.8416 - val_loss: 102.4258 - val_mae: 7.2505
#
# Epoch 00089: val_mae did not improve from 7.21638
# Epoch 90/100
#
# Epoch 00090: LearningRateScheduler reducing learning rate to 1e-05.
# 395/395 - 234s - loss: 81.5238 - mae: 6.8855 - val_loss: 101.9197 - val_mae: 7.2317
#
# Epoch 00090: val_mae did not improve from 7.21638
# Epoch 91/100
#
# Epoch 00091: LearningRateScheduler reducing learning rate to 1e-05.
# 395/395 - 234s - loss: 79.1707 - mae: 6.8062 - val_loss: 102.2272 - val_mae: 7.2451
#
# Epoch 00091: val_mae did not improve from 7.21638
# Epoch 92/100
#
# Epoch 00092: LearningRateScheduler reducing learning rate to 1e-05.
# 395/395 - 234s - loss: 78.9094 - mae: 6.7909 - val_loss: 102.3099 - val_mae: 7.2478
#
# Epoch 00092: val_mae did not improve from 7.21638
# Epoch 93/100
#
# Epoch 00093: LearningRateScheduler reducing learning rate to 1e-05.
# 395/395 - 234s - loss: 79.7202 - mae: 6.8386 - val_loss: 102.0753 - val_mae: 7.2358
#
# Epoch 00093: val_mae did not improve from 7.21638
# Epoch 94/100
#
# Epoch 00094: LearningRateScheduler reducing learning rate to 1e-05.
# 395/395 - 234s - loss: 79.4781 - mae: 6.8066 - val_loss: 102.2980 - val_mae: 7.2432
#
# Epoch 00094: val_mae did not improve from 7.21638
# Epoch 95/100
#
# Epoch 00095: LearningRateScheduler reducing learning rate to 1e-05.
# 395/395 - 234s - loss: 80.0934 - mae: 6.8396 - val_loss: 102.5409 - val_mae: 7.2579
#
# Epoch 00095: val_mae did not improve from 7.21638
# Epoch 96/100
#
# Epoch 00096: LearningRateScheduler reducing learning rate to 1e-05.
# 395/395 - 235s - loss: 79.5768 - mae: 6.8325 - val_loss: 102.4772 - val_mae: 7.2553
#
# Epoch 00096: val_mae did not improve from 7.21638
# Epoch 97/100
#
# Epoch 00097: LearningRateScheduler reducing learning rate to 1e-05.
# 395/395 - 234s - loss: 80.1601 - mae: 6.8629 - val_loss: 102.0633 - val_mae: 7.2389
#
# Epoch 00097: val_mae did not improve from 7.21638
# Epoch 98/100
#
# Epoch 00098: LearningRateScheduler reducing learning rate to 1e-05.
# 395/395 - 235s - loss: 78.5080 - mae: 6.7912 - val_loss: 102.3659 - val_mae: 7.2501
#
# Epoch 00098: val_mae did not improve from 7.21638
# Epoch 99/100
#
# Epoch 00099: LearningRateScheduler reducing learning rate to 1e-05.
# 395/395 - 234s - loss: 79.4847 - mae: 6.8245 - val_loss: 102.1384 - val_mae: 7.2378
#
# Epoch 00099: val_mae did not improve from 7.21638
# Epoch 100/100
#
# Epoch 00100: LearningRateScheduler reducing learning rate to 1e-05.
# 395/395 - 235s - loss: 79.6787 - mae: 6.8438 - val_loss: 102.3869 - val_mae: 7.2574
#
# Epoch 00100: val_mae did not improve from 7.21638

# %% [markdown]
# ### test

# %%
test_directory = '../input/hdadataset2021/Bone Age Datasets/Bone Age Test Set/Test Set Images/'

df_test = pd.read_csv('../input/hdaproject2021-codes/test.csv')

ids = df_test['id'].values.astype(str)
labels = (df_test['Sex'].values == 'M').astype(float)

# replace ',' with '.' and convert to float
ages_str = df_test['boneage'].values
ages = np.empty_like(ages_str)
for i, item in enumerate(ages_str):
    replaced = item.replace(',','.')
    replaced_float = float(replaced)
    ages[i] = replaced_float
ages = ages.astype(float)

test_ds = tf.data.Dataset.from_tensor_slices((ids, labels, ages))

def read_test_image(image_file, label, age):
    image = tf.io.read_file(test_directory + image_file + '.png')
    image = tf.io.decode_png(image, channels=1)
    return image, [label], [age] #lists are necessary for training the model (otherwise dims are unknown)

test_ds = test_ds.map(read_test_image).map(lambda image,label,age: (normalization_layer(resize_layer(image)), label, age)).cache()
test_ds = test_ds.prefetch(buffer_size=AUTOTUNE)

test_iterator = test_ds.as_numpy_iterator()
N = 200 #number of samples
test_images = np.empty(shape=(N, IMG_SIZE[0], IMG_SIZE[1], 1), dtype=np.float32)
test_labels = np.empty(shape=(N,), dtype=np.float32)
test_ages = np.empty(shape=(N,), dtype=np.float32)
for i, item in enumerate(test_iterator):
    test_images[i] = item[0]
    test_labels[i] = item[1]
    test_ages[i] = item[2]
    
print(test_images.shape)
print(test_labels.shape)
print(test_ages.shape)
# Out:
# (200, 300, 300, 1)
# (200,)
# (200,)

# %%
bonagenet.load_weights('./best_val_bonagenet_80ep.h5')

# %%
bonagenet_pred = bonagenet.predict((test_images, test_labels))

# %%
np.mean(np.abs(bonagenet_pred.squeeze() - test_ages.squeeze()))
# Out:
# 5.6038165

# %%
bonagenet.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 300, 300, 1) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 149, 149, 44) 396         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 149, 149, 44) 132         conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 149, 149, 44) 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 147, 147, 44) 17424       activation[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 147, 147, 44) 132         conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 147, 147, 44) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 147, 147, 89) 35244       activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 147, 147, 89) 267         conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 147, 147, 89) 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 73, 73, 89)   0           activation_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 73, 73, 112)  9968        max_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 73, 73, 112)  336         conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 73, 73, 112)  0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 71, 71, 268)  270144      activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 71, 71, 268)  804         conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 71, 71, 268)  0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 35, 35, 268)  0           activation_4[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 35, 35, 89)   23852       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 35, 35, 89)   267         conv2d_8[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 35, 35, 89)   0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 35, 35, 67)   17956       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 35, 35, 134)  107334      activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 35, 35, 67)   201         conv2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 35, 35, 134)  402         conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 35, 35, 67)   0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 35, 35, 134)  0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# average_pooling2d (AveragePooli (None, 35, 35, 268)  0           max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 35, 35, 89)   23852       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 35, 35, 89)   149075      activation_6[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 35, 35, 134)  161604      activation_9[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 35, 35, 44)   11792       average_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 35, 35, 89)   267         conv2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 35, 35, 89)   267         conv2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 35, 35, 134)  402         conv2d_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 35, 35, 44)   132         conv2d_11[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 35, 35, 89)   0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 35, 35, 89)   0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 35, 35, 134)  0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 35, 35, 44)   0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# mixed0-0 (Concatenate)          (None, 35, 35, 356)  0           activation_5[0][0]
#                                                                  activation_7[0][0]
#                                                                  activation_10[0][0]
#                                                                  activation_11[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 35, 35, 89)   31684       mixed0-0[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 35, 35, 89)   267         conv2d_15[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 35, 35, 89)   0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 35, 35, 67)   23852       mixed0-0[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 35, 35, 134)  107334      activation_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 35, 35, 67)   201         conv2d_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 35, 35, 134)  402         conv2d_16[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 35, 35, 67)   0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 35, 35, 134)  0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_1 (AveragePoo (None, 35, 35, 356)  0           mixed0-0[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 35, 35, 89)   31684       mixed0-0[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 35, 35, 89)   149075      activation_13[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 35, 35, 134)  161604      activation_16[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 35, 35, 89)   31684       average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 35, 35, 89)   267         conv2d_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 35, 35, 89)   267         conv2d_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 35, 35, 134)  402         conv2d_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 35, 35, 89)   267         conv2d_18[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 35, 35, 89)   0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 35, 35, 89)   0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 35, 35, 134)  0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 35, 35, 89)   0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# mixed1 (Concatenate)            (None, 35, 35, 401)  0           activation_12[0][0]
#                                                                  activation_14[0][0]
#                                                                  activation_17[0][0]
#                                                                  activation_18[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 35, 35, 89)   35689       mixed1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 35, 35, 89)   267         conv2d_22[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 35, 35, 89)   0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 35, 35, 67)   26867       mixed1[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 35, 35, 134)  107334      activation_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 35, 35, 67)   201         conv2d_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 35, 35, 134)  402         conv2d_23[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 35, 35, 67)   0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 35, 35, 134)  0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_2 (AveragePoo (None, 35, 35, 401)  0           mixed1[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 35, 35, 89)   35689       mixed1[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 35, 35, 89)   149075      activation_20[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 35, 35, 134)  161604      activation_23[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 35, 35, 89)   35689       average_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 35, 35, 89)   267         conv2d_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 35, 35, 89)   267         conv2d_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 35, 35, 134)  402         conv2d_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 35, 35, 89)   267         conv2d_25[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 35, 35, 89)   0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 35, 35, 89)   0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 35, 35, 134)  0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 35, 35, 89)   0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# mixed2 (Concatenate)            (None, 35, 35, 401)  0           activation_19[0][0]
#                                                                  activation_21[0][0]
#                                                                  activation_24[0][0]
#                                                                  activation_25[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 35, 35, 89)   35689       mixed2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 35, 35, 89)   267         conv2d_27[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 35, 35, 89)   0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 35, 35, 134)  107334      activation_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 35, 35, 134)  402         conv2d_28[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 35, 35, 134)  0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 17, 17, 537)  1938033     mixed2[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 17, 17, 134)  161604      activation_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 17, 17, 537)  1611        conv2d_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 17, 17, 134)  402         conv2d_29[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 17, 17, 537)  0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 17, 17, 134)  0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 17, 17, 401)  0           mixed2[0][0]
# __________________________________________________________________________________________________
# mixed3 (Concatenate)            (None, 17, 17, 1072) 0           activation_26[0][0]
#                                                                  activation_29[0][0]
#                                                                  max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 17, 17, 179)  191888      mixed3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 17, 17, 179)  537         conv2d_34[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 17, 17, 179)  0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 17, 17, 179)  224287      activation_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 17, 17, 179)  537         conv2d_35[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 17, 17, 179)  0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 17, 17, 179)  191888      mixed3[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 17, 17, 179)  224287      activation_35[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 17, 17, 179)  537         conv2d_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 17, 17, 179)  537         conv2d_36[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 17, 17, 179)  0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 17, 17, 179)  0           batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 17, 17, 179)  224287      activation_31[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 17, 17, 179)  224287      activation_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 17, 17, 179)  537         conv2d_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 17, 17, 179)  537         conv2d_37[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 17, 17, 179)  0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 17, 17, 179)  0           batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_3 (AveragePoo (None, 17, 17, 1072) 0           mixed3[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 17, 17, 268)  287296      mixed3[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 17, 17, 268)  335804      activation_32[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 17, 17, 268)  335804      activation_37[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 17, 17, 268)  287296      average_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 17, 17, 268)  804         conv2d_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 17, 17, 268)  804         conv2d_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 17, 17, 268)  804         conv2d_38[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 17, 17, 268)  804         conv2d_39[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 17, 17, 268)  0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 17, 17, 268)  0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 17, 17, 268)  0           batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 17, 17, 268)  0           batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# mixed4-0 (Concatenate)          (None, 17, 17, 1072) 0           activation_30[0][0]
#                                                                  activation_33[0][0]
#                                                                  activation_38[0][0]
#                                                                  activation_39[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 17, 17, 224)  240128      mixed4-0[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 17, 17, 224)  672         conv2d_44[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 17, 17, 224)  0           batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 17, 17, 224)  351232      activation_44[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 17, 17, 224)  672         conv2d_45[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 17, 17, 224)  0           batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 17, 17, 224)  240128      mixed4-0[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 17, 17, 224)  351232      activation_45[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 17, 17, 224)  672         conv2d_41[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 17, 17, 224)  672         conv2d_46[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 17, 17, 224)  0           batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 17, 17, 224)  0           batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 17, 17, 224)  351232      activation_41[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 17, 17, 224)  351232      activation_46[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 17, 17, 224)  672         conv2d_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, 17, 17, 224)  672         conv2d_47[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 17, 17, 224)  0           batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 17, 17, 224)  0           batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_4 (AveragePoo (None, 17, 17, 1072) 0           mixed4-0[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 17, 17, 268)  287296      mixed4-0[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 17, 17, 268)  420224      activation_42[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 17, 17, 268)  420224      activation_47[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 17, 17, 268)  287296      average_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 17, 17, 268)  804         conv2d_40[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 17, 17, 268)  804         conv2d_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 17, 17, 268)  804         conv2d_48[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, 17, 17, 268)  804         conv2d_49[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 17, 17, 268)  0           batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 17, 17, 268)  0           batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 17, 17, 268)  0           batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, 17, 17, 268)  0           batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# mixed5-0 (Concatenate)          (None, 17, 17, 1072) 0           activation_40[0][0]
#                                                                  activation_43[0][0]
#                                                                  activation_48[0][0]
#                                                                  activation_49[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 17, 17, 224)  240128      mixed5-0[0][0]
# __________________________________________________________________________________________________
# batch_normalization_54 (BatchNo (None, 17, 17, 224)  672         conv2d_54[0][0]
# __________________________________________________________________________________________________
# activation_54 (Activation)      (None, 17, 17, 224)  0           batch_normalization_54[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 17, 17, 224)  351232      activation_54[0][0]
# __________________________________________________________________________________________________
# batch_normalization_55 (BatchNo (None, 17, 17, 224)  672         conv2d_55[0][0]
# __________________________________________________________________________________________________
# activation_55 (Activation)      (None, 17, 17, 224)  0           batch_normalization_55[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 17, 17, 224)  240128      mixed5-0[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 17, 17, 224)  351232      activation_55[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 17, 17, 224)  672         conv2d_51[0][0]
# __________________________________________________________________________________________________
# batch_normalization_56 (BatchNo (None, 17, 17, 224)  672         conv2d_56[0][0]
# __________________________________________________________________________________________________
# activation_51 (Activation)      (None, 17, 17, 224)  0           batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# activation_56 (Activation)      (None, 17, 17, 224)  0           batch_normalization_56[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 17, 17, 224)  351232      activation_51[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, 17, 17, 224)  351232      activation_56[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, 17, 17, 224)  672         conv2d_52[0][0]
# __________________________________________________________________________________________________
# batch_normalization_57 (BatchNo (None, 17, 17, 224)  672         conv2d_57[0][0]
# __________________________________________________________________________________________________
# activation_52 (Activation)      (None, 17, 17, 224)  0           batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# activation_57 (Activation)      (None, 17, 17, 224)  0           batch_normalization_57[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_5 (AveragePoo (None, 17, 17, 1072) 0           mixed5-0[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 17, 17, 268)  287296      mixed5-0[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 17, 17, 268)  420224      activation_52[0][0]
# __________________________________________________________________________________________________
# conv2d_58 (Conv2D)              (None, 17, 17, 268)  420224      activation_57[0][0]
# __________________________________________________________________________________________________
# conv2d_59 (Conv2D)              (None, 17, 17, 268)  287296      average_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, 17, 17, 268)  804         conv2d_50[0][0]
# __________________________________________________________________________________________________
# batch_normalization_53 (BatchNo (None, 17, 17, 268)  804         conv2d_53[0][0]
# __________________________________________________________________________________________________
# batch_normalization_58 (BatchNo (None, 17, 17, 268)  804         conv2d_58[0][0]
# __________________________________________________________________________________________________
# batch_normalization_59 (BatchNo (None, 17, 17, 268)  804         conv2d_59[0][0]
# __________________________________________________________________________________________________
# activation_50 (Activation)      (None, 17, 17, 268)  0           batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# activation_53 (Activation)      (None, 17, 17, 268)  0           batch_normalization_53[0][0]
# __________________________________________________________________________________________________
# activation_58 (Activation)      (None, 17, 17, 268)  0           batch_normalization_58[0][0]
# __________________________________________________________________________________________________
# activation_59 (Activation)      (None, 17, 17, 268)  0           batch_normalization_59[0][0]
# __________________________________________________________________________________________________
# mixed5-1 (Concatenate)          (None, 17, 17, 1072) 0           activation_50[0][0]
#                                                                  activation_53[0][0]
#                                                                  activation_58[0][0]
#                                                                  activation_59[0][0]
# __________________________________________________________________________________________________
# conv2d_64 (Conv2D)              (None, 17, 17, 224)  240128      mixed5-1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_64 (BatchNo (None, 17, 17, 224)  672         conv2d_64[0][0]
# __________________________________________________________________________________________________
# activation_64 (Activation)      (None, 17, 17, 224)  0           batch_normalization_64[0][0]
# __________________________________________________________________________________________________
# conv2d_65 (Conv2D)              (None, 17, 17, 224)  351232      activation_64[0][0]
# __________________________________________________________________________________________________
# batch_normalization_65 (BatchNo (None, 17, 17, 224)  672         conv2d_65[0][0]
# __________________________________________________________________________________________________
# activation_65 (Activation)      (None, 17, 17, 224)  0           batch_normalization_65[0][0]
# __________________________________________________________________________________________________
# conv2d_61 (Conv2D)              (None, 17, 17, 224)  240128      mixed5-1[0][0]
# __________________________________________________________________________________________________
# conv2d_66 (Conv2D)              (None, 17, 17, 224)  351232      activation_65[0][0]
# __________________________________________________________________________________________________
# batch_normalization_61 (BatchNo (None, 17, 17, 224)  672         conv2d_61[0][0]
# __________________________________________________________________________________________________
# batch_normalization_66 (BatchNo (None, 17, 17, 224)  672         conv2d_66[0][0]
# __________________________________________________________________________________________________
# activation_61 (Activation)      (None, 17, 17, 224)  0           batch_normalization_61[0][0]
# __________________________________________________________________________________________________
# activation_66 (Activation)      (None, 17, 17, 224)  0           batch_normalization_66[0][0]
# __________________________________________________________________________________________________
# conv2d_62 (Conv2D)              (None, 17, 17, 224)  351232      activation_61[0][0]
# __________________________________________________________________________________________________
# conv2d_67 (Conv2D)              (None, 17, 17, 224)  351232      activation_66[0][0]
# __________________________________________________________________________________________________
# batch_normalization_62 (BatchNo (None, 17, 17, 224)  672         conv2d_62[0][0]
# __________________________________________________________________________________________________
# batch_normalization_67 (BatchNo (None, 17, 17, 224)  672         conv2d_67[0][0]
# __________________________________________________________________________________________________
# activation_62 (Activation)      (None, 17, 17, 224)  0           batch_normalization_62[0][0]
# __________________________________________________________________________________________________
# activation_67 (Activation)      (None, 17, 17, 224)  0           batch_normalization_67[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_6 (AveragePoo (None, 17, 17, 1072) 0           mixed5-1[0][0]
# __________________________________________________________________________________________________
# conv2d_60 (Conv2D)              (None, 17, 17, 268)  287296      mixed5-1[0][0]
# __________________________________________________________________________________________________
# conv2d_63 (Conv2D)              (None, 17, 17, 268)  420224      activation_62[0][0]
# __________________________________________________________________________________________________
# conv2d_68 (Conv2D)              (None, 17, 17, 268)  420224      activation_67[0][0]
# __________________________________________________________________________________________________
# conv2d_69 (Conv2D)              (None, 17, 17, 268)  287296      average_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_60 (BatchNo (None, 17, 17, 268)  804         conv2d_60[0][0]
# __________________________________________________________________________________________________
# batch_normalization_63 (BatchNo (None, 17, 17, 268)  804         conv2d_63[0][0]
# __________________________________________________________________________________________________
# batch_normalization_68 (BatchNo (None, 17, 17, 268)  804         conv2d_68[0][0]
# __________________________________________________________________________________________________
# batch_normalization_69 (BatchNo (None, 17, 17, 268)  804         conv2d_69[0][0]
# __________________________________________________________________________________________________
# activation_60 (Activation)      (None, 17, 17, 268)  0           batch_normalization_60[0][0]
# __________________________________________________________________________________________________
# activation_63 (Activation)      (None, 17, 17, 268)  0           batch_normalization_63[0][0]
# __________________________________________________________________________________________________
# activation_68 (Activation)      (None, 17, 17, 268)  0           batch_normalization_68[0][0]
# __________________________________________________________________________________________________
# activation_69 (Activation)      (None, 17, 17, 268)  0           batch_normalization_69[0][0]
# __________________________________________________________________________________________________
# mixed5-2 (Concatenate)          (None, 17, 17, 1072) 0           activation_60[0][0]
#                                                                  activation_63[0][0]
#                                                                  activation_68[0][0]
#                                                                  activation_69[0][0]
# __________________________________________________________________________________________________
# ...
# concatenate (Concatenate)       (None, 8, 8, 1074)   0           activation_122[0][0]
#                                                                  activation_123[0][0]
# __________________________________________________________________________________________________
# activation_124 (Activation)     (None, 8, 8, 268)    0           batch_normalization_124[0][0]
# __________________________________________________________________________________________________
# mixed8-0 (Concatenate)          (None, 8, 8, 2864)   0           activation_116[0][0]
#                                                                  mixed8_0[0][0]
#                                                                  concatenate[0][0]
#                                                                  activation_124[0][0]
# __________________________________________________________________________________________________
# conv2d_129 (Conv2D)             (None, 8, 8, 627)    1795728     mixed8-0[0][0]
# __________________________________________________________________________________________________
# batch_normalization_129 (BatchN (None, 8, 8, 627)    1881        conv2d_129[0][0]
# __________________________________________________________________________________________________
# activation_129 (Activation)     (None, 8, 8, 627)    0           batch_normalization_129[0][0]
# __________________________________________________________________________________________________
# conv2d_126 (Conv2D)             (None, 8, 8, 537)    1537968     mixed8-0[0][0]
# __________________________________________________________________________________________________
# conv2d_130 (Conv2D)             (None, 8, 8, 537)    3030291     activation_129[0][0]
# __________________________________________________________________________________________________
# batch_normalization_126 (BatchN (None, 8, 8, 537)    1611        conv2d_126[0][0]
# __________________________________________________________________________________________________
# batch_normalization_130 (BatchN (None, 8, 8, 537)    1611        conv2d_130[0][0]
# __________________________________________________________________________________________________
# activation_126 (Activation)     (None, 8, 8, 537)    0           batch_normalization_126[0][0]
# __________________________________________________________________________________________________
# activation_130 (Activation)     (None, 8, 8, 537)    0           batch_normalization_130[0][0]
# __________________________________________________________________________________________________
# conv2d_127 (Conv2D)             (None, 8, 8, 537)    865107      activation_126[0][0]
# __________________________________________________________________________________________________
# conv2d_128 (Conv2D)             (None, 8, 8, 537)    865107      activation_126[0][0]
# __________________________________________________________________________________________________
# conv2d_131 (Conv2D)             (None, 8, 8, 537)    865107      activation_130[0][0]
# __________________________________________________________________________________________________
# conv2d_132 (Conv2D)             (None, 8, 8, 537)    865107      activation_130[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_12 (AveragePo (None, 8, 8, 2864)   0           mixed8-0[0][0]
# __________________________________________________________________________________________________
# conv2d_125 (Conv2D)             (None, 8, 8, 448)    1283072     mixed8-0[0][0]
# __________________________________________________________________________________________________
# batch_normalization_127 (BatchN (None, 8, 8, 537)    1611        conv2d_127[0][0]
# __________________________________________________________________________________________________
# batch_normalization_128 (BatchN (None, 8, 8, 537)    1611        conv2d_128[0][0]
# __________________________________________________________________________________________________
# batch_normalization_131 (BatchN (None, 8, 8, 537)    1611        conv2d_131[0][0]
# __________________________________________________________________________________________________
# batch_normalization_132 (BatchN (None, 8, 8, 537)    1611        conv2d_132[0][0]
# __________________________________________________________________________________________________
# conv2d_133 (Conv2D)             (None, 8, 8, 268)    767552      average_pooling2d_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_125 (BatchN (None, 8, 8, 448)    1344        conv2d_125[0][0]
# __________________________________________________________________________________________________
# activation_127 (Activation)     (None, 8, 8, 537)    0           batch_normalization_127[0][0]
# __________________________________________________________________________________________________
# activation_128 (Activation)     (None, 8, 8, 537)    0           batch_normalization_128[0][0]
# __________________________________________________________________________________________________
# activation_131 (Activation)     (None, 8, 8, 537)    0           batch_normalization_131[0][0]
# __________________________________________________________________________________________________
# activation_132 (Activation)     (None, 8, 8, 537)    0           batch_normalization_132[0][0]
# __________________________________________________________________________________________________
# batch_normalization_133 (BatchN (None, 8, 8, 268)    804         conv2d_133[0][0]
# __________________________________________________________________________________________________
# activation_125 (Activation)     (None, 8, 8, 448)    0           batch_normalization_125[0][0]
# __________________________________________________________________________________________________
# mixed8_1 (Concatenate)          (None, 8, 8, 1074)   0           activation_127[0][0]
#                                                                  activation_128[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 8, 8, 1074)   0           activation_131[0][0]
#                                                                  activation_132[0][0]
# __________________________________________________________________________________________________
# activation_133 (Activation)     (None, 8, 8, 268)    0           batch_normalization_133[0][0]
# __________________________________________________________________________________________________
# mixed8-1 (Concatenate)          (None, 8, 8, 2864)   0           activation_125[0][0]
#                                                                  mixed8_1[0][0]
#                                                                  concatenate_1[0][0]
#                                                                  activation_133[0][0]
# __________________________________________________________________________________________________
# conv2d_138 (Conv2D)             (None, 8, 8, 627)    1795728     mixed8-1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_138 (BatchN (None, 8, 8, 627)    1881        conv2d_138[0][0]
# __________________________________________________________________________________________________
# activation_138 (Activation)     (None, 8, 8, 627)    0           batch_normalization_138[0][0]
# __________________________________________________________________________________________________
# conv2d_135 (Conv2D)             (None, 8, 8, 537)    1537968     mixed8-1[0][0]
# __________________________________________________________________________________________________
# conv2d_139 (Conv2D)             (None, 8, 8, 537)    3030291     activation_138[0][0]
# __________________________________________________________________________________________________
# batch_normalization_135 (BatchN (None, 8, 8, 537)    1611        conv2d_135[0][0]
# __________________________________________________________________________________________________
# batch_normalization_139 (BatchN (None, 8, 8, 537)    1611        conv2d_139[0][0]
# __________________________________________________________________________________________________
# activation_135 (Activation)     (None, 8, 8, 537)    0           batch_normalization_135[0][0]
# __________________________________________________________________________________________________
# activation_139 (Activation)     (None, 8, 8, 537)    0           batch_normalization_139[0][0]
# __________________________________________________________________________________________________
# conv2d_136 (Conv2D)             (None, 8, 8, 537)    865107      activation_135[0][0]
# __________________________________________________________________________________________________
# conv2d_137 (Conv2D)             (None, 8, 8, 537)    865107      activation_135[0][0]
# __________________________________________________________________________________________________
# conv2d_140 (Conv2D)             (None, 8, 8, 537)    865107      activation_139[0][0]
# __________________________________________________________________________________________________
# conv2d_141 (Conv2D)             (None, 8, 8, 537)    865107      activation_139[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_13 (AveragePo (None, 8, 8, 2864)   0           mixed8-1[0][0]
# __________________________________________________________________________________________________
# conv2d_134 (Conv2D)             (None, 8, 8, 448)    1283072     mixed8-1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_136 (BatchN (None, 8, 8, 537)    1611        conv2d_136[0][0]
# __________________________________________________________________________________________________
# batch_normalization_137 (BatchN (None, 8, 8, 537)    1611        conv2d_137[0][0]
# __________________________________________________________________________________________________
# batch_normalization_140 (BatchN (None, 8, 8, 537)    1611        conv2d_140[0][0]
# __________________________________________________________________________________________________
# batch_normalization_141 (BatchN (None, 8, 8, 537)    1611        conv2d_141[0][0]
# __________________________________________________________________________________________________
# conv2d_142 (Conv2D)             (None, 8, 8, 268)    767552      average_pooling2d_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_134 (BatchN (None, 8, 8, 448)    1344        conv2d_134[0][0]
# __________________________________________________________________________________________________
# activation_136 (Activation)     (None, 8, 8, 537)    0           batch_normalization_136[0][0]
# __________________________________________________________________________________________________
# activation_137 (Activation)     (None, 8, 8, 537)    0           batch_normalization_137[0][0]
# __________________________________________________________________________________________________
# activation_140 (Activation)     (None, 8, 8, 537)    0           batch_normalization_140[0][0]
# __________________________________________________________________________________________________
# activation_141 (Activation)     (None, 8, 8, 537)    0           batch_normalization_141[0][0]
# __________________________________________________________________________________________________
# batch_normalization_142 (BatchN (None, 8, 8, 268)    804         conv2d_142[0][0]
# __________________________________________________________________________________________________
# activation_134 (Activation)     (None, 8, 8, 448)    0           batch_normalization_134[0][0]
# __________________________________________________________________________________________________
# mixed8_2 (Concatenate)          (None, 8, 8, 1074)   0           activation_136[0][0]
#                                                                  activation_137[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 8, 8, 1074)   0           activation_140[0][0]
#                                                                  activation_141[0][0]
# __________________________________________________________________________________________________
# activation_142 (Activation)     (None, 8, 8, 268)    0           batch_normalization_142[0][0]
# __________________________________________________________________________________________________
# mixed8-2 (Concatenate)          (None, 8, 8, 2864)   0           activation_134[0][0]
#                                                                  mixed8_2[0][0]
#                                                                  concatenate_2[0][0]
#                                                                  activation_142[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 2864)         0           mixed8-2[0][0]
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, 1)]          0
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 2864)         0           global_average_pooling2d[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 100)          200         input_2[0][0]
# __________________________________________________________________________________________________
# gender_and_feat._concat (Concat (None, 2964)         0           dropout[0][0]
#                                                                  dense_2[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 3000)         8895000     gender_and_feat._concat[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 1)            3001        dense_3[0][0]
# ==================================================================================================
# Total params: 78,309,555
# Trainable params: 78,231,931
# Non-trainable params: 77,624
# __________________________________________________________________________________________________
# None
