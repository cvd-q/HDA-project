# %%
import pandas as pd
import tensorflow as tf
import numpy as np
from tensorflow.python.keras.engine import data_adapter
from tensorflow.keras import backend as K
import os, sys
os.mkdir('/kaggle/working/ckpts/')
sys.path.append('../input/boneage-ckpts')
sys.path.append('../input/hdaproject2021-codes/')
sys.path.append('../input/temppp/')

# %%
train_csv_directory = '../input/hdadataset2021/Bone Age Datasets/Bone Age Training Set/'
train_directory = '../input/hdadataset2021/Bone Age Datasets/Bone Age Training Set/boneage-training-dataset/'
df_train = pd.read_csv(train_csv_directory + 'train.csv')

val_csv_directory = '../input/hdadataset2021/'
val_directory = '../input/hdadataset2021/boneage-validation-dataset/'
df_val = pd.read_csv(val_csv_directory + 'Validation Dataset.csv')

# %%
ids = df_train['id'].values.astype(str)
labels = df_train['male'].values.astype(float)
ages = df_train['boneage'].values.astype(float)
train_ds = tf.data.Dataset.from_tensor_slices((ids, labels, ages))


ids = df_val['Image ID'].values.astype(str)
labels = df_val['male'].values.astype(float)
ages = df_val['Bone Age (months)'].values.astype(float)
val_ds = tf.data.Dataset.from_tensor_slices((ids, labels, ages))

IMG_SIZE = (300, 300, 1)
BATCH_SIZE = 16

# %%
def read_train_image(image_file, label, age):
    image = tf.io.read_file(train_directory + image_file+ '.png')
    image = tf.io.decode_png(image, channels=1)
    return image, [label], [age] #lists are necessary for training the model (otherwise dims are unknown)

def read_val_image(image_file, label, age):
    image = tf.io.read_file(val_directory + image_file + '.png')
    image = tf.io.decode_png(image, channels=1)
    return image, [label], [age] #lists are necessary for training the model (otherwise dims are unknown)

resize_layer = tf.keras.layers.experimental.preprocessing.Resizing(height=IMG_SIZE[0], width=IMG_SIZE[1])
normalization_layer = tf.keras.layers.experimental.preprocessing.Rescaling(1/255.)
zoom_layer = tf.keras.layers.experimental.preprocessing.RandomZoom(height_factor=(0.2,-0.3),
                                                                   width_factor=(0.2,-0.3),
                                                                  fill_mode='constant')
flip_layer = tf.keras.layers.experimental.preprocessing.RandomFlip(mode='horizontal')
shift_layer = tf.keras.layers.experimental.preprocessing.RandomTranslation(height_factor=0.2, width_factor=0.2,
                                                                           fill_mode='constant')

def brightness_function(image):
    image = tf.image.random_brightness(image, max_delta=0.3)
    image = tf.math.maximum(image, 0.)
    image = tf.math.minimum(image, 1.)
    return image

def augment(image, label, age):
    # data augmentation here
    image = shift_layer(image)
    image = zoom_layer(image)
    image = flip_layer(image)
    #image = brightness_function(image)
    return image, label, age

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE #tf.data.AUTOTUNE
train_ds = train_ds.map(read_train_image).map(lambda image,label,age: (normalization_layer((resize_layer(image))), label, age)).cache('../input/hdaproject2021-codes/train_cache_300')
train_ds = train_ds.shuffle(buffer_size=1000).batch(BATCH_SIZE).map(augment,num_parallel_calls=AUTOTUNE)
train_ds = train_ds.prefetch(buffer_size=AUTOTUNE)

val_ds = val_ds.map(read_val_image).map(lambda image,label,age: (normalization_layer(resize_layer(image)), label, age)).cache('../input/hdaproject2021-codes/val_cache_300')
val_ds = val_ds.prefetch(buffer_size=AUTOTUNE).batch(BATCH_SIZE)

# %%
#image = list(val_ds.take(1).as_numpy_iterator())[0][0][1]

# %%
# %matplotlib inline
#import matplotlib.pyplot as plt
#_ = plt.imshow(image)

# %% [markdown]
# # Boneage Model

# %%
from InceptionV3_3 import InceptionV3
class BoneAgeInceptionNet(tf.keras.Model):  
    def __init__(self, gender=True, beta=1):
        super(BoneAgeInceptionNet, self).__init__()
        
        model = InceptionV3(
                                include_top=False,
                                weights=None,
                                input_shape=IMG_SIZE,
                                beta=beta)
                
        
        if gender:
            initializer = tf.keras.initializers.GlorotNormal()
            gender_input = tf.keras.Input(shape=(1))
            gender_output = tf.keras.layers.Dense(100, activation='relu', kernel_initializer=initializer)(gender_input)
            
            model_global_avg = tf.keras.layers.GlobalAveragePooling2D()(model.output)
            
            concat_output = tf.keras.layers.Concatenate(name='gender_and_feat._concat')([model_global_avg, gender_output])
            
            #dense_output = tf.keras.layers.Dense(2000,activation='relu', kernel_regularizer='l2', kernel_initializer=initializer)(concat_output)
            
            overall_output = tf.keras.layers.Dense(1,activation='relu', kernel_regularizer='l2', kernel_initializer=initializer)(concat_output)
            
            self.model = tf.keras.Model(inputs=[model.input, gender_input], outputs = overall_output)
        else:
            pass #COMPLETE!
                
        
        
    def call(self, x, training=False):
        imgs, labels = x
        
        y = self.model([imgs, labels],training)
       
        return y

    def train_step(self, data):
        
        data = data_adapter.expand_1d(data)
        imgs, labels, ages = data
        
        with tf.GradientTape() as tape:
            y_pred = self((imgs, labels), training=True)  # Forward pass

            loss = self.compiled_loss(ages, y_pred)

        trainable_vars = self.trainable_variables
        gradients = tape.gradient(loss, trainable_vars)
        
        # Update weights
        self.optimizer.apply_gradients(zip(gradients, trainable_vars))

        self.compiled_metrics.update_state(ages, y_pred)
        _dict = {m.name: m.result() for m in self.metrics}
        
        return _dict

    def test_step(self, data):
        
        data = data_adapter.expand_1d(data)
        imgs, labels, ages = data

        y_pred = self((imgs, labels), training=False)  # Forward pass

        loss = self.compiled_loss(ages, y_pred)

        self.compiled_metrics.update_state(ages, y_pred)
        _dict = {m.name: m.result() for m in self.metrics}
        
        return _dict
    
    def summary(self):
        print(self.model.summary())

# %%
boneageinception = BoneAgeInceptionNet(beta=1)
ckpt_callback = tf.keras.callbacks.ModelCheckpoint(
                filepath='./ckpts/best_val_inception_80ep.h5', monitor='val_mae', verbose=1, save_best_only=True,
                save_weights_only=True, mode='min')

def scheduler(epoch, lr):
    if epoch < 30:
        return lr
    elif epoch < 60:
        return 1e-3
    else:
        return 1e-4

lr_scheduler_callback = tf.keras.callbacks.LearningRateScheduler(scheduler, verbose=1)

optimizer = tf.keras.optimizers.Adam(learning_rate=1e-2)
metric = tf.keras.metrics.MeanAbsoluteError()
boneageinception.compile(optimizer=optimizer, loss='mse', metrics=['mae'])

boneageinception.fit(train_ds, validation_data=val_ds,callbacks = [ckpt_callback,lr_scheduler_callback],
                    epochs=80, verbose=2)
# Out:
# Epoch 1/80
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# 789/789 - 223s - loss: 1802.0460 - mae: 33.5684 - val_loss: 1698.8781 - val_mae: 32.2104
#
# Epoch 00001: val_mae improved from inf to 32.21043, saving model to ./ckpts/best_val_inception_80ep.h5
# Epoch 2/80
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# 789/789 - 196s - loss: 1675.8655 - mae: 32.7601 - val_loss: 1805.4727 - val_mae: 32.4805
#
# Epoch 00002: val_mae did not improve from 32.21043
# Epoch 3/80
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# 789/789 - 196s - loss: 1617.5944 - mae: 32.1626 - val_loss: 1655.2950 - val_mae: 32.8484
#
# Epoch 00003: val_mae did not improve from 32.21043
# Epoch 4/80
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# 789/789 - 197s - loss: 1531.8098 - mae: 31.0976 - val_loss: 1988.0009 - val_mae: 36.9998
#
# Epoch 00004: val_mae did not improve from 32.21043
# Epoch 5/80
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# 789/789 - 197s - loss: 1490.3488 - mae: 30.6385 - val_loss: 3063.8403 - val_mae: 45.8493
#
# Epoch 00005: val_mae did not improve from 32.21043
# Epoch 6/80
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# 789/789 - 196s - loss: 1386.2452 - mae: 29.4021 - val_loss: 3154.8923 - val_mae: 44.7346
#
# Epoch 00006: val_mae did not improve from 32.21043
# Epoch 7/80
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# 789/789 - 197s - loss: 1526.7609 - mae: 31.1439 - val_loss: 3231.4873 - val_mae: 49.6639
#
# Epoch 00007: val_mae did not improve from 32.21043
# Epoch 8/80
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# 789/789 - 196s - loss: 1238.3108 - mae: 27.1826 - val_loss: 2688.9768 - val_mae: 43.7884
#
# Epoch 00008: val_mae did not improve from 32.21043
# Epoch 9/80
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# 789/789 - 196s - loss: 1102.4733 - mae: 25.1151 - val_loss: 2193.0803 - val_mae: 41.9566
#
# Epoch 00009: val_mae did not improve from 32.21043
# Epoch 10/80
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# 789/789 - 196s - loss: 802.0270 - mae: 21.1813 - val_loss: 684.0469 - val_mae: 18.4732
#
# Epoch 00010: val_mae improved from 32.21043 to 18.47324, saving model to ./ckpts/best_val_inception_80ep.h5
# Epoch 11/80
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# 789/789 - 196s - loss: 538.5073 - mae: 17.5183 - val_loss: 638.6875 - val_mae: 20.8499
#
# Epoch 00011: val_mae did not improve from 18.47324
# Epoch 12/80
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# 789/789 - 197s - loss: 455.0635 - mae: 16.2735 - val_loss: 1549.6793 - val_mae: 35.6895
#
# Epoch 00012: val_mae did not improve from 18.47324
# Epoch 13/80
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# 789/789 - 197s - loss: 384.8781 - mae: 15.0596 - val_loss: 348.3878 - val_mae: 14.4435
#
# Epoch 00013: val_mae improved from 18.47324 to 14.44349, saving model to ./ckpts/best_val_inception_80ep.h5
# Epoch 14/80
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# 789/789 - 197s - loss: 385.8636 - mae: 15.0858 - val_loss: 351.6187 - val_mae: 15.0780
#
# Epoch 00014: val_mae did not improve from 14.44349
# Epoch 15/80
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# 789/789 - 197s - loss: 350.2176 - mae: 14.4164 - val_loss: 2997.2930 - val_mae: 49.3748
#
# Epoch 00015: val_mae did not improve from 14.44349
# Epoch 16/80
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# 789/789 - 197s - loss: 324.9625 - mae: 13.8335 - val_loss: 471.5042 - val_mae: 16.5034
#
# Epoch 00016: val_mae did not improve from 14.44349
# Epoch 17/80
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# 789/789 - 196s - loss: 303.2277 - mae: 13.4131 - val_loss: 898.4564 - val_mae: 24.3465
#
# Epoch 00017: val_mae did not improve from 14.44349
# Epoch 18/80
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# 789/789 - 197s - loss: 284.7711 - mae: 12.9275 - val_loss: 917.5908 - val_mae: 26.9977
#
# Epoch 00018: val_mae did not improve from 14.44349
# Epoch 19/80
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# 789/789 - 197s - loss: 274.5380 - mae: 12.6820 - val_loss: 300.4907 - val_mae: 13.4114
#
# Epoch 00019: val_mae improved from 14.44349 to 13.41145, saving model to ./ckpts/best_val_inception_80ep.h5
# Epoch 20/80
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# 789/789 - 196s - loss: 272.6039 - mae: 12.6369 - val_loss: 288.2323 - val_mae: 13.4756
#
# Epoch 00020: val_mae did not improve from 13.41145
# Epoch 21/80
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# 789/789 - 196s - loss: 233.7937 - mae: 11.6711 - val_loss: 190.0837 - val_mae: 10.5528
#
# Epoch 00021: val_mae improved from 13.41145 to 10.55277, saving model to ./ckpts/best_val_inception_80ep.h5
# Epoch 22/80
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# 789/789 - 195s - loss: 234.0755 - mae: 11.6947 - val_loss: 274.0983 - val_mae: 12.3587
#
# Epoch 00022: val_mae did not improve from 10.55277
# Epoch 23/80
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# 789/789 - 195s - loss: 206.4601 - mae: 10.8174 - val_loss: 344.5699 - val_mae: 15.3931
#
# Epoch 00023: val_mae did not improve from 10.55277
# Epoch 24/80
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# 789/789 - 196s - loss: 200.8012 - mae: 10.8059 - val_loss: 188.4753 - val_mae: 10.5473
#
# Epoch 00024: val_mae improved from 10.55277 to 10.54728, saving model to ./ckpts/best_val_inception_80ep.h5
# Epoch 25/80
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# 789/789 - 196s - loss: 197.0145 - mae: 10.6489 - val_loss: 194.6074 - val_mae: 10.2725
#
# Epoch 00025: val_mae improved from 10.54728 to 10.27245, saving model to ./ckpts/best_val_inception_80ep.h5
# Epoch 26/80
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# 789/789 - 196s - loss: 182.1700 - mae: 10.3018 - val_loss: 269.9756 - val_mae: 12.5444
#
# Epoch 00026: val_mae did not improve from 10.27245
# Epoch 27/80
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# 789/789 - 196s - loss: 177.1116 - mae: 10.1329 - val_loss: 195.1608 - val_mae: 10.4671
#
# Epoch 00027: val_mae did not improve from 10.27245
# Epoch 28/80
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# 789/789 - 196s - loss: 172.0563 - mae: 10.0127 - val_loss: 452.8715 - val_mae: 14.6673
#
# Epoch 00028: val_mae did not improve from 10.27245
# Epoch 29/80
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# 789/789 - 196s - loss: 168.7103 - mae: 9.9125 - val_loss: 300.2254 - val_mae: 12.5991
#
# Epoch 00029: val_mae did not improve from 10.27245
# Epoch 30/80
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# 789/789 - 196s - loss: 165.5301 - mae: 9.7642 - val_loss: 163.0735 - val_mae: 9.3513
#
# Epoch 00030: val_mae improved from 10.27245 to 9.35131, saving model to ./ckpts/best_val_inception_80ep.h5
# Epoch 31/80
#
# Epoch 00031: LearningRateScheduler reducing learning rate to 0.001.
# 789/789 - 196s - loss: 130.9907 - mae: 8.6904 - val_loss: 137.2395 - val_mae: 8.8876
#
# Epoch 00031: val_mae improved from 9.35131 to 8.88756, saving model to ./ckpts/best_val_inception_80ep.h5
# Epoch 32/80
#
# Epoch 00032: LearningRateScheduler reducing learning rate to 0.001.
# 789/789 - 195s - loss: 127.4686 - mae: 8.6396 - val_loss: 133.4222 - val_mae: 8.7692
#
# Epoch 00032: val_mae improved from 8.88756 to 8.76923, saving model to ./ckpts/best_val_inception_80ep.h5
# Epoch 33/80
#
# Epoch 00033: LearningRateScheduler reducing learning rate to 0.001.
# 789/789 - 196s - loss: 124.5585 - mae: 8.5429 - val_loss: 142.2355 - val_mae: 9.1507
#
# Epoch 00033: val_mae did not improve from 8.76923
# Epoch 34/80
#
# Epoch 00034: LearningRateScheduler reducing learning rate to 0.001.
# 789/789 - 195s - loss: 123.9486 - mae: 8.5249 - val_loss: 129.3951 - val_mae: 8.6491
#
# Epoch 00034: val_mae improved from 8.76923 to 8.64907, saving model to ./ckpts/best_val_inception_80ep.h5
# Epoch 35/80
#
# Epoch 00035: LearningRateScheduler reducing learning rate to 0.001.
# 789/789 - 196s - loss: 121.4666 - mae: 8.4346 - val_loss: 133.6301 - val_mae: 8.8796
#
# Epoch 00035: val_mae did not improve from 8.64907
# Epoch 36/80
#
# Epoch 00036: LearningRateScheduler reducing learning rate to 0.001.
# 789/789 - 196s - loss: 122.3294 - mae: 8.4713 - val_loss: 131.8947 - val_mae: 8.7467
#
# Epoch 00036: val_mae did not improve from 8.64907
# Epoch 37/80
#
# Epoch 00037: LearningRateScheduler reducing learning rate to 0.001.
# 789/789 - 196s - loss: 121.2623 - mae: 8.3459 - val_loss: 126.9558 - val_mae: 8.5085
#
# Epoch 00037: val_mae improved from 8.64907 to 8.50850, saving model to ./ckpts/best_val_inception_80ep.h5
# Epoch 38/80
#
# Epoch 00038: LearningRateScheduler reducing learning rate to 0.001.
# 789/789 - 195s - loss: 117.3597 - mae: 8.3011 - val_loss: 134.0498 - val_mae: 8.7937
#
# Epoch 00038: val_mae did not improve from 8.50850
# Epoch 39/80
#
# Epoch 00039: LearningRateScheduler reducing learning rate to 0.001.
# 789/789 - 195s - loss: 119.1942 - mae: 8.3141 - val_loss: 126.4357 - val_mae: 8.5174
#
# Epoch 00039: val_mae did not improve from 8.50850
# Epoch 40/80
#
# Epoch 00040: LearningRateScheduler reducing learning rate to 0.001.
# 789/789 - 196s - loss: 118.5832 - mae: 8.3521 - val_loss: 123.2670 - val_mae: 8.4568
#
# Epoch 00040: val_mae improved from 8.50850 to 8.45680, saving model to ./ckpts/best_val_inception_80ep.h5
# Epoch 41/80
#
# Epoch 00041: LearningRateScheduler reducing learning rate to 0.001.
# 789/789 - 196s - loss: 117.0826 - mae: 8.2931 - val_loss: 126.1661 - val_mae: 8.4215
#
# Epoch 00041: val_mae improved from 8.45680 to 8.42155, saving model to ./ckpts/best_val_inception_80ep.h5
# Epoch 42/80
#
# Epoch 00042: LearningRateScheduler reducing learning rate to 0.001.
# 789/789 - 196s - loss: 115.9896 - mae: 8.2888 - val_loss: 127.9244 - val_mae: 8.4963
#
# Epoch 00042: val_mae did not improve from 8.42155
# Epoch 43/80
#
# Epoch 00043: LearningRateScheduler reducing learning rate to 0.001.
# 789/789 - 195s - loss: 115.6257 - mae: 8.2178 - val_loss: 125.7275 - val_mae: 8.4581
#
# Epoch 00043: val_mae did not improve from 8.42155
# Epoch 44/80
#
# Epoch 00044: LearningRateScheduler reducing learning rate to 0.001.
# 789/789 - 195s - loss: 116.5851 - mae: 8.2696 - val_loss: 120.6215 - val_mae: 8.3632
#
# Epoch 00044: val_mae improved from 8.42155 to 8.36325, saving model to ./ckpts/best_val_inception_80ep.h5
# Epoch 45/80
#
# Epoch 00045: LearningRateScheduler reducing learning rate to 0.001.
# 789/789 - 196s - loss: 113.7317 - mae: 8.2045 - val_loss: 123.3064 - val_mae: 8.4151
#
# Epoch 00045: val_mae did not improve from 8.36325
# Epoch 46/80
#
# Epoch 00046: LearningRateScheduler reducing learning rate to 0.001.
# 789/789 - 195s - loss: 115.4832 - mae: 8.2418 - val_loss: 135.7856 - val_mae: 8.9308
#
# Epoch 00046: val_mae did not improve from 8.36325
# Epoch 47/80
#
# Epoch 00047: LearningRateScheduler reducing learning rate to 0.001.
# 789/789 - 195s - loss: 113.0013 - mae: 8.1603 - val_loss: 129.9490 - val_mae: 8.6872
#
# Epoch 00047: val_mae did not improve from 8.36325
# Epoch 48/80
#
# Epoch 00048: LearningRateScheduler reducing learning rate to 0.001.
# 789/789 - 196s - loss: 110.7942 - mae: 8.1317 - val_loss: 134.8281 - val_mae: 8.8579
#
# Epoch 00048: val_mae did not improve from 8.36325
# Epoch 49/80
#
# Epoch 00049: LearningRateScheduler reducing learning rate to 0.001.
# 789/789 - 196s - loss: 110.3608 - mae: 8.0590 - val_loss: 133.4768 - val_mae: 8.6746
#
# Epoch 00049: val_mae did not improve from 8.36325
# Epoch 50/80
#
# Epoch 00050: LearningRateScheduler reducing learning rate to 0.001.
# 789/789 - 196s - loss: 109.4870 - mae: 8.0853 - val_loss: 123.3410 - val_mae: 8.3205
#
# Epoch 00050: val_mae improved from 8.36325 to 8.32049, saving model to ./ckpts/best_val_inception_80ep.h5
# Epoch 51/80
#
# Epoch 00051: LearningRateScheduler reducing learning rate to 0.001.
# 789/789 - 196s - loss: 111.0188 - mae: 8.0991 - val_loss: 116.9576 - val_mae: 8.2562
#
# Epoch 00051: val_mae improved from 8.32049 to 8.25618, saving model to ./ckpts/best_val_inception_80ep.h5
# Epoch 52/80
#
# Epoch 00052: LearningRateScheduler reducing learning rate to 0.001.
# 789/789 - 196s - loss: 108.8984 - mae: 8.0395 - val_loss: 124.2248 - val_mae: 8.3440
#
# Epoch 00052: val_mae did not improve from 8.25618
# Epoch 53/80
#
# Epoch 00053: LearningRateScheduler reducing learning rate to 0.001.
# 789/789 - 196s - loss: 111.2794 - mae: 8.0840 - val_loss: 124.7963 - val_mae: 8.4523
#
# Epoch 00053: val_mae did not improve from 8.25618
# Epoch 54/80
#
# Epoch 00054: LearningRateScheduler reducing learning rate to 0.001.
# 789/789 - 196s - loss: 108.2997 - mae: 8.0434 - val_loss: 124.4827 - val_mae: 8.3613
#
# Epoch 00054: val_mae did not improve from 8.25618
# Epoch 55/80
#
# Epoch 00055: LearningRateScheduler reducing learning rate to 0.001.
# 789/789 - 195s - loss: 108.4232 - mae: 7.9927 - val_loss: 121.1541 - val_mae: 8.2527
#
# Epoch 00055: val_mae improved from 8.25618 to 8.25266, saving model to ./ckpts/best_val_inception_80ep.h5
# Epoch 56/80
#
# Epoch 00056: LearningRateScheduler reducing learning rate to 0.001.
# 789/789 - 196s - loss: 109.8312 - mae: 8.0405 - val_loss: 121.6109 - val_mae: 8.2926
#
# Epoch 00056: val_mae did not improve from 8.25266
# Epoch 57/80
#
# Epoch 00057: LearningRateScheduler reducing learning rate to 0.001.
# 789/789 - 196s - loss: 109.2263 - mae: 8.0407 - val_loss: 122.3220 - val_mae: 8.2543
#
# Epoch 00057: val_mae did not improve from 8.25266
# Epoch 58/80
#
# Epoch 00058: LearningRateScheduler reducing learning rate to 0.001.
# 789/789 - 196s - loss: 106.7935 - mae: 7.9639 - val_loss: 120.1189 - val_mae: 8.2327
#
# Epoch 00058: val_mae improved from 8.25266 to 8.23265, saving model to ./ckpts/best_val_inception_80ep.h5
# Epoch 59/80
#
# Epoch 00059: LearningRateScheduler reducing learning rate to 0.001.
# 789/789 - 196s - loss: 106.8591 - mae: 7.9633 - val_loss: 120.6786 - val_mae: 8.1991
#
# Epoch 00059: val_mae improved from 8.23265 to 8.19908, saving model to ./ckpts/best_val_inception_80ep.h5
# Epoch 60/80
#
# Epoch 00060: LearningRateScheduler reducing learning rate to 0.001.
# 789/789 - 196s - loss: 110.1582 - mae: 8.0056 - val_loss: 127.5041 - val_mae: 8.4511
#
# Epoch 00060: val_mae did not improve from 8.19908
# Epoch 61/80
#
# Epoch 00061: LearningRateScheduler reducing learning rate to 0.0001.
# 789/789 - 196s - loss: 106.2290 - mae: 7.8994 - val_loss: 123.7579 - val_mae: 8.2787
#
# Epoch 00061: val_mae did not improve from 8.19908
# Epoch 62/80
#
# Epoch 00062: LearningRateScheduler reducing learning rate to 0.0001.
# 789/789 - 196s - loss: 107.3917 - mae: 7.8901 - val_loss: 123.7647 - val_mae: 8.2874
#
# Epoch 00062: val_mae did not improve from 8.19908
# Epoch 63/80
#
# Epoch 00063: LearningRateScheduler reducing learning rate to 0.0001.
# 789/789 - 196s - loss: 105.3605 - mae: 7.8454 - val_loss: 122.0174 - val_mae: 8.2281
#
# Epoch 00063: val_mae did not improve from 8.19908
# Epoch 64/80
#
# Epoch 00064: LearningRateScheduler reducing learning rate to 0.0001.
# 789/789 - 196s - loss: 104.0607 - mae: 7.8326 - val_loss: 122.3603 - val_mae: 8.2489
#
# Epoch 00064: val_mae did not improve from 8.19908
# Epoch 65/80
#
# Epoch 00065: LearningRateScheduler reducing learning rate to 0.0001.
# 789/789 - 195s - loss: 104.6612 - mae: 7.8693 - val_loss: 121.5685 - val_mae: 8.2275
#
# Epoch 00065: val_mae did not improve from 8.19908
# Epoch 66/80
#
# Epoch 00066: LearningRateScheduler reducing learning rate to 0.0001.
# 789/789 - 196s - loss: 103.8310 - mae: 7.8577 - val_loss: 121.0104 - val_mae: 8.2198
#
# Epoch 00066: val_mae did not improve from 8.19908
# Epoch 67/80
#
# Epoch 00067: LearningRateScheduler reducing learning rate to 0.0001.
# 789/789 - 196s - loss: 102.6605 - mae: 7.8245 - val_loss: 120.3436 - val_mae: 8.1986
#
# Epoch 00067: val_mae improved from 8.19908 to 8.19860, saving model to ./ckpts/best_val_inception_80ep.h5
# Epoch 68/80
#
# Epoch 00068: LearningRateScheduler reducing learning rate to 0.0001.
# 789/789 - 196s - loss: 103.1385 - mae: 7.7962 - val_loss: 121.5905 - val_mae: 8.2480
#
# Epoch 00068: val_mae did not improve from 8.19860
# Epoch 69/80
#
# Epoch 00069: LearningRateScheduler reducing learning rate to 0.0001.
# 789/789 - 195s - loss: 101.6590 - mae: 7.7998 - val_loss: 121.5596 - val_mae: 8.2527
#
# Epoch 00069: val_mae did not improve from 8.19860
# Epoch 70/80
#
# Epoch 00070: LearningRateScheduler reducing learning rate to 0.0001.
# 789/789 - 196s - loss: 102.0192 - mae: 7.7962 - val_loss: 121.4973 - val_mae: 8.2646
#
# Epoch 00070: val_mae did not improve from 8.19860
# Epoch 71/80
#
# Epoch 00071: LearningRateScheduler reducing learning rate to 0.0001.
# 789/789 - 196s - loss: 104.1547 - mae: 7.8503 - val_loss: 120.9708 - val_mae: 8.2383
#
# Epoch 00071: val_mae did not improve from 8.19860
# Epoch 72/80
#
# Epoch 00072: LearningRateScheduler reducing learning rate to 0.0001.
# 789/789 - 195s - loss: 103.0695 - mae: 7.7994 - val_loss: 121.7202 - val_mae: 8.2592
#
# Epoch 00072: val_mae did not improve from 8.19860
# Epoch 73/80
#
# Epoch 00073: LearningRateScheduler reducing learning rate to 0.0001.
# 789/789 - 196s - loss: 103.4449 - mae: 7.7935 - val_loss: 119.1867 - val_mae: 8.1683
#
# Epoch 00073: val_mae improved from 8.19860 to 8.16831, saving model to ./ckpts/best_val_inception_80ep.h5
# Epoch 74/80
#
# Epoch 00074: LearningRateScheduler reducing learning rate to 0.0001.
# 789/789 - 196s - loss: 103.0927 - mae: 7.7843 - val_loss: 119.6886 - val_mae: 8.1905
#
# Epoch 00074: val_mae did not improve from 8.16831
# Epoch 75/80
#
# Epoch 00075: LearningRateScheduler reducing learning rate to 0.0001.
# 789/789 - 196s - loss: 101.5313 - mae: 7.7689 - val_loss: 121.3326 - val_mae: 8.2456
#
# Epoch 00075: val_mae did not improve from 8.16831
# Epoch 76/80
#
# Epoch 00076: LearningRateScheduler reducing learning rate to 0.0001.
# 789/789 - 195s - loss: 102.3966 - mae: 7.7778 - val_loss: 118.8268 - val_mae: 8.1800
#
# Epoch 00076: val_mae did not improve from 8.16831
# Epoch 77/80
#
# Epoch 00077: LearningRateScheduler reducing learning rate to 0.0001.
# 789/789 - 196s - loss: 102.8365 - mae: 7.7834 - val_loss: 117.1747 - val_mae: 8.1154
#
# Epoch 00077: val_mae improved from 8.16831 to 8.11541, saving model to ./ckpts/best_val_inception_80ep.h5
# Epoch 78/80
#
# Epoch 00078: LearningRateScheduler reducing learning rate to 0.0001.
# 789/789 - 195s - loss: 103.5375 - mae: 7.7906 - val_loss: 118.9913 - val_mae: 8.1575
#
# Epoch 00078: val_mae did not improve from 8.11541
# Epoch 79/80
#
# Epoch 00079: LearningRateScheduler reducing learning rate to 0.0001.
# 789/789 - 196s - loss: 102.7459 - mae: 7.7819 - val_loss: 120.6164 - val_mae: 8.2191
#
# Epoch 00079: val_mae did not improve from 8.11541
# Epoch 80/80
#
# Epoch 00080: LearningRateScheduler reducing learning rate to 0.0001.
# 789/789 - 196s - loss: 102.6761 - mae: 7.7675 - val_loss: 122.6067 - val_mae: 8.2861
#
# Epoch 00080: val_mae did not improve from 8.11541

# %% [markdown]
# ### test

# %%
test_directory = '../input/hdadataset2021/Bone Age Datasets/Bone Age Test Set/Test Set Images/'

df_test = pd.read_csv('../input/hdaproject2021-codes/test.csv')

ids = df_test['id'].values.astype(str)
labels = (df_test['Sex'].values == 'M').astype(float)

# replace ',' with '.' and convert to float
ages_str = df_test['boneage'].values
ages = np.empty_like(ages_str)
for i, item in enumerate(ages_str):
    replaced = item.replace(',','.')
    replaced_float = float(replaced)
    ages[i] = replaced_float
ages = ages.astype(float)

test_ds = tf.data.Dataset.from_tensor_slices((ids, labels, ages))

def read_test_image(image_file, label, age):
    image = tf.io.read_file(test_directory + image_file + '.png')
    image = tf.io.decode_png(image, channels=1)
    return image, [label], [age] #lists are necessary for training the model (otherwise dims are unknown)

test_ds = test_ds.map(read_test_image).map(lambda image,label,age: (normalization_layer(resize_layer(image)), label, age)).cache()
test_ds = test_ds.prefetch(buffer_size=AUTOTUNE)

test_iterator = test_ds.as_numpy_iterator()
N = 200 #number of samples
test_images = np.empty(shape=(N, IMG_SIZE[0], IMG_SIZE[1], 1), dtype=np.float32)
test_labels = np.empty(shape=(N,), dtype=np.float32)
test_ages = np.empty(shape=(N,), dtype=np.float32)
for i, item in enumerate(test_iterator):
    test_images[i] = item[0]
    test_labels[i] = item[1]
    test_ages[i] = item[2]
    
print(test_images.shape)
print(test_labels.shape)
print(test_ages.shape)
# Out:
# (200, 300, 300, 1)
# (200,)
# (200,)

# %%
boneageinception.load_weights('./ckpts/best_val_inception_80ep.h5')

# %%
boneageinception_pred = boneageinception.predict((test_images, test_labels))

# %%
np.mean(np.abs(boneageinception_pred.squeeze() - test_ages.squeeze()))
# Out:
# 7.090858

# %%
boneageinception.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 300, 300, 1) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 149, 149, 32) 288         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 149, 149, 32) 96          conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 149, 149, 32) 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 147, 147, 32) 9216        activation[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 147, 147, 32) 96          conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 147, 147, 32) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 147, 147, 64) 18432       activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 147, 147, 64) 192         conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 147, 147, 64) 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 73, 73, 64)   0           activation_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 73, 73, 80)   5120        max_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 73, 73, 80)   240         conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 73, 73, 80)   0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 71, 71, 192)  138240      activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 71, 71, 192)  576         conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 71, 71, 192)  0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 35, 35, 192)  0           activation_4[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 35, 35, 64)   12288       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 35, 35, 64)   192         conv2d_8[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 35, 35, 64)   0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 35, 35, 48)   9216        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 35, 35, 96)   55296       activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 35, 35, 48)   144         conv2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 35, 35, 96)   288         conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 35, 35, 48)   0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 35, 35, 96)   0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# average_pooling2d (AveragePooli (None, 35, 35, 192)  0           max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 35, 35, 64)   12288       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 35, 35, 64)   76800       activation_6[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 35, 35, 96)   82944       activation_9[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 35, 35, 32)   6144        average_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 35, 35, 64)   192         conv2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 35, 35, 64)   192         conv2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 35, 35, 96)   288         conv2d_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 35, 35, 32)   96          conv2d_11[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 35, 35, 64)   0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 35, 35, 64)   0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 35, 35, 96)   0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 35, 35, 32)   0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# mixed0-0 (Concatenate)          (None, 35, 35, 256)  0           activation_5[0][0]
#                                                                  activation_7[0][0]
#                                                                  activation_10[0][0]
#                                                                  activation_11[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 35, 35, 64)   16384       mixed0-0[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 35, 35, 64)   192         conv2d_15[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 35, 35, 64)   0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 35, 35, 48)   12288       mixed0-0[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 35, 35, 96)   55296       activation_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 35, 35, 48)   144         conv2d_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 35, 35, 96)   288         conv2d_16[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 35, 35, 48)   0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 35, 35, 96)   0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_1 (AveragePoo (None, 35, 35, 256)  0           mixed0-0[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 35, 35, 64)   16384       mixed0-0[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 35, 35, 64)   76800       activation_13[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 35, 35, 96)   82944       activation_16[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 35, 35, 64)   16384       average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 35, 35, 64)   192         conv2d_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 35, 35, 64)   192         conv2d_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 35, 35, 96)   288         conv2d_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 35, 35, 64)   192         conv2d_18[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 35, 35, 64)   0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 35, 35, 64)   0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 35, 35, 96)   0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 35, 35, 64)   0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# mixed1 (Concatenate)            (None, 35, 35, 288)  0           activation_12[0][0]
#                                                                  activation_14[0][0]
#                                                                  activation_17[0][0]
#                                                                  activation_18[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 35, 35, 64)   18432       mixed1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 35, 35, 64)   192         conv2d_22[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 35, 35, 64)   0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 35, 35, 48)   13824       mixed1[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 35, 35, 96)   55296       activation_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 35, 35, 48)   144         conv2d_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 35, 35, 96)   288         conv2d_23[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 35, 35, 48)   0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 35, 35, 96)   0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_2 (AveragePoo (None, 35, 35, 288)  0           mixed1[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 35, 35, 64)   18432       mixed1[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 35, 35, 64)   76800       activation_20[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 35, 35, 96)   82944       activation_23[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 35, 35, 64)   18432       average_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 35, 35, 64)   192         conv2d_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 35, 35, 64)   192         conv2d_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 35, 35, 96)   288         conv2d_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 35, 35, 64)   192         conv2d_25[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 35, 35, 64)   0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 35, 35, 64)   0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 35, 35, 96)   0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 35, 35, 64)   0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# mixed2 (Concatenate)            (None, 35, 35, 288)  0           activation_19[0][0]
#                                                                  activation_21[0][0]
#                                                                  activation_24[0][0]
#                                                                  activation_25[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 35, 35, 64)   18432       mixed2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 35, 35, 64)   192         conv2d_27[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 35, 35, 64)   0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 35, 35, 96)   55296       activation_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 35, 35, 96)   288         conv2d_28[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 35, 35, 96)   0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 17, 17, 384)  995328      mixed2[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 17, 17, 96)   82944       activation_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 17, 17, 384)  1152        conv2d_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 17, 17, 96)   288         conv2d_29[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 17, 17, 384)  0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 17, 17, 96)   0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 17, 17, 288)  0           mixed2[0][0]
# __________________________________________________________________________________________________
# mixed3 (Concatenate)            (None, 17, 17, 768)  0           activation_26[0][0]
#                                                                  activation_29[0][0]
#                                                                  max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 17, 17, 128)  98304       mixed3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 17, 17, 128)  384         conv2d_34[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 17, 17, 128)  0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 17, 17, 128)  114688      activation_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 17, 17, 128)  384         conv2d_35[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 17, 17, 128)  0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 17, 17, 128)  98304       mixed3[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 17, 17, 128)  114688      activation_35[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 17, 17, 128)  384         conv2d_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 17, 17, 128)  384         conv2d_36[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 17, 17, 128)  0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 17, 17, 128)  0           batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 17, 17, 128)  114688      activation_31[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 17, 17, 128)  114688      activation_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 17, 17, 128)  384         conv2d_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 17, 17, 128)  384         conv2d_37[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 17, 17, 128)  0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 17, 17, 128)  0           batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_3 (AveragePoo (None, 17, 17, 768)  0           mixed3[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 17, 17, 192)  147456      mixed3[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 17, 17, 192)  172032      activation_32[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 17, 17, 192)  172032      activation_37[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 17, 17, 192)  147456      average_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 17, 17, 192)  576         conv2d_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 17, 17, 192)  576         conv2d_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 17, 17, 192)  576         conv2d_38[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 17, 17, 192)  576         conv2d_39[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 17, 17, 192)  0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 17, 17, 192)  0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 17, 17, 192)  0           batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 17, 17, 192)  0           batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# mixed4 (Concatenate)            (None, 17, 17, 768)  0           activation_30[0][0]
#                                                                  activation_33[0][0]
#                                                                  activation_38[0][0]
#                                                                  activation_39[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 17, 17, 160)  122880      mixed4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 17, 17, 160)  480         conv2d_44[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 17, 17, 160)  0           batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 17, 17, 160)  179200      activation_44[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 17, 17, 160)  480         conv2d_45[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 17, 17, 160)  0           batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 17, 17, 160)  122880      mixed4[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 17, 17, 160)  179200      activation_45[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 17, 17, 160)  480         conv2d_41[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 17, 17, 160)  480         conv2d_46[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 17, 17, 160)  0           batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 17, 17, 160)  0           batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 17, 17, 160)  179200      activation_41[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 17, 17, 160)  179200      activation_46[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 17, 17, 160)  480         conv2d_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, 17, 17, 160)  480         conv2d_47[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 17, 17, 160)  0           batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 17, 17, 160)  0           batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_4 (AveragePoo (None, 17, 17, 768)  0           mixed4[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 17, 17, 192)  147456      mixed4[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 17, 17, 192)  215040      activation_42[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 17, 17, 192)  215040      activation_47[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 17, 17, 192)  147456      average_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 17, 17, 192)  576         conv2d_40[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 17, 17, 192)  576         conv2d_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 17, 17, 192)  576         conv2d_48[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, 17, 17, 192)  576         conv2d_49[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 17, 17, 192)  0           batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 17, 17, 192)  0           batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 17, 17, 192)  0           batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, 17, 17, 192)  0           batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# mixed5-0 (Concatenate)          (None, 17, 17, 768)  0           activation_40[0][0]
#                                                                  activation_43[0][0]
#                                                                  activation_48[0][0]
#                                                                  activation_49[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 17, 17, 160)  122880      mixed5-0[0][0]
# __________________________________________________________________________________________________
# batch_normalization_54 (BatchNo (None, 17, 17, 160)  480         conv2d_54[0][0]
# __________________________________________________________________________________________________
# activation_54 (Activation)      (None, 17, 17, 160)  0           batch_normalization_54[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 17, 17, 160)  179200      activation_54[0][0]
# __________________________________________________________________________________________________
# batch_normalization_55 (BatchNo (None, 17, 17, 160)  480         conv2d_55[0][0]
# __________________________________________________________________________________________________
# activation_55 (Activation)      (None, 17, 17, 160)  0           batch_normalization_55[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 17, 17, 160)  122880      mixed5-0[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 17, 17, 160)  179200      activation_55[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 17, 17, 160)  480         conv2d_51[0][0]
# __________________________________________________________________________________________________
# batch_normalization_56 (BatchNo (None, 17, 17, 160)  480         conv2d_56[0][0]
# __________________________________________________________________________________________________
# activation_51 (Activation)      (None, 17, 17, 160)  0           batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# activation_56 (Activation)      (None, 17, 17, 160)  0           batch_normalization_56[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 17, 17, 160)  179200      activation_51[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, 17, 17, 160)  179200      activation_56[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, 17, 17, 160)  480         conv2d_52[0][0]
# __________________________________________________________________________________________________
# batch_normalization_57 (BatchNo (None, 17, 17, 160)  480         conv2d_57[0][0]
# __________________________________________________________________________________________________
# activation_52 (Activation)      (None, 17, 17, 160)  0           batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# activation_57 (Activation)      (None, 17, 17, 160)  0           batch_normalization_57[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_5 (AveragePoo (None, 17, 17, 768)  0           mixed5-0[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 17, 17, 192)  147456      mixed5-0[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 17, 17, 192)  215040      activation_52[0][0]
# __________________________________________________________________________________________________
# conv2d_58 (Conv2D)              (None, 17, 17, 192)  215040      activation_57[0][0]
# __________________________________________________________________________________________________
# conv2d_59 (Conv2D)              (None, 17, 17, 192)  147456      average_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, 17, 17, 192)  576         conv2d_50[0][0]
# __________________________________________________________________________________________________
# batch_normalization_53 (BatchNo (None, 17, 17, 192)  576         conv2d_53[0][0]
# __________________________________________________________________________________________________
# batch_normalization_58 (BatchNo (None, 17, 17, 192)  576         conv2d_58[0][0]
# __________________________________________________________________________________________________
# batch_normalization_59 (BatchNo (None, 17, 17, 192)  576         conv2d_59[0][0]
# __________________________________________________________________________________________________
# activation_50 (Activation)      (None, 17, 17, 192)  0           batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# activation_53 (Activation)      (None, 17, 17, 192)  0           batch_normalization_53[0][0]
# __________________________________________________________________________________________________
# activation_58 (Activation)      (None, 17, 17, 192)  0           batch_normalization_58[0][0]
# __________________________________________________________________________________________________
# activation_59 (Activation)      (None, 17, 17, 192)  0           batch_normalization_59[0][0]
# __________________________________________________________________________________________________
# mixed5-1 (Concatenate)          (None, 17, 17, 768)  0           activation_50[0][0]
#                                                                  activation_53[0][0]
#                                                                  activation_58[0][0]
#                                                                  activation_59[0][0]
# __________________________________________________________________________________________________
# conv2d_64 (Conv2D)              (None, 17, 17, 160)  122880      mixed5-1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_64 (BatchNo (None, 17, 17, 160)  480         conv2d_64[0][0]
# __________________________________________________________________________________________________
# activation_64 (Activation)      (None, 17, 17, 160)  0           batch_normalization_64[0][0]
# __________________________________________________________________________________________________
# conv2d_65 (Conv2D)              (None, 17, 17, 160)  179200      activation_64[0][0]
# __________________________________________________________________________________________________
# batch_normalization_65 (BatchNo (None, 17, 17, 160)  480         conv2d_65[0][0]
# __________________________________________________________________________________________________
# activation_65 (Activation)      (None, 17, 17, 160)  0           batch_normalization_65[0][0]
# __________________________________________________________________________________________________
# conv2d_61 (Conv2D)              (None, 17, 17, 160)  122880      mixed5-1[0][0]
# __________________________________________________________________________________________________
# conv2d_66 (Conv2D)              (None, 17, 17, 160)  179200      activation_65[0][0]
# __________________________________________________________________________________________________
# batch_normalization_61 (BatchNo (None, 17, 17, 160)  480         conv2d_61[0][0]
# __________________________________________________________________________________________________
# batch_normalization_66 (BatchNo (None, 17, 17, 160)  480         conv2d_66[0][0]
# __________________________________________________________________________________________________
# activation_61 (Activation)      (None, 17, 17, 160)  0           batch_normalization_61[0][0]
# __________________________________________________________________________________________________
# activation_66 (Activation)      (None, 17, 17, 160)  0           batch_normalization_66[0][0]
# __________________________________________________________________________________________________
# conv2d_62 (Conv2D)              (None, 17, 17, 160)  179200      activation_61[0][0]
# __________________________________________________________________________________________________
# conv2d_67 (Conv2D)              (None, 17, 17, 160)  179200      activation_66[0][0]
# __________________________________________________________________________________________________
# batch_normalization_62 (BatchNo (None, 17, 17, 160)  480         conv2d_62[0][0]
# __________________________________________________________________________________________________
# batch_normalization_67 (BatchNo (None, 17, 17, 160)  480         conv2d_67[0][0]
# __________________________________________________________________________________________________
# activation_62 (Activation)      (None, 17, 17, 160)  0           batch_normalization_62[0][0]
# __________________________________________________________________________________________________
# activation_67 (Activation)      (None, 17, 17, 160)  0           batch_normalization_67[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_6 (AveragePoo (None, 17, 17, 768)  0           mixed5-1[0][0]
# __________________________________________________________________________________________________
# conv2d_60 (Conv2D)              (None, 17, 17, 192)  147456      mixed5-1[0][0]
# __________________________________________________________________________________________________
# conv2d_63 (Conv2D)              (None, 17, 17, 192)  215040      activation_62[0][0]
# __________________________________________________________________________________________________
# conv2d_68 (Conv2D)              (None, 17, 17, 192)  215040      activation_67[0][0]
# __________________________________________________________________________________________________
# conv2d_69 (Conv2D)              (None, 17, 17, 192)  147456      average_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_60 (BatchNo (None, 17, 17, 192)  576         conv2d_60[0][0]
# __________________________________________________________________________________________________
# batch_normalization_63 (BatchNo (None, 17, 17, 192)  576         conv2d_63[0][0]
# __________________________________________________________________________________________________
# batch_normalization_68 (BatchNo (None, 17, 17, 192)  576         conv2d_68[0][0]
# __________________________________________________________________________________________________
# batch_normalization_69 (BatchNo (None, 17, 17, 192)  576         conv2d_69[0][0]
# __________________________________________________________________________________________________
# activation_60 (Activation)      (None, 17, 17, 192)  0           batch_normalization_60[0][0]
# __________________________________________________________________________________________________
# activation_63 (Activation)      (None, 17, 17, 192)  0           batch_normalization_63[0][0]
# __________________________________________________________________________________________________
# activation_68 (Activation)      (None, 17, 17, 192)  0           batch_normalization_68[0][0]
# __________________________________________________________________________________________________
# activation_69 (Activation)      (None, 17, 17, 192)  0           batch_normalization_69[0][0]
# __________________________________________________________________________________________________
# mixed5-2 (Concatenate)          (None, 17, 17, 768)  0           activation_60[0][0]
#                                                                  activation_63[0][0]
#                                                                  activation_68[0][0]
#                                                                  activation_69[0][0]
# __________________________________________________________________________________________________
# ...
# __________________________________________________________________________________________________
# mixed8_1 (Concatenate)          (None, 8, 8, 768)    0           activation_157[0][0]
#                                                                  activation_158[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 8, 8, 768)    0           activation_161[0][0]
#                                                                  activation_162[0][0]
# __________________________________________________________________________________________________
# activation_163 (Activation)     (None, 8, 8, 192)    0           batch_normalization_163[0][0]
# __________________________________________________________________________________________________
# mixed8-1 (Concatenate)          (None, 8, 8, 2048)   0           activation_155[0][0]
#                                                                  mixed8_1[0][0]
#                                                                  concatenate_1[0][0]
#                                                                  activation_163[0][0]
# __________________________________________________________________________________________________
# conv2d_168 (Conv2D)             (None, 8, 8, 448)    917504      mixed8-1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_168 (BatchN (None, 8, 8, 448)    1344        conv2d_168[0][0]
# __________________________________________________________________________________________________
# activation_168 (Activation)     (None, 8, 8, 448)    0           batch_normalization_168[0][0]
# __________________________________________________________________________________________________
# conv2d_165 (Conv2D)             (None, 8, 8, 384)    786432      mixed8-1[0][0]
# __________________________________________________________________________________________________
# conv2d_169 (Conv2D)             (None, 8, 8, 384)    1548288     activation_168[0][0]
# __________________________________________________________________________________________________
# batch_normalization_165 (BatchN (None, 8, 8, 384)    1152        conv2d_165[0][0]
# __________________________________________________________________________________________________
# batch_normalization_169 (BatchN (None, 8, 8, 384)    1152        conv2d_169[0][0]
# __________________________________________________________________________________________________
# activation_165 (Activation)     (None, 8, 8, 384)    0           batch_normalization_165[0][0]
# __________________________________________________________________________________________________
# activation_169 (Activation)     (None, 8, 8, 384)    0           batch_normalization_169[0][0]
# __________________________________________________________________________________________________
# conv2d_166 (Conv2D)             (None, 8, 8, 384)    442368      activation_165[0][0]
# __________________________________________________________________________________________________
# conv2d_167 (Conv2D)             (None, 8, 8, 384)    442368      activation_165[0][0]
# __________________________________________________________________________________________________
# conv2d_170 (Conv2D)             (None, 8, 8, 384)    442368      activation_169[0][0]
# __________________________________________________________________________________________________
# conv2d_171 (Conv2D)             (None, 8, 8, 384)    442368      activation_169[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_16 (AveragePo (None, 8, 8, 2048)   0           mixed8-1[0][0]
# __________________________________________________________________________________________________
# conv2d_164 (Conv2D)             (None, 8, 8, 320)    655360      mixed8-1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_166 (BatchN (None, 8, 8, 384)    1152        conv2d_166[0][0]
# __________________________________________________________________________________________________
# batch_normalization_167 (BatchN (None, 8, 8, 384)    1152        conv2d_167[0][0]
# __________________________________________________________________________________________________
# batch_normalization_170 (BatchN (None, 8, 8, 384)    1152        conv2d_170[0][0]
# __________________________________________________________________________________________________
# batch_normalization_171 (BatchN (None, 8, 8, 384)    1152        conv2d_171[0][0]
# __________________________________________________________________________________________________
# conv2d_172 (Conv2D)             (None, 8, 8, 192)    393216      average_pooling2d_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_164 (BatchN (None, 8, 8, 320)    960         conv2d_164[0][0]
# __________________________________________________________________________________________________
# activation_166 (Activation)     (None, 8, 8, 384)    0           batch_normalization_166[0][0]
# __________________________________________________________________________________________________
# activation_167 (Activation)     (None, 8, 8, 384)    0           batch_normalization_167[0][0]
# __________________________________________________________________________________________________
# activation_170 (Activation)     (None, 8, 8, 384)    0           batch_normalization_170[0][0]
# __________________________________________________________________________________________________
# activation_171 (Activation)     (None, 8, 8, 384)    0           batch_normalization_171[0][0]
# __________________________________________________________________________________________________
# batch_normalization_172 (BatchN (None, 8, 8, 192)    576         conv2d_172[0][0]
# __________________________________________________________________________________________________
# activation_164 (Activation)     (None, 8, 8, 320)    0           batch_normalization_164[0][0]
# __________________________________________________________________________________________________
# mixed8_2 (Concatenate)          (None, 8, 8, 768)    0           activation_166[0][0]
#                                                                  activation_167[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 8, 8, 768)    0           activation_170[0][0]
#                                                                  activation_171[0][0]
# __________________________________________________________________________________________________
# activation_172 (Activation)     (None, 8, 8, 192)    0           batch_normalization_172[0][0]
# __________________________________________________________________________________________________
# mixed8-2 (Concatenate)          (None, 8, 8, 2048)   0           activation_164[0][0]
#                                                                  mixed8_2[0][0]
#                                                                  concatenate_2[0][0]
#                                                                  activation_172[0][0]
# __________________________________________________________________________________________________
# conv2d_177 (Conv2D)             (None, 8, 8, 448)    917504      mixed8-2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_177 (BatchN (None, 8, 8, 448)    1344        conv2d_177[0][0]
# __________________________________________________________________________________________________
# activation_177 (Activation)     (None, 8, 8, 448)    0           batch_normalization_177[0][0]
# __________________________________________________________________________________________________
# conv2d_174 (Conv2D)             (None, 8, 8, 384)    786432      mixed8-2[0][0]
# __________________________________________________________________________________________________
# conv2d_178 (Conv2D)             (None, 8, 8, 384)    1548288     activation_177[0][0]
# __________________________________________________________________________________________________
# batch_normalization_174 (BatchN (None, 8, 8, 384)    1152        conv2d_174[0][0]
# __________________________________________________________________________________________________
# batch_normalization_178 (BatchN (None, 8, 8, 384)    1152        conv2d_178[0][0]
# __________________________________________________________________________________________________
# activation_174 (Activation)     (None, 8, 8, 384)    0           batch_normalization_174[0][0]
# __________________________________________________________________________________________________
# activation_178 (Activation)     (None, 8, 8, 384)    0           batch_normalization_178[0][0]
# __________________________________________________________________________________________________
# conv2d_175 (Conv2D)             (None, 8, 8, 384)    442368      activation_174[0][0]
# __________________________________________________________________________________________________
# conv2d_176 (Conv2D)             (None, 8, 8, 384)    442368      activation_174[0][0]
# __________________________________________________________________________________________________
# conv2d_179 (Conv2D)             (None, 8, 8, 384)    442368      activation_178[0][0]
# __________________________________________________________________________________________________
# conv2d_180 (Conv2D)             (None, 8, 8, 384)    442368      activation_178[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_17 (AveragePo (None, 8, 8, 2048)   0           mixed8-2[0][0]
# __________________________________________________________________________________________________
# conv2d_173 (Conv2D)             (None, 8, 8, 320)    655360      mixed8-2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_175 (BatchN (None, 8, 8, 384)    1152        conv2d_175[0][0]
# __________________________________________________________________________________________________
# batch_normalization_176 (BatchN (None, 8, 8, 384)    1152        conv2d_176[0][0]
# __________________________________________________________________________________________________
# batch_normalization_179 (BatchN (None, 8, 8, 384)    1152        conv2d_179[0][0]
# __________________________________________________________________________________________________
# batch_normalization_180 (BatchN (None, 8, 8, 384)    1152        conv2d_180[0][0]
# __________________________________________________________________________________________________
# conv2d_181 (Conv2D)             (None, 8, 8, 192)    393216      average_pooling2d_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_173 (BatchN (None, 8, 8, 320)    960         conv2d_173[0][0]
# __________________________________________________________________________________________________
# activation_175 (Activation)     (None, 8, 8, 384)    0           batch_normalization_175[0][0]
# __________________________________________________________________________________________________
# activation_176 (Activation)     (None, 8, 8, 384)    0           batch_normalization_176[0][0]
# __________________________________________________________________________________________________
# activation_179 (Activation)     (None, 8, 8, 384)    0           batch_normalization_179[0][0]
# __________________________________________________________________________________________________
# activation_180 (Activation)     (None, 8, 8, 384)    0           batch_normalization_180[0][0]
# __________________________________________________________________________________________________
# batch_normalization_181 (BatchN (None, 8, 8, 192)    576         conv2d_181[0][0]
# __________________________________________________________________________________________________
# activation_173 (Activation)     (None, 8, 8, 320)    0           batch_normalization_173[0][0]
# __________________________________________________________________________________________________
# mixed8_3 (Concatenate)          (None, 8, 8, 768)    0           activation_175[0][0]
#                                                                  activation_176[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 8, 8, 768)    0           activation_179[0][0]
#                                                                  activation_180[0][0]
# __________________________________________________________________________________________________
# activation_181 (Activation)     (None, 8, 8, 192)    0           batch_normalization_181[0][0]
# __________________________________________________________________________________________________
# mixed8-3 (Concatenate)          (None, 8, 8, 2048)   0           activation_173[0][0]
#                                                                  mixed8_3[0][0]
#                                                                  concatenate_3[0][0]
#                                                                  activation_181[0][0]
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, 1)]          0
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 2048)         0           mixed8-3[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 100)          200         input_2[0][0]
# __________________________________________________________________________________________________
# gender_and_feat._concat (Concat (None, 2148)         0           global_average_pooling2d[0][0]
#                                                                  dense[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 1)            2149        gender_and_feat._concat[0][0]
# ==================================================================================================
# Total params: 47,167,245
# Trainable params: 47,094,413
# Non-trainable params: 72,832
# __________________________________________________________________________________________________
# None
