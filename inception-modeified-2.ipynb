# %%
import pandas as pd
import tensorflow as tf
import numpy as np
from tensorflow.python.keras.engine import data_adapter
from tensorflow.keras import backend as K
import os, sys
os.mkdir('/kaggle/working/ckpts/')
sys.path.append('../input/boneage-ckpts')
sys.path.append('../input/hdaproject2021-codes/')
sys.path.append('../input/temppp/')

# %%
train_csv_directory = '../input/hdadataset2021/Bone Age Datasets/Bone Age Training Set/'
train_directory = '../input/hdadataset2021/Bone Age Datasets/Bone Age Training Set/boneage-training-dataset/'
df_train = pd.read_csv(train_csv_directory + 'train.csv')

val_csv_directory = '../input/hdadataset2021/'
val_directory = '../input/hdadataset2021/boneage-validation-dataset/'
df_val = pd.read_csv(val_csv_directory + 'Validation Dataset.csv')

# %%
ids = df_train['id'].values.astype(str)
labels = df_train['male'].values.astype(float)
ages = df_train['boneage'].values.astype(float)
train_ds = tf.data.Dataset.from_tensor_slices((ids, labels, ages))


ids = df_val['Image ID'].values.astype(str)
labels = df_val['male'].values.astype(float)
ages = df_val['Bone Age (months)'].values.astype(float)
val_ds = tf.data.Dataset.from_tensor_slices((ids, labels, ages))

IMG_SIZE = (300, 300, 1)
BATCH_SIZE = 16

# %%
def read_train_image(image_file, label, age):
    image = tf.io.read_file(train_directory + image_file+ '.png')
    image = tf.io.decode_png(image, channels=1)
    return image, [label], [age] #lists are necessary for training the model (otherwise dims are unknown)

def read_val_image(image_file, label, age):
    image = tf.io.read_file(val_directory + image_file + '.png')
    image = tf.io.decode_png(image, channels=1)
    return image, [label], [age] #lists are necessary for training the model (otherwise dims are unknown)

resize_layer = tf.keras.layers.experimental.preprocessing.Resizing(height=IMG_SIZE[0], width=IMG_SIZE[1])
normalization_layer = tf.keras.layers.experimental.preprocessing.Rescaling(1/255.)
zoom_layer = tf.keras.layers.experimental.preprocessing.RandomZoom(height_factor=(0.2,-0.3),
                                                                   width_factor=(0.2,-0.3),
                                                                  fill_mode='constant')
flip_layer = tf.keras.layers.experimental.preprocessing.RandomFlip(mode='horizontal')
shift_layer = tf.keras.layers.experimental.preprocessing.RandomTranslation(height_factor=0.2, width_factor=0.2,
                                                                           fill_mode='constant')

def brightness_function(image):
    image = tf.image.random_brightness(image, max_delta=0.3)
    image = tf.math.maximum(image, 0.)
    image = tf.math.minimum(image, 1.)
    return image

def augment(image, label, age):
    # data augmentation here
    image = shift_layer(image)
    image = zoom_layer(image)
    image = flip_layer(image)
    #image = brightness_function(image)
    return image, label, age

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE #tf.data.AUTOTUNE
train_ds = train_ds.map(read_train_image).map(lambda image,label,age: (normalization_layer((resize_layer(image))), label, age)).cache('../input/hdaproject2021-codes/train_cache_300')
train_ds = train_ds.shuffle(buffer_size=1000).batch(BATCH_SIZE).map(augment,num_parallel_calls=AUTOTUNE)
train_ds = train_ds.prefetch(buffer_size=AUTOTUNE)

val_ds = val_ds.map(read_val_image).map(lambda image,label,age: (normalization_layer(resize_layer(image)), label, age)).cache('../input/hdaproject2021-codes/val_cache_300')
val_ds = val_ds.prefetch(buffer_size=AUTOTUNE).batch(BATCH_SIZE)

# %%
#image = list(val_ds.take(1).as_numpy_iterator())[0][0][1]

# %%
# %matplotlib inline
#import matplotlib.pyplot as plt
#_ = plt.imshow(image)

# %% [markdown]
# # Boneage Model

# %%
from InceptionV3_1 import InceptionV3
class BoneAgeInceptionNet(tf.keras.Model):  
    def __init__(self, gender=True, beta=1):
        super(BoneAgeInceptionNet, self).__init__()
        
        model = InceptionV3(
                                include_top=False,
                                weights=None,
                                input_shape=IMG_SIZE,
                                beta=beta)
        
        
        
        #dense_model = DenseNet()
        
        #last_conv=relu_final_blk
        #for layer in dense_model.model.layers:
            #global_average
            #if layer.name.startswith('global_max'):
                #model_global_max = layer.output
                
        
        if gender:
            initializer = tf.keras.initializers.GlorotNormal()
            gender_input = tf.keras.Input(shape=(1))
            gender_output = tf.keras.layers.Dense(100, activation='relu', kernel_initializer=initializer)(gender_input)
            
            model_global_avg = tf.keras.layers.GlobalAveragePooling2D()(model.output)
            
            concat_output = tf.keras.layers.Concatenate(name='gender_and_feat._concat')([model_global_avg, gender_output])
            
            #dense_output = tf.keras.layers.Dense(2000,activation='relu', kernel_regularizer='l2', kernel_initializer=initializer)(concat_output)
            
            overall_output = tf.keras.layers.Dense(1,activation='relu', kernel_regularizer='l2', kernel_initializer=initializer)(concat_output)
            
            self.model = tf.keras.Model(inputs=[model.input, gender_input], outputs = overall_output)
        else:
            pass #COMPLETE!
                
        
        
    def call(self, x, training=False):
        imgs, labels = x
        
        y = self.model([imgs, labels],training)
       
        return y

    def train_step(self, data):
        
        data = data_adapter.expand_1d(data)
        imgs, labels, ages = data
        
        with tf.GradientTape() as tape:
            y_pred = self((imgs, labels), training=True)  # Forward pass

            loss = self.compiled_loss(ages, y_pred)

        trainable_vars = self.trainable_variables
        gradients = tape.gradient(loss, trainable_vars)
        
        # Update weights
        self.optimizer.apply_gradients(zip(gradients, trainable_vars))

        self.compiled_metrics.update_state(ages, y_pred)
        _dict = {m.name: m.result() for m in self.metrics}
        
        return _dict

    def test_step(self, data):
        
        data = data_adapter.expand_1d(data)
        imgs, labels, ages = data

        y_pred = self((imgs, labels), training=False)  # Forward pass

        loss = self.compiled_loss(ages, y_pred)

        self.compiled_metrics.update_state(ages, y_pred)
        _dict = {m.name: m.result() for m in self.metrics}
        
        return _dict
    
    def summary(self):
        print(self.model.summary())

# %%
boneageinception = BoneAgeInceptionNet(beta=1.3)
ckpt_callback = tf.keras.callbacks.ModelCheckpoint(
                filepath='./ckpts/best_val_inception_80ep.h5', monitor='val_mae', verbose=1, save_best_only=True,
                save_weights_only=True, mode='min')

def scheduler(epoch, lr):
    if epoch < 30:
        return lr
    elif epoch < 60:
        return 1e-3
    else:
        return 1e-4

lr_scheduler_callback = tf.keras.callbacks.LearningRateScheduler(scheduler, verbose=1)

optimizer = tf.keras.optimizers.Adam(learning_rate=1e-2)
metric = tf.keras.metrics.MeanAbsoluteError()
boneageinception.compile(optimizer=optimizer, loss='mse', metrics=['mae'])

boneageinception.fit(train_ds, validation_data=val_ds,callbacks = [ckpt_callback,lr_scheduler_callback],
                    epochs=80, verbose=2)
# Out:
# Epoch 1/80
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# 789/789 - 243s - loss: 1782.4303 - mae: 33.4543 - val_loss: 2090.6572 - val_mae: 38.7787
#
# Epoch 00001: val_mae improved from inf to 38.77870, saving model to ./ckpts/best_val_inception_80ep.h5
# Epoch 2/80
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# 789/789 - 218s - loss: 1618.0751 - mae: 32.1608 - val_loss: 2983.2410 - val_mae: 41.8772
#
# Epoch 00002: val_mae did not improve from 38.77870
# Epoch 3/80
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# 789/789 - 219s - loss: 1634.0934 - mae: 32.3043 - val_loss: 2480.8591 - val_mae: 42.6896
#
# Epoch 00003: val_mae did not improve from 38.77870
# Epoch 4/80
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# 789/789 - 218s - loss: 1592.9532 - mae: 31.9105 - val_loss: 3221.0725 - val_mae: 48.9196
#
# Epoch 00004: val_mae did not improve from 38.77870
# Epoch 5/80
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# 789/789 - 218s - loss: 1569.4504 - mae: 31.6505 - val_loss: 2350.6135 - val_mae: 36.2874
#
# Epoch 00005: val_mae improved from 38.77870 to 36.28742, saving model to ./ckpts/best_val_inception_80ep.h5
# Epoch 6/80
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# 789/789 - 218s - loss: 1406.8584 - mae: 29.6964 - val_loss: 1686.4824 - val_mae: 32.6409
#
# Epoch 00006: val_mae improved from 36.28742 to 32.64094, saving model to ./ckpts/best_val_inception_80ep.h5
# Epoch 7/80
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# 789/789 - 218s - loss: 1220.0619 - mae: 27.3020 - val_loss: 1704.7196 - val_mae: 31.8649
#
# Epoch 00007: val_mae improved from 32.64094 to 31.86490, saving model to ./ckpts/best_val_inception_80ep.h5
# Epoch 8/80
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# 789/789 - 219s - loss: 1169.4871 - mae: 26.3077 - val_loss: 1296.7561 - val_mae: 27.4802
#
# Epoch 00008: val_mae improved from 31.86490 to 27.48018, saving model to ./ckpts/best_val_inception_80ep.h5
# Epoch 9/80
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# 789/789 - 219s - loss: 923.9304 - mae: 22.7463 - val_loss: 3586.8140 - val_mae: 53.3050
#
# Epoch 00009: val_mae did not improve from 27.48018
# Epoch 10/80
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# 789/789 - 219s - loss: 750.2948 - mae: 20.1900 - val_loss: 831.3088 - val_mae: 21.7704
#
# Epoch 00010: val_mae improved from 27.48018 to 21.77041, saving model to ./ckpts/best_val_inception_80ep.h5
# Epoch 11/80
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# 789/789 - 219s - loss: 570.9161 - mae: 17.9155 - val_loss: 707.8668 - val_mae: 20.3896
#
# Epoch 00011: val_mae improved from 21.77041 to 20.38960, saving model to ./ckpts/best_val_inception_80ep.h5
# Epoch 12/80
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# 789/789 - 218s - loss: 409.9006 - mae: 15.4530 - val_loss: 363.2144 - val_mae: 14.8150
#
# Epoch 00012: val_mae improved from 20.38960 to 14.81502, saving model to ./ckpts/best_val_inception_80ep.h5
# Epoch 13/80
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# 789/789 - 218s - loss: 383.1339 - mae: 14.9729 - val_loss: 1052.7036 - val_mae: 29.0394
#
# Epoch 00013: val_mae did not improve from 14.81502
# Epoch 14/80
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# 789/789 - 218s - loss: 341.4056 - mae: 14.1852 - val_loss: 241.2345 - val_mae: 11.8027
#
# Epoch 00014: val_mae improved from 14.81502 to 11.80272, saving model to ./ckpts/best_val_inception_80ep.h5
# Epoch 15/80
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# 789/789 - 219s - loss: 328.1488 - mae: 13.9701 - val_loss: 288.9566 - val_mae: 12.7368
#
# Epoch 00015: val_mae did not improve from 11.80272
# Epoch 16/80
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# 789/789 - 219s - loss: 322.4255 - mae: 13.8025 - val_loss: 238.5592 - val_mae: 11.4615
#
# Epoch 00016: val_mae improved from 11.80272 to 11.46149, saving model to ./ckpts/best_val_inception_80ep.h5
# Epoch 17/80
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# 789/789 - 219s - loss: 312.7449 - mae: 13.5951 - val_loss: 233.1500 - val_mae: 11.3438
#
# Epoch 00017: val_mae improved from 11.46149 to 11.34382, saving model to ./ckpts/best_val_inception_80ep.h5
# Epoch 18/80
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# 789/789 - 218s - loss: 288.2545 - mae: 13.0813 - val_loss: 294.0771 - val_mae: 13.1102
#
# Epoch 00018: val_mae did not improve from 11.34382
# Epoch 19/80
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# 789/789 - 218s - loss: 274.8758 - mae: 12.8171 - val_loss: 188.4725 - val_mae: 10.3930
#
# Epoch 00019: val_mae improved from 11.34382 to 10.39299, saving model to ./ckpts/best_val_inception_80ep.h5
# Epoch 20/80
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# 789/789 - 219s - loss: 256.6535 - mae: 12.2954 - val_loss: 305.5927 - val_mae: 13.6114
#
# Epoch 00020: val_mae did not improve from 10.39299
# Epoch 21/80
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# 789/789 - 218s - loss: 234.6040 - mae: 11.7101 - val_loss: 197.5141 - val_mae: 10.5636
#
# Epoch 00021: val_mae did not improve from 10.39299
# Epoch 22/80
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# 789/789 - 218s - loss: 224.1680 - mae: 11.3626 - val_loss: 186.5472 - val_mae: 10.7033
#
# Epoch 00022: val_mae did not improve from 10.39299
# Epoch 23/80
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# 789/789 - 219s - loss: 208.0112 - mae: 11.0153 - val_loss: 168.5372 - val_mae: 9.8981
#
# Epoch 00023: val_mae improved from 10.39299 to 9.89808, saving model to ./ckpts/best_val_inception_80ep.h5
# Epoch 24/80
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# 789/789 - 219s - loss: 183.2390 - mae: 10.4021 - val_loss: 246.2028 - val_mae: 11.8598
#
# Epoch 00024: val_mae did not improve from 9.89808
# Epoch 25/80
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# 789/789 - 218s - loss: 179.5866 - mae: 10.2409 - val_loss: 362.8907 - val_mae: 15.4617
#
# Epoch 00025: val_mae did not improve from 9.89808
# Epoch 26/80
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# 789/789 - 218s - loss: 196.9807 - mae: 10.6180 - val_loss: 183.2811 - val_mae: 10.1972
#
# Epoch 00026: val_mae did not improve from 9.89808
# Epoch 27/80
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# 789/789 - 219s - loss: 178.3616 - mae: 10.1429 - val_loss: 159.2561 - val_mae: 9.4663
#
# Epoch 00027: val_mae improved from 9.89808 to 9.46631, saving model to ./ckpts/best_val_inception_80ep.h5
# Epoch 28/80
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# 789/789 - 218s - loss: 174.9312 - mae: 10.0347 - val_loss: 166.3876 - val_mae: 9.9202
#
# Epoch 00028: val_mae did not improve from 9.46631
# Epoch 29/80
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# 789/789 - 219s - loss: 160.2197 - mae: 9.7200 - val_loss: 206.9018 - val_mae: 11.1225
#
# Epoch 00029: val_mae did not improve from 9.46631
# Epoch 30/80
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# 789/789 - 218s - loss: 163.1909 - mae: 9.7350 - val_loss: 199.5130 - val_mae: 11.1702
#
# Epoch 00030: val_mae did not improve from 9.46631
# Epoch 31/80
#
# Epoch 00031: LearningRateScheduler reducing learning rate to 0.001.
# 789/789 - 219s - loss: 127.8837 - mae: 8.6403 - val_loss: 141.9221 - val_mae: 8.9763
#
# Epoch 00031: val_mae improved from 9.46631 to 8.97634, saving model to ./ckpts/best_val_inception_80ep.h5
# Epoch 32/80
#
# Epoch 00032: LearningRateScheduler reducing learning rate to 0.001.
# 789/789 - 218s - loss: 121.0417 - mae: 8.4105 - val_loss: 132.8075 - val_mae: 8.6362
#
# Epoch 00032: val_mae improved from 8.97634 to 8.63620, saving model to ./ckpts/best_val_inception_80ep.h5
# Epoch 33/80
#
# Epoch 00033: LearningRateScheduler reducing learning rate to 0.001.
# 789/789 - 218s - loss: 121.9386 - mae: 8.4740 - val_loss: 132.7742 - val_mae: 8.6795
#
# Epoch 00033: val_mae did not improve from 8.63620
# Epoch 34/80
#
# Epoch 00034: LearningRateScheduler reducing learning rate to 0.001.
# 789/789 - 219s - loss: 121.6964 - mae: 8.4336 - val_loss: 140.0226 - val_mae: 8.9871
#
# Epoch 00034: val_mae did not improve from 8.63620
# Epoch 35/80
#
# Epoch 00035: LearningRateScheduler reducing learning rate to 0.001.
# 789/789 - 218s - loss: 120.4947 - mae: 8.4113 - val_loss: 132.0484 - val_mae: 8.6807
#
# Epoch 00035: val_mae did not improve from 8.63620
# Epoch 36/80
#
# Epoch 00036: LearningRateScheduler reducing learning rate to 0.001.
# 789/789 - 219s - loss: 117.3883 - mae: 8.3523 - val_loss: 129.1486 - val_mae: 8.5211
#
# Epoch 00036: val_mae improved from 8.63620 to 8.52113, saving model to ./ckpts/best_val_inception_80ep.h5
# Epoch 37/80
#
# Epoch 00037: LearningRateScheduler reducing learning rate to 0.001.
# 789/789 - 219s - loss: 117.1088 - mae: 8.2891 - val_loss: 126.5221 - val_mae: 8.4188
#
# Epoch 00037: val_mae improved from 8.52113 to 8.41883, saving model to ./ckpts/best_val_inception_80ep.h5
# Epoch 38/80
#
# Epoch 00038: LearningRateScheduler reducing learning rate to 0.001.
# 789/789 - 218s - loss: 116.8555 - mae: 8.2823 - val_loss: 128.7326 - val_mae: 8.5615
#
# Epoch 00038: val_mae did not improve from 8.41883
# Epoch 39/80
#
# Epoch 00039: LearningRateScheduler reducing learning rate to 0.001.
# 789/789 - 219s - loss: 115.1525 - mae: 8.3056 - val_loss: 123.2135 - val_mae: 8.3183
#
# Epoch 00039: val_mae improved from 8.41883 to 8.31826, saving model to ./ckpts/best_val_inception_80ep.h5
# Epoch 40/80
#
# Epoch 00040: LearningRateScheduler reducing learning rate to 0.001.
# 789/789 - 218s - loss: 113.2385 - mae: 8.1792 - val_loss: 134.3791 - val_mae: 8.7791
#
# Epoch 00040: val_mae did not improve from 8.31826
# Epoch 41/80
#
# Epoch 00041: LearningRateScheduler reducing learning rate to 0.001.
# 789/789 - 218s - loss: 111.7867 - mae: 8.1831 - val_loss: 134.5089 - val_mae: 8.7520
#
# Epoch 00041: val_mae did not improve from 8.31826
# Epoch 42/80
#
# Epoch 00042: LearningRateScheduler reducing learning rate to 0.001.
# 789/789 - 218s - loss: 112.3540 - mae: 8.1397 - val_loss: 145.7379 - val_mae: 9.2144
#
# Epoch 00042: val_mae did not improve from 8.31826
# Epoch 43/80
#
# Epoch 00043: LearningRateScheduler reducing learning rate to 0.001.
# 789/789 - 218s - loss: 112.0054 - mae: 8.1773 - val_loss: 127.8080 - val_mae: 8.4903
#
# Epoch 00043: val_mae did not improve from 8.31826
# Epoch 44/80
#
# Epoch 00044: LearningRateScheduler reducing learning rate to 0.001.
# 789/789 - 219s - loss: 112.0518 - mae: 8.1399 - val_loss: 124.0847 - val_mae: 8.4252
#
# Epoch 00044: val_mae did not improve from 8.31826
# Epoch 45/80
#
# Epoch 00045: LearningRateScheduler reducing learning rate to 0.001.
# 789/789 - 219s - loss: 112.6052 - mae: 8.1467 - val_loss: 127.0334 - val_mae: 8.4739
#
# Epoch 00045: val_mae did not improve from 8.31826
# Epoch 46/80
#
# Epoch 00046: LearningRateScheduler reducing learning rate to 0.001.
# 789/789 - 219s - loss: 110.3453 - mae: 8.0544 - val_loss: 121.0615 - val_mae: 8.2724
#
# Epoch 00046: val_mae improved from 8.31826 to 8.27244, saving model to ./ckpts/best_val_inception_80ep.h5
# Epoch 47/80
#
# Epoch 00047: LearningRateScheduler reducing learning rate to 0.001.
# 789/789 - 218s - loss: 110.0939 - mae: 8.0684 - val_loss: 132.4606 - val_mae: 8.7854
#
# Epoch 00047: val_mae did not improve from 8.27244
# Epoch 48/80
#
# Epoch 00048: LearningRateScheduler reducing learning rate to 0.001.
# 789/789 - 219s - loss: 108.9344 - mae: 8.0096 - val_loss: 130.4397 - val_mae: 8.6998
#
# Epoch 00048: val_mae did not improve from 8.27244
# Epoch 49/80
#
# Epoch 00049: LearningRateScheduler reducing learning rate to 0.001.
# 789/789 - 219s - loss: 108.3507 - mae: 8.0235 - val_loss: 123.1036 - val_mae: 8.3044
#
# Epoch 00049: val_mae did not improve from 8.27244
# Epoch 50/80
#
# Epoch 00050: LearningRateScheduler reducing learning rate to 0.001.
# 789/789 - 219s - loss: 108.6783 - mae: 8.0511 - val_loss: 132.7269 - val_mae: 8.7832
#
# Epoch 00050: val_mae did not improve from 8.27244
# Epoch 51/80
#
# Epoch 00051: LearningRateScheduler reducing learning rate to 0.001.
# 789/789 - 219s - loss: 108.3590 - mae: 8.0370 - val_loss: 122.7805 - val_mae: 8.2995
#
# Epoch 00051: val_mae did not improve from 8.27244
# Epoch 52/80
#
# Epoch 00052: LearningRateScheduler reducing learning rate to 0.001.
# 789/789 - 218s - loss: 106.8808 - mae: 7.9542 - val_loss: 123.1849 - val_mae: 8.3578
#
# Epoch 00052: val_mae did not improve from 8.27244
# Epoch 53/80
#
# Epoch 00053: LearningRateScheduler reducing learning rate to 0.001.
# 789/789 - 219s - loss: 107.8625 - mae: 8.0251 - val_loss: 130.7580 - val_mae: 8.6608
#
# Epoch 00053: val_mae did not improve from 8.27244
# Epoch 54/80
#
# Epoch 00054: LearningRateScheduler reducing learning rate to 0.001.
# 789/789 - 218s - loss: 106.4720 - mae: 7.9396 - val_loss: 123.2961 - val_mae: 8.2980
#
# Epoch 00054: val_mae did not improve from 8.27244
# Epoch 55/80
#
# Epoch 00055: LearningRateScheduler reducing learning rate to 0.001.
# 789/789 - 219s - loss: 106.7528 - mae: 7.9188 - val_loss: 123.6355 - val_mae: 8.3726
#
# Epoch 00055: val_mae did not improve from 8.27244
# Epoch 56/80
#
# Epoch 00056: LearningRateScheduler reducing learning rate to 0.001.
# 789/789 - 219s - loss: 104.3773 - mae: 7.9046 - val_loss: 123.3466 - val_mae: 8.3119
#
# Epoch 00056: val_mae did not improve from 8.27244
# Epoch 57/80
#
# Epoch 00057: LearningRateScheduler reducing learning rate to 0.001.
# 789/789 - 218s - loss: 104.9351 - mae: 7.9042 - val_loss: 119.6498 - val_mae: 8.1804
#
# Epoch 00057: val_mae improved from 8.27244 to 8.18042, saving model to ./ckpts/best_val_inception_80ep.h5
# Epoch 58/80
#
# Epoch 00058: LearningRateScheduler reducing learning rate to 0.001.
# 789/789 - 219s - loss: 105.1693 - mae: 7.9275 - val_loss: 124.7496 - val_mae: 8.3375
#
# Epoch 00058: val_mae did not improve from 8.18042
# Epoch 59/80
#
# Epoch 00059: LearningRateScheduler reducing learning rate to 0.001.
# 789/789 - 218s - loss: 104.8370 - mae: 7.9083 - val_loss: 119.6890 - val_mae: 8.1434
#
# Epoch 00059: val_mae improved from 8.18042 to 8.14340, saving model to ./ckpts/best_val_inception_80ep.h5
# Epoch 60/80
#
# Epoch 00060: LearningRateScheduler reducing learning rate to 0.001.
# 789/789 - 218s - loss: 104.2597 - mae: 7.8707 - val_loss: 127.7908 - val_mae: 8.5390
#
# Epoch 00060: val_mae did not improve from 8.14340
# Epoch 61/80
#
# Epoch 00061: LearningRateScheduler reducing learning rate to 0.0001.
# 789/789 - 218s - loss: 101.6870 - mae: 7.7383 - val_loss: 121.7375 - val_mae: 8.2670
#
# Epoch 00061: val_mae did not improve from 8.14340
# Epoch 62/80
#
# Epoch 00062: LearningRateScheduler reducing learning rate to 0.0001.
# 789/789 - 219s - loss: 100.0151 - mae: 7.7081 - val_loss: 120.7654 - val_mae: 8.2418
#
# Epoch 00062: val_mae did not improve from 8.14340
# Epoch 63/80
#
# Epoch 00063: LearningRateScheduler reducing learning rate to 0.0001.
# 789/789 - 219s - loss: 99.2164 - mae: 7.6789 - val_loss: 121.5281 - val_mae: 8.2627
#
# Epoch 00063: val_mae did not improve from 8.14340
# Epoch 64/80
#
# Epoch 00064: LearningRateScheduler reducing learning rate to 0.0001.
# 789/789 - 219s - loss: 100.3737 - mae: 7.7215 - val_loss: 120.3266 - val_mae: 8.2220
#
# Epoch 00064: val_mae did not improve from 8.14340
# Epoch 65/80
#
# Epoch 00065: LearningRateScheduler reducing learning rate to 0.0001.
# 789/789 - 219s - loss: 99.0200 - mae: 7.6960 - val_loss: 119.3299 - val_mae: 8.1926
#
# Epoch 00065: val_mae did not improve from 8.14340
# Epoch 66/80
#
# Epoch 00066: LearningRateScheduler reducing learning rate to 0.0001.
# 789/789 - 218s - loss: 99.5078 - mae: 7.7103 - val_loss: 120.2108 - val_mae: 8.2258
#
# Epoch 00066: val_mae did not improve from 8.14340
# Epoch 67/80
#
# Epoch 00067: LearningRateScheduler reducing learning rate to 0.0001.
# 789/789 - 218s - loss: 100.7261 - mae: 7.7066 - val_loss: 120.4270 - val_mae: 8.2162
#
# Epoch 00067: val_mae did not improve from 8.14340
# Epoch 68/80
#
# Epoch 00068: LearningRateScheduler reducing learning rate to 0.0001.
# 789/789 - 219s - loss: 99.0190 - mae: 7.6723 - val_loss: 120.9471 - val_mae: 8.2552
#
# Epoch 00068: val_mae did not improve from 8.14340
# Epoch 69/80
#
# Epoch 00069: LearningRateScheduler reducing learning rate to 0.0001.
# 789/789 - 219s - loss: 98.3378 - mae: 7.6621 - val_loss: 119.2153 - val_mae: 8.1679
#
# Epoch 00069: val_mae did not improve from 8.14340
# Epoch 70/80
#
# Epoch 00070: LearningRateScheduler reducing learning rate to 0.0001.
# 789/789 - 219s - loss: 99.8895 - mae: 7.6855 - val_loss: 118.7663 - val_mae: 8.1530
#
# Epoch 00070: val_mae did not improve from 8.14340
# Epoch 71/80
#
# Epoch 00071: LearningRateScheduler reducing learning rate to 0.0001.
# 789/789 - 218s - loss: 98.9634 - mae: 7.6980 - val_loss: 118.9123 - val_mae: 8.1649
#
# Epoch 00071: val_mae did not improve from 8.14340
# Epoch 72/80
#
# Epoch 00072: LearningRateScheduler reducing learning rate to 0.0001.
# 789/789 - 218s - loss: 97.5256 - mae: 7.6489 - val_loss: 119.7923 - val_mae: 8.2096
#
# Epoch 00072: val_mae did not improve from 8.14340
# Epoch 73/80
#
# Epoch 00073: LearningRateScheduler reducing learning rate to 0.0001.
# 789/789 - 218s - loss: 100.4098 - mae: 7.7109 - val_loss: 119.4284 - val_mae: 8.2031
#
# Epoch 00073: val_mae did not improve from 8.14340
# Epoch 74/80
#
# Epoch 00074: LearningRateScheduler reducing learning rate to 0.0001.
# 789/789 - 218s - loss: 100.6364 - mae: 7.6856 - val_loss: 119.3589 - val_mae: 8.1982
#
# Epoch 00074: val_mae did not improve from 8.14340
# Epoch 75/80
#
# Epoch 00075: LearningRateScheduler reducing learning rate to 0.0001.
# 789/789 - 218s - loss: 99.3895 - mae: 7.6917 - val_loss: 119.5528 - val_mae: 8.2010
#
# Epoch 00075: val_mae did not improve from 8.14340
# Epoch 76/80
#
# Epoch 00076: LearningRateScheduler reducing learning rate to 0.0001.
# 789/789 - 219s - loss: 99.1437 - mae: 7.6611 - val_loss: 118.5259 - val_mae: 8.1601
#
# Epoch 00076: val_mae did not improve from 8.14340
# Epoch 77/80
#
# Epoch 00077: LearningRateScheduler reducing learning rate to 0.0001.
# 789/789 - 218s - loss: 99.8232 - mae: 7.7168 - val_loss: 119.5225 - val_mae: 8.2062
#
# Epoch 00077: val_mae did not improve from 8.14340
# Epoch 78/80
#
# Epoch 00078: LearningRateScheduler reducing learning rate to 0.0001.
# 789/789 - 218s - loss: 99.2174 - mae: 7.6861 - val_loss: 118.0310 - val_mae: 8.1278
#
# Epoch 00078: val_mae improved from 8.14340 to 8.12778, saving model to ./ckpts/best_val_inception_80ep.h5
# Epoch 79/80
#
# Epoch 00079: LearningRateScheduler reducing learning rate to 0.0001.
# 789/789 - 218s - loss: 100.5415 - mae: 7.7087 - val_loss: 120.3722 - val_mae: 8.2507
#
# Epoch 00079: val_mae did not improve from 8.12778
# Epoch 80/80
#
# Epoch 00080: LearningRateScheduler reducing learning rate to 0.0001.
# 789/789 - 218s - loss: 99.9290 - mae: 7.6727 - val_loss: 118.9716 - val_mae: 8.1719
#
# Epoch 00080: val_mae did not improve from 8.12778

# %% [markdown]
# ### test

# %%
test_directory = '../input/hdadataset2021/Bone Age Datasets/Bone Age Test Set/Test Set Images/'

df_test = pd.read_csv('../input/hdaproject2021-codes/test.csv')

ids = df_test['id'].values.astype(str)
labels = (df_test['Sex'].values == 'M').astype(float)

# replace ',' with '.' and convert to float
ages_str = df_test['boneage'].values
ages = np.empty_like(ages_str)
for i, item in enumerate(ages_str):
    replaced = item.replace(',','.')
    replaced_float = float(replaced)
    ages[i] = replaced_float
ages = ages.astype(float)

test_ds = tf.data.Dataset.from_tensor_slices((ids, labels, ages))

def read_test_image(image_file, label, age):
    image = tf.io.read_file(test_directory + image_file + '.png')
    image = tf.io.decode_png(image, channels=1)
    return image, [label], [age] #lists are necessary for training the model (otherwise dims are unknown)

test_ds = test_ds.map(read_test_image).map(lambda image,label,age: (normalization_layer(resize_layer(image)), label, age)).cache()
test_ds = test_ds.prefetch(buffer_size=AUTOTUNE)

test_iterator = test_ds.as_numpy_iterator()
N = 200 #number of samples
test_images = np.empty(shape=(N, IMG_SIZE[0], IMG_SIZE[1], 1), dtype=np.float32)
test_labels = np.empty(shape=(N,), dtype=np.float32)
test_ages = np.empty(shape=(N,), dtype=np.float32)
for i, item in enumerate(test_iterator):
    test_images[i] = item[0]
    test_labels[i] = item[1]
    test_ages[i] = item[2]
    
print(test_images.shape)
print(test_labels.shape)
print(test_ages.shape)
# Out:
# (200, 300, 300, 1)
# (200,)
# (200,)

# %%
boneageinception.load_weights('./ckpts/best_val_inception_80ep.h5')

# %%
boneageinception_pred = boneageinception.predict((test_images, test_labels))

# %%
np.mean(np.abs(boneageinception_pred.squeeze() - test_ages.squeeze()))
# Out:
# 6.852223

# %%
boneageinception.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 300, 300, 1) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 149, 149, 41) 369         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 149, 149, 41) 123         conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 149, 149, 41) 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 147, 147, 41) 15129       activation[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 147, 147, 41) 123         conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 147, 147, 41) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 147, 147, 83) 30627       activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 147, 147, 83) 249         conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 147, 147, 83) 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 73, 73, 83)   0           activation_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 73, 73, 104)  8632        max_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 73, 73, 104)  312         conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 73, 73, 104)  0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 71, 71, 249)  233064      activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 71, 71, 249)  747         conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 71, 71, 249)  0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 35, 35, 249)  0           activation_4[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 35, 35, 83)   20667       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 35, 35, 83)   249         conv2d_8[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 35, 35, 83)   0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 35, 35, 62)   15438       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 35, 35, 124)  92628       activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 35, 35, 62)   186         conv2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 35, 35, 124)  372         conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 35, 35, 62)   0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 35, 35, 124)  0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# average_pooling2d (AveragePooli (None, 35, 35, 249)  0           max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 35, 35, 83)   20667       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 35, 35, 83)   128650      activation_6[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 35, 35, 124)  138384      activation_9[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 35, 35, 41)   10209       average_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 35, 35, 83)   249         conv2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 35, 35, 83)   249         conv2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 35, 35, 124)  372         conv2d_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 35, 35, 41)   123         conv2d_11[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 35, 35, 83)   0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 35, 35, 83)   0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 35, 35, 124)  0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 35, 35, 41)   0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# mixed0-0 (Concatenate)          (None, 35, 35, 331)  0           activation_5[0][0]
#                                                                  activation_7[0][0]
#                                                                  activation_10[0][0]
#                                                                  activation_11[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 35, 35, 83)   27473       mixed0-0[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 35, 35, 83)   249         conv2d_15[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 35, 35, 83)   0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 35, 35, 62)   20522       mixed0-0[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 35, 35, 124)  92628       activation_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 35, 35, 62)   186         conv2d_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 35, 35, 124)  372         conv2d_16[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 35, 35, 62)   0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 35, 35, 124)  0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_1 (AveragePoo (None, 35, 35, 331)  0           mixed0-0[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 35, 35, 83)   27473       mixed0-0[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 35, 35, 83)   128650      activation_13[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 35, 35, 124)  138384      activation_16[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 35, 35, 83)   27473       average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 35, 35, 83)   249         conv2d_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 35, 35, 83)   249         conv2d_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 35, 35, 124)  372         conv2d_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 35, 35, 83)   249         conv2d_18[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 35, 35, 83)   0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 35, 35, 83)   0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 35, 35, 124)  0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 35, 35, 83)   0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# mixed1 (Concatenate)            (None, 35, 35, 373)  0           activation_12[0][0]
#                                                                  activation_14[0][0]
#                                                                  activation_17[0][0]
#                                                                  activation_18[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 35, 35, 83)   30959       mixed1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 35, 35, 83)   249         conv2d_22[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 35, 35, 83)   0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 35, 35, 62)   23126       mixed1[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 35, 35, 124)  92628       activation_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 35, 35, 62)   186         conv2d_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 35, 35, 124)  372         conv2d_23[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 35, 35, 62)   0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 35, 35, 124)  0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_2 (AveragePoo (None, 35, 35, 373)  0           mixed1[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 35, 35, 83)   30959       mixed1[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 35, 35, 83)   128650      activation_20[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 35, 35, 124)  138384      activation_23[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 35, 35, 83)   30959       average_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 35, 35, 83)   249         conv2d_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 35, 35, 83)   249         conv2d_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 35, 35, 124)  372         conv2d_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 35, 35, 83)   249         conv2d_25[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 35, 35, 83)   0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 35, 35, 83)   0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 35, 35, 124)  0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 35, 35, 83)   0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# mixed2 (Concatenate)            (None, 35, 35, 373)  0           activation_19[0][0]
#                                                                  activation_21[0][0]
#                                                                  activation_24[0][0]
#                                                                  activation_25[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 35, 35, 83)   30959       mixed2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 35, 35, 83)   249         conv2d_27[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 35, 35, 83)   0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 35, 35, 124)  92628       activation_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 35, 35, 124)  372         conv2d_28[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 35, 35, 124)  0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 17, 17, 499)  1675143     mixed2[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 17, 17, 124)  138384      activation_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 17, 17, 499)  1497        conv2d_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 17, 17, 124)  372         conv2d_29[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 17, 17, 499)  0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 17, 17, 124)  0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 17, 17, 373)  0           mixed2[0][0]
# __________________________________________________________________________________________________
# mixed3 (Concatenate)            (None, 17, 17, 996)  0           activation_26[0][0]
#                                                                  activation_29[0][0]
#                                                                  max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 17, 17, 166)  165336      mixed3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 17, 17, 166)  498         conv2d_34[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 17, 17, 166)  0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 17, 17, 166)  192892      activation_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 17, 17, 166)  498         conv2d_35[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 17, 17, 166)  0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 17, 17, 166)  165336      mixed3[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 17, 17, 166)  192892      activation_35[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 17, 17, 166)  498         conv2d_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 17, 17, 166)  498         conv2d_36[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 17, 17, 166)  0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 17, 17, 166)  0           batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 17, 17, 166)  192892      activation_31[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 17, 17, 166)  192892      activation_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 17, 17, 166)  498         conv2d_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 17, 17, 166)  498         conv2d_37[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 17, 17, 166)  0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 17, 17, 166)  0           batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_3 (AveragePoo (None, 17, 17, 996)  0           mixed3[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 17, 17, 249)  248004      mixed3[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 17, 17, 249)  289338      activation_32[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 17, 17, 249)  289338      activation_37[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 17, 17, 249)  248004      average_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 17, 17, 249)  747         conv2d_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 17, 17, 249)  747         conv2d_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 17, 17, 249)  747         conv2d_38[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 17, 17, 249)  747         conv2d_39[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 17, 17, 249)  0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 17, 17, 249)  0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 17, 17, 249)  0           batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 17, 17, 249)  0           batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# mixed4 (Concatenate)            (None, 17, 17, 996)  0           activation_30[0][0]
#                                                                  activation_33[0][0]
#                                                                  activation_38[0][0]
#                                                                  activation_39[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 17, 17, 208)  207168      mixed4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 17, 17, 208)  624         conv2d_44[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 17, 17, 208)  0           batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 17, 17, 208)  302848      activation_44[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 17, 17, 208)  624         conv2d_45[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 17, 17, 208)  0           batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 17, 17, 208)  207168      mixed4[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 17, 17, 208)  302848      activation_45[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 17, 17, 208)  624         conv2d_41[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 17, 17, 208)  624         conv2d_46[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 17, 17, 208)  0           batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 17, 17, 208)  0           batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 17, 17, 208)  302848      activation_41[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 17, 17, 208)  302848      activation_46[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 17, 17, 208)  624         conv2d_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, 17, 17, 208)  624         conv2d_47[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 17, 17, 208)  0           batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 17, 17, 208)  0           batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_4 (AveragePoo (None, 17, 17, 996)  0           mixed4[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 17, 17, 249)  248004      mixed4[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 17, 17, 249)  362544      activation_42[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 17, 17, 249)  362544      activation_47[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 17, 17, 249)  248004      average_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 17, 17, 249)  747         conv2d_40[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 17, 17, 249)  747         conv2d_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 17, 17, 249)  747         conv2d_48[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, 17, 17, 249)  747         conv2d_49[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 17, 17, 249)  0           batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 17, 17, 249)  0           batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 17, 17, 249)  0           batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, 17, 17, 249)  0           batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# mixed5-0 (Concatenate)          (None, 17, 17, 996)  0           activation_40[0][0]
#                                                                  activation_43[0][0]
#                                                                  activation_48[0][0]
#                                                                  activation_49[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 17, 17, 208)  207168      mixed5-0[0][0]
# __________________________________________________________________________________________________
# batch_normalization_54 (BatchNo (None, 17, 17, 208)  624         conv2d_54[0][0]
# __________________________________________________________________________________________________
# activation_54 (Activation)      (None, 17, 17, 208)  0           batch_normalization_54[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 17, 17, 208)  302848      activation_54[0][0]
# __________________________________________________________________________________________________
# batch_normalization_55 (BatchNo (None, 17, 17, 208)  624         conv2d_55[0][0]
# __________________________________________________________________________________________________
# activation_55 (Activation)      (None, 17, 17, 208)  0           batch_normalization_55[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 17, 17, 208)  207168      mixed5-0[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 17, 17, 208)  302848      activation_55[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 17, 17, 208)  624         conv2d_51[0][0]
# __________________________________________________________________________________________________
# batch_normalization_56 (BatchNo (None, 17, 17, 208)  624         conv2d_56[0][0]
# __________________________________________________________________________________________________
# activation_51 (Activation)      (None, 17, 17, 208)  0           batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# activation_56 (Activation)      (None, 17, 17, 208)  0           batch_normalization_56[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 17, 17, 208)  302848      activation_51[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, 17, 17, 208)  302848      activation_56[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, 17, 17, 208)  624         conv2d_52[0][0]
# __________________________________________________________________________________________________
# batch_normalization_57 (BatchNo (None, 17, 17, 208)  624         conv2d_57[0][0]
# __________________________________________________________________________________________________
# activation_52 (Activation)      (None, 17, 17, 208)  0           batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# activation_57 (Activation)      (None, 17, 17, 208)  0           batch_normalization_57[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_5 (AveragePoo (None, 17, 17, 996)  0           mixed5-0[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 17, 17, 249)  248004      mixed5-0[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 17, 17, 249)  362544      activation_52[0][0]
# __________________________________________________________________________________________________
# conv2d_58 (Conv2D)              (None, 17, 17, 249)  362544      activation_57[0][0]
# __________________________________________________________________________________________________
# conv2d_59 (Conv2D)              (None, 17, 17, 249)  248004      average_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, 17, 17, 249)  747         conv2d_50[0][0]
# __________________________________________________________________________________________________
# batch_normalization_53 (BatchNo (None, 17, 17, 249)  747         conv2d_53[0][0]
# __________________________________________________________________________________________________
# batch_normalization_58 (BatchNo (None, 17, 17, 249)  747         conv2d_58[0][0]
# __________________________________________________________________________________________________
# batch_normalization_59 (BatchNo (None, 17, 17, 249)  747         conv2d_59[0][0]
# __________________________________________________________________________________________________
# activation_50 (Activation)      (None, 17, 17, 249)  0           batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# activation_53 (Activation)      (None, 17, 17, 249)  0           batch_normalization_53[0][0]
# __________________________________________________________________________________________________
# activation_58 (Activation)      (None, 17, 17, 249)  0           batch_normalization_58[0][0]
# __________________________________________________________________________________________________
# activation_59 (Activation)      (None, 17, 17, 249)  0           batch_normalization_59[0][0]
# __________________________________________________________________________________________________
# mixed5-1 (Concatenate)          (None, 17, 17, 996)  0           activation_50[0][0]
#                                                                  activation_53[0][0]
#                                                                  activation_58[0][0]
#                                                                  activation_59[0][0]
# __________________________________________________________________________________________________
# conv2d_64 (Conv2D)              (None, 17, 17, 208)  207168      mixed5-1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_64 (BatchNo (None, 17, 17, 208)  624         conv2d_64[0][0]
# __________________________________________________________________________________________________
# activation_64 (Activation)      (None, 17, 17, 208)  0           batch_normalization_64[0][0]
# __________________________________________________________________________________________________
# conv2d_65 (Conv2D)              (None, 17, 17, 208)  302848      activation_64[0][0]
# __________________________________________________________________________________________________
# batch_normalization_65 (BatchNo (None, 17, 17, 208)  624         conv2d_65[0][0]
# __________________________________________________________________________________________________
# activation_65 (Activation)      (None, 17, 17, 208)  0           batch_normalization_65[0][0]
# __________________________________________________________________________________________________
# conv2d_61 (Conv2D)              (None, 17, 17, 208)  207168      mixed5-1[0][0]
# __________________________________________________________________________________________________
# conv2d_66 (Conv2D)              (None, 17, 17, 208)  302848      activation_65[0][0]
# __________________________________________________________________________________________________
# batch_normalization_61 (BatchNo (None, 17, 17, 208)  624         conv2d_61[0][0]
# __________________________________________________________________________________________________
# batch_normalization_66 (BatchNo (None, 17, 17, 208)  624         conv2d_66[0][0]
# __________________________________________________________________________________________________
# activation_61 (Activation)      (None, 17, 17, 208)  0           batch_normalization_61[0][0]
# __________________________________________________________________________________________________
# activation_66 (Activation)      (None, 17, 17, 208)  0           batch_normalization_66[0][0]
# __________________________________________________________________________________________________
# conv2d_62 (Conv2D)              (None, 17, 17, 208)  302848      activation_61[0][0]
# __________________________________________________________________________________________________
# conv2d_67 (Conv2D)              (None, 17, 17, 208)  302848      activation_66[0][0]
# __________________________________________________________________________________________________
# batch_normalization_62 (BatchNo (None, 17, 17, 208)  624         conv2d_62[0][0]
# __________________________________________________________________________________________________
# batch_normalization_67 (BatchNo (None, 17, 17, 208)  624         conv2d_67[0][0]
# __________________________________________________________________________________________________
# activation_62 (Activation)      (None, 17, 17, 208)  0           batch_normalization_62[0][0]
# __________________________________________________________________________________________________
# activation_67 (Activation)      (None, 17, 17, 208)  0           batch_normalization_67[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_6 (AveragePoo (None, 17, 17, 996)  0           mixed5-1[0][0]
# __________________________________________________________________________________________________
# conv2d_60 (Conv2D)              (None, 17, 17, 249)  248004      mixed5-1[0][0]
# __________________________________________________________________________________________________
# conv2d_63 (Conv2D)              (None, 17, 17, 249)  362544      activation_62[0][0]
# __________________________________________________________________________________________________
# conv2d_68 (Conv2D)              (None, 17, 17, 249)  362544      activation_67[0][0]
# __________________________________________________________________________________________________
# conv2d_69 (Conv2D)              (None, 17, 17, 249)  248004      average_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_60 (BatchNo (None, 17, 17, 249)  747         conv2d_60[0][0]
# __________________________________________________________________________________________________
# batch_normalization_63 (BatchNo (None, 17, 17, 249)  747         conv2d_63[0][0]
# __________________________________________________________________________________________________
# batch_normalization_68 (BatchNo (None, 17, 17, 249)  747         conv2d_68[0][0]
# __________________________________________________________________________________________________
# batch_normalization_69 (BatchNo (None, 17, 17, 249)  747         conv2d_69[0][0]
# __________________________________________________________________________________________________
# activation_60 (Activation)      (None, 17, 17, 249)  0           batch_normalization_60[0][0]
# __________________________________________________________________________________________________
# activation_63 (Activation)      (None, 17, 17, 249)  0           batch_normalization_63[0][0]
# __________________________________________________________________________________________________
# activation_68 (Activation)      (None, 17, 17, 249)  0           batch_normalization_68[0][0]
# __________________________________________________________________________________________________
# activation_69 (Activation)      (None, 17, 17, 249)  0           batch_normalization_69[0][0]
# __________________________________________________________________________________________________
# mixed5-2 (Concatenate)          (None, 17, 17, 996)  0           activation_60[0][0]
#                                                                  activation_63[0][0]
#                                                                  activation_68[0][0]
#                                                                  activation_69[0][0]
# __________________________________________________________________________________________________
# ...
# __________________________________________________________________________________________________
# mixed8_0 (Concatenate)          (None, 8, 8, 998)    0           activation_108[0][0]
#                                                                  activation_109[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 8, 8, 998)    0           activation_112[0][0]
#                                                                  activation_113[0][0]
# __________________________________________________________________________________________________
# activation_114 (Activation)     (None, 8, 8, 249)    0           batch_normalization_114[0][0]
# __________________________________________________________________________________________________
# mixed8-0 (Concatenate)          (None, 8, 8, 2661)   0           activation_106[0][0]
#                                                                  mixed8_0[0][0]
#                                                                  concatenate[0][0]
#                                                                  activation_114[0][0]
# __________________________________________________________________________________________________
# conv2d_119 (Conv2D)             (None, 8, 8, 582)    1548702     mixed8-0[0][0]
# __________________________________________________________________________________________________
# batch_normalization_119 (BatchN (None, 8, 8, 582)    1746        conv2d_119[0][0]
# __________________________________________________________________________________________________
# activation_119 (Activation)     (None, 8, 8, 582)    0           batch_normalization_119[0][0]
# __________________________________________________________________________________________________
# conv2d_116 (Conv2D)             (None, 8, 8, 499)    1327839     mixed8-0[0][0]
# __________________________________________________________________________________________________
# conv2d_120 (Conv2D)             (None, 8, 8, 499)    2613762     activation_119[0][0]
# __________________________________________________________________________________________________
# batch_normalization_116 (BatchN (None, 8, 8, 499)    1497        conv2d_116[0][0]
# __________________________________________________________________________________________________
# batch_normalization_120 (BatchN (None, 8, 8, 499)    1497        conv2d_120[0][0]
# __________________________________________________________________________________________________
# activation_116 (Activation)     (None, 8, 8, 499)    0           batch_normalization_116[0][0]
# __________________________________________________________________________________________________
# activation_120 (Activation)     (None, 8, 8, 499)    0           batch_normalization_120[0][0]
# __________________________________________________________________________________________________
# conv2d_117 (Conv2D)             (None, 8, 8, 499)    747003      activation_116[0][0]
# __________________________________________________________________________________________________
# conv2d_118 (Conv2D)             (None, 8, 8, 499)    747003      activation_116[0][0]
# __________________________________________________________________________________________________
# conv2d_121 (Conv2D)             (None, 8, 8, 499)    747003      activation_120[0][0]
# __________________________________________________________________________________________________
# conv2d_122 (Conv2D)             (None, 8, 8, 499)    747003      activation_120[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_11 (AveragePo (None, 8, 8, 2661)   0           mixed8-0[0][0]
# __________________________________________________________________________________________________
# conv2d_115 (Conv2D)             (None, 8, 8, 416)    1106976     mixed8-0[0][0]
# __________________________________________________________________________________________________
# batch_normalization_117 (BatchN (None, 8, 8, 499)    1497        conv2d_117[0][0]
# __________________________________________________________________________________________________
# batch_normalization_118 (BatchN (None, 8, 8, 499)    1497        conv2d_118[0][0]
# __________________________________________________________________________________________________
# batch_normalization_121 (BatchN (None, 8, 8, 499)    1497        conv2d_121[0][0]
# __________________________________________________________________________________________________
# batch_normalization_122 (BatchN (None, 8, 8, 499)    1497        conv2d_122[0][0]
# __________________________________________________________________________________________________
# conv2d_123 (Conv2D)             (None, 8, 8, 249)    662589      average_pooling2d_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_115 (BatchN (None, 8, 8, 416)    1248        conv2d_115[0][0]
# __________________________________________________________________________________________________
# activation_117 (Activation)     (None, 8, 8, 499)    0           batch_normalization_117[0][0]
# __________________________________________________________________________________________________
# activation_118 (Activation)     (None, 8, 8, 499)    0           batch_normalization_118[0][0]
# __________________________________________________________________________________________________
# activation_121 (Activation)     (None, 8, 8, 499)    0           batch_normalization_121[0][0]
# __________________________________________________________________________________________________
# activation_122 (Activation)     (None, 8, 8, 499)    0           batch_normalization_122[0][0]
# __________________________________________________________________________________________________
# batch_normalization_123 (BatchN (None, 8, 8, 249)    747         conv2d_123[0][0]
# __________________________________________________________________________________________________
# activation_115 (Activation)     (None, 8, 8, 416)    0           batch_normalization_115[0][0]
# __________________________________________________________________________________________________
# mixed8_1 (Concatenate)          (None, 8, 8, 998)    0           activation_117[0][0]
#                                                                  activation_118[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 8, 8, 998)    0           activation_121[0][0]
#                                                                  activation_122[0][0]
# __________________________________________________________________________________________________
# activation_123 (Activation)     (None, 8, 8, 249)    0           batch_normalization_123[0][0]
# __________________________________________________________________________________________________
# mixed8-1 (Concatenate)          (None, 8, 8, 2661)   0           activation_115[0][0]
#                                                                  mixed8_1[0][0]
#                                                                  concatenate_1[0][0]
#                                                                  activation_123[0][0]
# __________________________________________________________________________________________________
# conv2d_128 (Conv2D)             (None, 8, 8, 582)    1548702     mixed8-1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_128 (BatchN (None, 8, 8, 582)    1746        conv2d_128[0][0]
# __________________________________________________________________________________________________
# activation_128 (Activation)     (None, 8, 8, 582)    0           batch_normalization_128[0][0]
# __________________________________________________________________________________________________
# conv2d_125 (Conv2D)             (None, 8, 8, 499)    1327839     mixed8-1[0][0]
# __________________________________________________________________________________________________
# conv2d_129 (Conv2D)             (None, 8, 8, 499)    2613762     activation_128[0][0]
# __________________________________________________________________________________________________
# batch_normalization_125 (BatchN (None, 8, 8, 499)    1497        conv2d_125[0][0]
# __________________________________________________________________________________________________
# batch_normalization_129 (BatchN (None, 8, 8, 499)    1497        conv2d_129[0][0]
# __________________________________________________________________________________________________
# activation_125 (Activation)     (None, 8, 8, 499)    0           batch_normalization_125[0][0]
# __________________________________________________________________________________________________
# activation_129 (Activation)     (None, 8, 8, 499)    0           batch_normalization_129[0][0]
# __________________________________________________________________________________________________
# conv2d_126 (Conv2D)             (None, 8, 8, 499)    747003      activation_125[0][0]
# __________________________________________________________________________________________________
# conv2d_127 (Conv2D)             (None, 8, 8, 499)    747003      activation_125[0][0]
# __________________________________________________________________________________________________
# conv2d_130 (Conv2D)             (None, 8, 8, 499)    747003      activation_129[0][0]
# __________________________________________________________________________________________________
# conv2d_131 (Conv2D)             (None, 8, 8, 499)    747003      activation_129[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_12 (AveragePo (None, 8, 8, 2661)   0           mixed8-1[0][0]
# __________________________________________________________________________________________________
# conv2d_124 (Conv2D)             (None, 8, 8, 416)    1106976     mixed8-1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_126 (BatchN (None, 8, 8, 499)    1497        conv2d_126[0][0]
# __________________________________________________________________________________________________
# batch_normalization_127 (BatchN (None, 8, 8, 499)    1497        conv2d_127[0][0]
# __________________________________________________________________________________________________
# batch_normalization_130 (BatchN (None, 8, 8, 499)    1497        conv2d_130[0][0]
# __________________________________________________________________________________________________
# batch_normalization_131 (BatchN (None, 8, 8, 499)    1497        conv2d_131[0][0]
# __________________________________________________________________________________________________
# conv2d_132 (Conv2D)             (None, 8, 8, 249)    662589      average_pooling2d_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_124 (BatchN (None, 8, 8, 416)    1248        conv2d_124[0][0]
# __________________________________________________________________________________________________
# activation_126 (Activation)     (None, 8, 8, 499)    0           batch_normalization_126[0][0]
# __________________________________________________________________________________________________
# activation_127 (Activation)     (None, 8, 8, 499)    0           batch_normalization_127[0][0]
# __________________________________________________________________________________________________
# activation_130 (Activation)     (None, 8, 8, 499)    0           batch_normalization_130[0][0]
# __________________________________________________________________________________________________
# activation_131 (Activation)     (None, 8, 8, 499)    0           batch_normalization_131[0][0]
# __________________________________________________________________________________________________
# batch_normalization_132 (BatchN (None, 8, 8, 249)    747         conv2d_132[0][0]
# __________________________________________________________________________________________________
# activation_124 (Activation)     (None, 8, 8, 416)    0           batch_normalization_124[0][0]
# __________________________________________________________________________________________________
# mixed8_2 (Concatenate)          (None, 8, 8, 998)    0           activation_126[0][0]
#                                                                  activation_127[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 8, 8, 998)    0           activation_130[0][0]
#                                                                  activation_131[0][0]
# __________________________________________________________________________________________________
# activation_132 (Activation)     (None, 8, 8, 249)    0           batch_normalization_132[0][0]
# __________________________________________________________________________________________________
# mixed8-2 (Concatenate)          (None, 8, 8, 2661)   0           activation_124[0][0]
#                                                                  mixed8_2[0][0]
#                                                                  concatenate_2[0][0]
#                                                                  activation_132[0][0]
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, 1)]          0
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 2661)         0           mixed8-2[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 100)          200         input_2[0][0]
# __________________________________________________________________________________________________
# gender_and_feat._concat (Concat (None, 2761)         0           global_average_pooling2d[0][0]
#                                                                  dense[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 1)            2762        gender_and_feat._concat[0][0]
# ==================================================================================================
# Total params: 55,551,791
# Trainable params: 55,485,155
# Non-trainable params: 66,636
# __________________________________________________________________________________________________
# None
