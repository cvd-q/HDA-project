# %% [markdown]
# # Data preprocessing

# %%
import pandas as pd
import tensorflow as tf
import numpy as np
from tensorflow.python.keras.engine import data_adapter
from tensorflow.keras import backend as K

# %%
train_csv_directory = '../hdadataset2021/Bone Age Datasets/Bone Age Training Set/'
train_directory = '../hdadataset2021/Bone Age Datasets/Bone Age Training Set/boneage-training-dataset/'
df_train = pd.read_csv(train_csv_directory + 'train.csv')

val_csv_directory = '../hdadataset2021/'
val_directory = '../hdadataset2021/boneage-validation-dataset/'
df_val = pd.read_csv(val_csv_directory + 'Validation Dataset.csv')

# %%
ids = df_train['id'].values.astype(str)
labels = df_train['male'].values.astype(float)
ages = df_train['boneage'].values.astype(float)
train_ds = tf.data.Dataset.from_tensor_slices((ids, labels, ages))


ids = df_val['Image ID'].values.astype(str)
labels = df_val['male'].values.astype(float)
ages = df_val['Bone Age (months)'].values.astype(float)
val_ds = tf.data.Dataset.from_tensor_slices((ids, labels, ages))

IMG_SIZE = (300, 300, 1)
BATCH_SIZE = 16

# %%
def read_train_image(image_file, label, age):
    image = tf.io.read_file(train_directory + image_file+ '.png')
    image = tf.io.decode_png(image, channels=1)
    return image, [label], [age] #lists are necessary for training the model (otherwise dims are unknown)

def read_val_image(image_file, label, age):
    image = tf.io.read_file(val_directory + image_file + '.png')
    image = tf.io.decode_png(image, channels=1)
    return image, [label], [age] #lists are necessary for training the model (otherwise dims are unknown)

resize_layer = tf.keras.layers.experimental.preprocessing.Resizing(height=IMG_SIZE[0], width=IMG_SIZE[1])
normalization_layer = tf.keras.layers.experimental.preprocessing.Rescaling(1/255.)
zoom_layer = tf.keras.layers.experimental.preprocessing.RandomZoom(height_factor=(0.2,-0.3),
                                                                   width_factor=(0.2,-0.3),
                                                                  fill_mode='constant')
flip_layer = tf.keras.layers.experimental.preprocessing.RandomFlip(mode='horizontal')

def brightness_function(image):
    image = tf.image.random_brightness(image, max_delta=0.3)
    image = tf.math.maximum(image, 0.)
    image = tf.math.minimum(image, 1.)
    return image

def augment(image, label, age):
    # data augmentation here
    image = zoom_layer(image)
    image = flip_layer(image)
    image = brightness_function(image)
    return image, label, age

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE #tf.data.AUTOTUNE
train_ds = train_ds.map(read_train_image).map(lambda image,label,age: (normalization_layer((resize_layer(image))), label, age)).cache('./train_cache_300')
train_ds = train_ds.shuffle(buffer_size=1000).batch(BATCH_SIZE).map(augment,num_parallel_calls=AUTOTUNE)
train_ds = train_ds.prefetch(buffer_size=AUTOTUNE)

val_ds = val_ds.map(read_val_image).map(lambda image,label,age: (normalization_layer(resize_layer(image)), label, age)).cache('./val_cache_300')
val_ds = val_ds.prefetch(buffer_size=AUTOTUNE).batch(BATCH_SIZE)

# %%
#image = list(val_ds.take(1).as_numpy_iterator())[0][0][1]

# %%
# %matplotlib inline
#import matplotlib.pyplot as plt
#_ = plt.imshow(image)

# %% [markdown]
# # Inception Model

# %%
class BoneAgeInception(tf.keras.Model):  
    def __init__(self, gender=True):
        super(BoneAgeInception, self).__init__()
        
        model = tf.keras.applications.InceptionV3(
                                include_top=False,
                                weights=None,
                                input_shape=IMG_SIZE)
        
        
        
        #dense_model = DenseNet()
        
        #last_conv=relu_final_blk
        #for layer in dense_model.model.layers:
            #global_average
            #if layer.name.startswith('global_max'):
                #model_global_max = layer.output
                
        
        if gender:
            initializer = tf.keras.initializers.GlorotNormal()
            gender_input = tf.keras.Input(shape=(1))
            gender_output = tf.keras.layers.Dense(100, activation='relu', kernel_initializer=initializer)(gender_input)
            
            model_global_avg = tf.keras.layers.GlobalAveragePooling2D()(model.output)
            
            concat_output = tf.keras.layers.Concatenate(name='gender_and_feat._concat')([model_global_avg, gender_output])
            
            #dense_output = tf.keras.layers.Dense(2000,activation='relu', kernel_regularizer='l2', kernel_initializer=initializer)(concat_output)
            
            overall_output = tf.keras.layers.Dense(1,activation='relu', kernel_regularizer='l2', kernel_initializer=initializer)(concat_output)
            
            self.model = tf.keras.Model(inputs=[model.input, gender_input], outputs = overall_output)
        else:
            pass #COMPLETE!
                
        
        
    def call(self, x, training=False):
        imgs, labels = x
        
        y = self.model([imgs, labels],training)
       
        return y

    def train_step(self, data):
        
        data = data_adapter.expand_1d(data)
        imgs, labels, ages = data
        
        with tf.GradientTape() as tape:
            y_pred = self((imgs, labels), training=True)  # Forward pass

            loss = self.compiled_loss(ages, y_pred)

        trainable_vars = self.trainable_variables
        gradients = tape.gradient(loss, trainable_vars)
        
        # Update weights
        self.optimizer.apply_gradients(zip(gradients, trainable_vars))

        self.compiled_metrics.update_state(ages, y_pred)
        _dict = {m.name: m.result() for m in self.metrics}
        
        return _dict

    def test_step(self, data):
        
        data = data_adapter.expand_1d(data)
        imgs, labels, ages = data

        y_pred = self((imgs, labels), training=False)  # Forward pass

        loss = self.compiled_loss(ages, y_pred)

        self.compiled_metrics.update_state(ages, y_pred)
        _dict = {m.name: m.result() for m in self.metrics}
        
        return _dict
    
    def summary(self):
        print(self.model.summary())

# %%
bonageinception = BoneAgeInception()
ckpt_callback = tf.keras.callbacks.ModelCheckpoint(
                filepath='./ckpts/inception/best_val_inception_100ep.h5', monitor='val_mae', verbose=1, save_best_only=True,
                save_weights_only=True, mode='min')

def scheduler(epoch, lr):
    if epoch < 20:
        return lr
    elif epoch < 40:
        return 1e-3
    elif epoch < 60:
        return 1e-4
    else:
        return 1e-5

lr_scheduler_callback = tf.keras.callbacks.LearningRateScheduler(scheduler, verbose=1)

optimizer = tf.keras.optimizers.Adam(learning_rate=1e-2)
metric = tf.keras.metrics.MeanAbsoluteError()
bonageinception.compile(optimizer=optimizer, loss='mse', metrics=['mae'])

bonageinception.fit(train_ds, validation_data=val_ds,callbacks = [ckpt_callback,lr_scheduler_callback],
                    epochs=100, verbose=2)
# Out:
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# Epoch 1/100
# WARNING:tensorflow:Layer bone_age_inception is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because its dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
#
# Epoch 00001: val_mae improved from inf to 37.20489, saving model to ./ckpts/inception/best_val_inception_100ep.h5
# 789/789 - 109s - loss: 1644.1091 - mae: 31.6735 - val_loss: 2010.2118 - val_mae: 37.2049
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# Epoch 2/100
#
# Epoch 00002: val_mae improved from 37.20489 to 32.90630, saving model to ./ckpts/inception/best_val_inception_100ep.h5
# 789/789 - 108s - loss: 1568.6165 - mae: 31.5525 - val_loss: 1888.4045 - val_mae: 32.9063
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# Epoch 3/100
#
# Epoch 00003: val_mae did not improve from 32.90630
# 789/789 - 107s - loss: 1456.4189 - mae: 30.2332 - val_loss: 1975.4670 - val_mae: 34.8400
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# Epoch 4/100
#
# Epoch 00004: val_mae did not improve from 32.90630
# 789/789 - 107s - loss: 1401.6809 - mae: 29.4712 - val_loss: 1997.5519 - val_mae: 35.0608
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# Epoch 5/100
#
# Epoch 00005: val_mae improved from 32.90630 to 22.09131, saving model to ./ckpts/inception/best_val_inception_100ep.h5
# 789/789 - 107s - loss: 992.5587 - mae: 23.5791 - val_loss: 1078.5253 - val_mae: 22.0913
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# Epoch 6/100
#
# Epoch 00006: val_mae did not improve from 22.09131
# 789/789 - 107s - loss: 728.6285 - mae: 19.9010 - val_loss: 2591.2087 - val_mae: 46.4254
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# Epoch 7/100
#
# Epoch 00007: val_mae improved from 22.09131 to 17.15582, saving model to ./ckpts/inception/best_val_inception_100ep.h5
# 789/789 - 107s - loss: 576.2460 - mae: 17.8939 - val_loss: 620.9033 - val_mae: 17.1558
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# Epoch 8/100
#
# Epoch 00008: val_mae did not improve from 17.15582
# 789/789 - 107s - loss: 534.4473 - mae: 17.2016 - val_loss: 2582.7754 - val_mae: 46.7360
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# Epoch 9/100
#
# Epoch 00009: val_mae improved from 17.15582 to 13.95114, saving model to ./ckpts/inception/best_val_inception_100ep.h5
# 789/789 - 107s - loss: 422.3806 - mae: 15.3397 - val_loss: 355.6199 - val_mae: 13.9511
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# Epoch 10/100
#
# Epoch 00010: val_mae improved from 13.95114 to 13.55961, saving model to ./ckpts/inception/best_val_inception_100ep.h5
# 789/789 - 107s - loss: 396.5343 - mae: 14.8542 - val_loss: 339.8264 - val_mae: 13.5596
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# Epoch 11/100
#
# Epoch 00011: val_mae improved from 13.55961 to 10.83374, saving model to ./ckpts/inception/best_val_inception_100ep.h5
# 789/789 - 107s - loss: 365.4644 - mae: 14.0580 - val_loss: 226.5202 - val_mae: 10.8337
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# Epoch 12/100
#
# Epoch 00012: val_mae did not improve from 10.83374
# 789/789 - 107s - loss: 312.5421 - mae: 12.9868 - val_loss: 366.9751 - val_mae: 13.3437
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# Epoch 13/100
#
# Epoch 00013: val_mae did not improve from 10.83374
# 789/789 - 107s - loss: 307.9493 - mae: 12.8993 - val_loss: 303.2206 - val_mae: 12.9264
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# Epoch 14/100
#
# Epoch 00014: val_mae improved from 10.83374 to 10.74565, saving model to ./ckpts/inception/best_val_inception_100ep.h5
# 789/789 - 108s - loss: 269.4201 - mae: 12.2354 - val_loss: 222.6579 - val_mae: 10.7456
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# Epoch 15/100
#
# Epoch 00015: val_mae did not improve from 10.74565
# 789/789 - 107s - loss: 289.3442 - mae: 12.4490 - val_loss: 280.8900 - val_mae: 11.4731
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# Epoch 16/100
#
# Epoch 00016: val_mae did not improve from 10.74565
# 789/789 - 107s - loss: 261.6823 - mae: 11.9840 - val_loss: 213.1712 - val_mae: 10.9763
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# Epoch 17/100
#
# Epoch 00017: val_mae did not improve from 10.74565
# 789/789 - 107s - loss: 252.3401 - mae: 11.6485 - val_loss: 609.5135 - val_mae: 21.3230
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# Epoch 18/100
#
# Epoch 00018: val_mae did not improve from 10.74565
# 789/789 - 107s - loss: 222.1757 - mae: 11.1364 - val_loss: 256.5451 - val_mae: 12.7157
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# Epoch 19/100
#
# Epoch 00019: val_mae did not improve from 10.74565
# 789/789 - 107s - loss: 238.1939 - mae: 11.2700 - val_loss: 290.8210 - val_mae: 13.5100
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# Epoch 20/100
#
# Epoch 00020: val_mae improved from 10.74565 to 9.96640, saving model to ./ckpts/inception/best_val_inception_100ep.h5
# 789/789 - 108s - loss: 216.5386 - mae: 10.9613 - val_loss: 189.6245 - val_mae: 9.9664
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 21/100
#
# Epoch 00021: val_mae improved from 9.96640 to 9.10765, saving model to ./ckpts/inception/best_val_inception_100ep.h5
# 789/789 - 108s - loss: 190.1342 - mae: 9.9163 - val_loss: 142.2745 - val_mae: 9.1077
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 22/100
#
# Epoch 00022: val_mae improved from 9.10765 to 8.77501, saving model to ./ckpts/inception/best_val_inception_100ep.h5
# 789/789 - 108s - loss: 176.8091 - mae: 9.6156 - val_loss: 134.5602 - val_mae: 8.7750
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 23/100
#
# Epoch 00023: val_mae did not improve from 8.77501
# 789/789 - 107s - loss: 163.3579 - mae: 9.3418 - val_loss: 133.9805 - val_mae: 8.8376
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 24/100
#
# Epoch 00024: val_mae did not improve from 8.77501
# 789/789 - 107s - loss: 165.9494 - mae: 9.4207 - val_loss: 142.9508 - val_mae: 9.0963
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 25/100
#
# Epoch 00025: val_mae improved from 8.77501 to 8.72062, saving model to ./ckpts/inception/best_val_inception_100ep.h5
# 789/789 - 108s - loss: 171.5298 - mae: 9.4717 - val_loss: 130.2170 - val_mae: 8.7206
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 26/100
#
# Epoch 00026: val_mae did not improve from 8.72062
# 789/789 - 107s - loss: 166.4366 - mae: 9.3830 - val_loss: 135.4586 - val_mae: 8.7728
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 27/100
#
# Epoch 00027: val_mae did not improve from 8.72062
# 789/789 - 107s - loss: 155.4603 - mae: 9.2066 - val_loss: 133.6289 - val_mae: 8.7666
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 28/100
#
# Epoch 00028: val_mae improved from 8.72062 to 8.64148, saving model to ./ckpts/inception/best_val_inception_100ep.h5
# 789/789 - 108s - loss: 161.2080 - mae: 9.2458 - val_loss: 131.5206 - val_mae: 8.6415
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 29/100
#
# Epoch 00029: val_mae did not improve from 8.64148
# 789/789 - 107s - loss: 154.4742 - mae: 9.1132 - val_loss: 133.3424 - val_mae: 8.8165
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 30/100
#
# Epoch 00030: val_mae did not improve from 8.64148
# 789/789 - 107s - loss: 158.6036 - mae: 9.1657 - val_loss: 130.3746 - val_mae: 8.6975
#
# Epoch 00031: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 31/100
#
# Epoch 00031: val_mae improved from 8.64148 to 8.49439, saving model to ./ckpts/inception/best_val_inception_100ep.h5
# 789/789 - 108s - loss: 166.0214 - mae: 9.2840 - val_loss: 125.8063 - val_mae: 8.4944
#
# Epoch 00032: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 32/100
#
# Epoch 00032: val_mae did not improve from 8.49439
# 789/789 - 107s - loss: 161.1166 - mae: 9.1507 - val_loss: 126.3202 - val_mae: 8.5078
#
# Epoch 00033: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 33/100
#
# Epoch 00033: val_mae improved from 8.49439 to 8.47346, saving model to ./ckpts/inception/best_val_inception_100ep.h5
# 789/789 - 108s - loss: 177.7485 - mae: 9.3715 - val_loss: 125.5531 - val_mae: 8.4735
#
# Epoch 00034: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 34/100
#
# Epoch 00034: val_mae did not improve from 8.47346
# 789/789 - 107s - loss: 156.4612 - mae: 9.0601 - val_loss: 131.6930 - val_mae: 8.8353
#
# Epoch 00035: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 35/100
#
# Epoch 00035: val_mae did not improve from 8.47346
# 789/789 - 107s - loss: 161.2124 - mae: 9.1412 - val_loss: 139.1714 - val_mae: 9.0768
#
# Epoch 00036: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 36/100
#
# Epoch 00036: val_mae did not improve from 8.47346
# 789/789 - 107s - loss: 151.9722 - mae: 9.0198 - val_loss: 127.5847 - val_mae: 8.5594
#
# Epoch 00037: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 37/100
#
# Epoch 00037: val_mae did not improve from 8.47346
# 789/789 - 107s - loss: 156.0447 - mae: 9.0068 - val_loss: 125.7366 - val_mae: 8.5980
#
# Epoch 00038: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 38/100
#
# Epoch 00038: val_mae improved from 8.47346 to 8.38607, saving model to ./ckpts/inception/best_val_inception_100ep.h5
# 789/789 - 108s - loss: 146.6629 - mae: 8.8619 - val_loss: 121.5568 - val_mae: 8.3861
#
# Epoch 00039: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 39/100
#
# Epoch 00039: val_mae did not improve from 8.38607
# 789/789 - 107s - loss: 162.2035 - mae: 9.1057 - val_loss: 122.7505 - val_mae: 8.4284
#
# Epoch 00040: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 40/100
#
# Epoch 00040: val_mae did not improve from 8.38607
# 789/789 - 107s - loss: 155.9690 - mae: 8.9643 - val_loss: 122.6177 - val_mae: 8.4562
#
# Epoch 00041: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 41/100
#
# Epoch 00041: val_mae did not improve from 8.38607
# 789/789 - 107s - loss: 148.6696 - mae: 8.7837 - val_loss: 120.9424 - val_mae: 8.4044
#
# Epoch 00042: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 42/100
#
# Epoch 00042: val_mae did not improve from 8.38607
# 789/789 - 107s - loss: 142.1691 - mae: 8.7394 - val_loss: 123.6360 - val_mae: 8.5291
#
# Epoch 00043: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 43/100
#
# Epoch 00043: val_mae did not improve from 8.38607
# 789/789 - 107s - loss: 145.7247 - mae: 8.7290 - val_loss: 121.0155 - val_mae: 8.4062
#
# Epoch 00044: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 44/100
#
# Epoch 00044: val_mae improved from 8.38607 to 8.36688, saving model to ./ckpts/inception/best_val_inception_100ep.h5
# 789/789 - 108s - loss: 151.7301 - mae: 8.8500 - val_loss: 119.8948 - val_mae: 8.3669
#
# Epoch 00045: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 45/100
#
# Epoch 00045: val_mae did not improve from 8.36688
# 789/789 - 107s - loss: 146.2302 - mae: 8.7390 - val_loss: 120.0594 - val_mae: 8.3817
#
# Epoch 00046: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 46/100
#
# Epoch 00046: val_mae did not improve from 8.36688
# 789/789 - 107s - loss: 150.7802 - mae: 8.8269 - val_loss: 122.0855 - val_mae: 8.4741
#
# Epoch 00047: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 47/100
#
# Epoch 00047: val_mae did not improve from 8.36688
# 789/789 - 107s - loss: 148.6254 - mae: 8.7780 - val_loss: 122.8332 - val_mae: 8.5120
#
# Epoch 00048: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 48/100
#
# Epoch 00048: val_mae did not improve from 8.36688
# 789/789 - 107s - loss: 135.1125 - mae: 8.5331 - val_loss: 120.8993 - val_mae: 8.4175
#
# Epoch 00049: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 49/100
#
# Epoch 00049: val_mae did not improve from 8.36688
# 789/789 - 107s - loss: 142.1194 - mae: 8.6498 - val_loss: 122.1661 - val_mae: 8.4789
#
# Epoch 00050: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 50/100
#
# Epoch 00050: val_mae did not improve from 8.36688
# 789/789 - 107s - loss: 138.7059 - mae: 8.6264 - val_loss: 120.8650 - val_mae: 8.3916
#
# Epoch 00051: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 51/100
#
# Epoch 00051: val_mae did not improve from 8.36688
# 789/789 - 107s - loss: 137.8507 - mae: 8.6173 - val_loss: 122.8314 - val_mae: 8.5111
#
# Epoch 00052: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 52/100
#
# Epoch 00052: val_mae did not improve from 8.36688
# 789/789 - 107s - loss: 142.8196 - mae: 8.6492 - val_loss: 124.2940 - val_mae: 8.5757
#
# Epoch 00053: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 53/100
#
# Epoch 00053: val_mae did not improve from 8.36688
# 789/789 - 107s - loss: 138.7795 - mae: 8.6622 - val_loss: 122.9159 - val_mae: 8.5033
#
# Epoch 00054: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 54/100
#
# Epoch 00054: val_mae did not improve from 8.36688
# 789/789 - 107s - loss: 149.1364 - mae: 8.7685 - val_loss: 122.7924 - val_mae: 8.4942
#
# Epoch 00055: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 55/100
#
# Epoch 00055: val_mae did not improve from 8.36688
# 789/789 - 107s - loss: 136.3470 - mae: 8.5823 - val_loss: 122.6128 - val_mae: 8.5055
#
# Epoch 00056: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 56/100
#
# Epoch 00056: val_mae did not improve from 8.36688
# 789/789 - 107s - loss: 140.2234 - mae: 8.6137 - val_loss: 120.6952 - val_mae: 8.3924
#
# Epoch 00057: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 57/100
#
# Epoch 00057: val_mae did not improve from 8.36688
# 789/789 - 107s - loss: 137.7742 - mae: 8.6018 - val_loss: 122.2853 - val_mae: 8.4969
#
# Epoch 00058: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 58/100
#
# Epoch 00058: val_mae did not improve from 8.36688
# 789/789 - 107s - loss: 147.2222 - mae: 8.7508 - val_loss: 121.3087 - val_mae: 8.4432
#
# Epoch 00059: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 59/100
#
# Epoch 00059: val_mae did not improve from 8.36688
# 789/789 - 107s - loss: 142.3620 - mae: 8.6456 - val_loss: 121.9567 - val_mae: 8.4473
#
# Epoch 00060: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 60/100
#
# Epoch 00060: val_mae did not improve from 8.36688
# 789/789 - 107s - loss: 143.6375 - mae: 8.6736 - val_loss: 120.4276 - val_mae: 8.3973
#
# Epoch 00061: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 61/100
#
# Epoch 00061: val_mae did not improve from 8.36688
# 789/789 - 107s - loss: 134.1783 - mae: 8.5334 - val_loss: 120.2668 - val_mae: 8.3797
#
# Epoch 00062: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 62/100
#
# Epoch 00062: val_mae did not improve from 8.36688
# 789/789 - 107s - loss: 134.6327 - mae: 8.5912 - val_loss: 120.4531 - val_mae: 8.3933
#
# Epoch 00063: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 63/100
#
# Epoch 00063: val_mae did not improve from 8.36688
# 789/789 - 107s - loss: 150.1193 - mae: 8.8535 - val_loss: 121.2578 - val_mae: 8.4317
#
# Epoch 00064: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 64/100
#
# Epoch 00064: val_mae did not improve from 8.36688
# 789/789 - 107s - loss: 144.0943 - mae: 8.6627 - val_loss: 120.5959 - val_mae: 8.3985
#
# Epoch 00065: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 65/100
#
# Epoch 00065: val_mae did not improve from 8.36688
# 789/789 - 107s - loss: 138.5272 - mae: 8.6444 - val_loss: 120.5261 - val_mae: 8.3935
#
# Epoch 00066: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 66/100
#
# Epoch 00066: val_mae did not improve from 8.36688
# 789/789 - 107s - loss: 135.8114 - mae: 8.5755 - val_loss: 120.4614 - val_mae: 8.3927
#
# Epoch 00067: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 67/100
#
# Epoch 00067: val_mae did not improve from 8.36688
# 789/789 - 107s - loss: 142.2089 - mae: 8.6182 - val_loss: 120.8766 - val_mae: 8.4166
#
# Epoch 00068: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 68/100
#
# Epoch 00068: val_mae did not improve from 8.36688
# 789/789 - 107s - loss: 144.3762 - mae: 8.6242 - val_loss: 121.5274 - val_mae: 8.4657
#
# Epoch 00069: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 69/100
#
# Epoch 00069: val_mae did not improve from 8.36688
# 789/789 - 107s - loss: 155.6170 - mae: 8.8086 - val_loss: 121.1675 - val_mae: 8.4206
#
# Epoch 00070: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 70/100
#
# Epoch 00070: val_mae did not improve from 8.36688
# 789/789 - 107s - loss: 140.9459 - mae: 8.6231 - val_loss: 120.6606 - val_mae: 8.4050
#
# Epoch 00071: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 71/100
#
# Epoch 00071: val_mae improved from 8.36688 to 8.33104, saving model to ./ckpts/inception/best_val_inception_100ep.h5
# 789/789 - 107s - loss: 145.4867 - mae: 8.6730 - val_loss: 119.5944 - val_mae: 8.3310
#
# Epoch 00072: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 72/100
#
# Epoch 00072: val_mae did not improve from 8.33104
# 789/789 - 107s - loss: 137.7237 - mae: 8.5666 - val_loss: 121.3636 - val_mae: 8.4372
#
# Epoch 00073: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 73/100
#
# Epoch 00073: val_mae did not improve from 8.33104
# 789/789 - 107s - loss: 127.8039 - mae: 8.4325 - val_loss: 119.9183 - val_mae: 8.3847
#
# Epoch 00074: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 74/100
#
# Epoch 00074: val_mae did not improve from 8.33104
# 789/789 - 107s - loss: 143.9856 - mae: 8.6205 - val_loss: 120.3613 - val_mae: 8.3744
#
# Epoch 00075: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 75/100
#
# Epoch 00075: val_mae did not improve from 8.33104
# 789/789 - 107s - loss: 137.3821 - mae: 8.6330 - val_loss: 121.5011 - val_mae: 8.4442
#
# Epoch 00076: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 76/100
#
# Epoch 00076: val_mae did not improve from 8.33104
# 789/789 - 107s - loss: 143.3633 - mae: 8.6151 - val_loss: 122.0513 - val_mae: 8.4893
#
# Epoch 00077: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 77/100
#
# Epoch 00077: val_mae did not improve from 8.33104
# 789/789 - 107s - loss: 140.7017 - mae: 8.6485 - val_loss: 120.6530 - val_mae: 8.4133
#
# Epoch 00078: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 78/100
#
# Epoch 00078: val_mae did not improve from 8.33104
# 789/789 - 107s - loss: 134.1106 - mae: 8.5293 - val_loss: 119.9944 - val_mae: 8.3554
#
# Epoch 00079: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 79/100
#
# Epoch 00079: val_mae did not improve from 8.33104
# 789/789 - 107s - loss: 143.8479 - mae: 8.7090 - val_loss: 120.2041 - val_mae: 8.3702
#
# Epoch 00080: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 80/100
#
# Epoch 00080: val_mae did not improve from 8.33104
# 789/789 - 107s - loss: 145.4455 - mae: 8.6866 - val_loss: 121.5035 - val_mae: 8.4477
#
# Epoch 00081: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 81/100
#
# Epoch 00081: val_mae did not improve from 8.33104
# 789/789 - 107s - loss: 134.9924 - mae: 8.5645 - val_loss: 120.5622 - val_mae: 8.3973
#
# Epoch 00082: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 82/100
#
# Epoch 00082: val_mae did not improve from 8.33104
# 789/789 - 107s - loss: 143.9807 - mae: 8.6548 - val_loss: 119.9036 - val_mae: 8.3555
#
# Epoch 00083: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 83/100
#
# Epoch 00083: val_mae did not improve from 8.33104
# 789/789 - 107s - loss: 138.6874 - mae: 8.6171 - val_loss: 120.5494 - val_mae: 8.3957
#
# Epoch 00084: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 84/100
#
# Epoch 00084: val_mae did not improve from 8.33104
# 789/789 - 107s - loss: 151.8996 - mae: 8.7688 - val_loss: 120.5364 - val_mae: 8.3693
#
# Epoch 00085: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 85/100
#
# Epoch 00085: val_mae did not improve from 8.33104
# 789/789 - 107s - loss: 140.8593 - mae: 8.6587 - val_loss: 120.8342 - val_mae: 8.3971
#
# Epoch 00086: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 86/100
#
# Epoch 00086: val_mae did not improve from 8.33104
# 789/789 - 107s - loss: 143.1706 - mae: 8.6298 - val_loss: 121.2291 - val_mae: 8.4303
#
# Epoch 00087: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 87/100
#
# Epoch 00087: val_mae did not improve from 8.33104
# 789/789 - 107s - loss: 139.2590 - mae: 8.5833 - val_loss: 121.2959 - val_mae: 8.4268
#
# Epoch 00088: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 88/100
#
# Epoch 00088: val_mae did not improve from 8.33104
# 789/789 - 107s - loss: 135.5686 - mae: 8.5471 - val_loss: 121.2581 - val_mae: 8.4340
#
# Epoch 00089: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 89/100
#
# Epoch 00089: val_mae did not improve from 8.33104
# 789/789 - 107s - loss: 145.8547 - mae: 8.6248 - val_loss: 120.7380 - val_mae: 8.4005
#
# Epoch 00090: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 90/100
#
# Epoch 00090: val_mae did not improve from 8.33104
# 789/789 - 107s - loss: 140.7487 - mae: 8.6522 - val_loss: 120.9755 - val_mae: 8.4193
#
# Epoch 00091: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 91/100

# %% [markdown]
# ### test

# %%
test_directory = '../hdadataset2021/Bone Age Datasets/Bone Age Test Set/Test Set Images/'

df_test = pd.read_csv('./test.csv')

ids = df_test['id'].values.astype(str)
labels = (df_test['Sex'].values == 'M').astype(float)

# replace ',' with '.' and convert to float
ages_str = df_test['boneage'].values
ages = np.empty_like(ages_str)
for i, item in enumerate(ages_str):
    replaced = item.replace(',','.')
    replaced_float = float(replaced)
    ages[i] = replaced_float
ages = ages.astype(float)

test_ds = tf.data.Dataset.from_tensor_slices((ids, labels, ages))

def read_test_image(image_file, label, age):
    image = tf.io.read_file(test_directory + image_file + '.png')
    image = tf.io.decode_png(image, channels=1)
    return image, [label], [age] #lists are necessary for training the model (otherwise dims are unknown)

test_ds = test_ds.map(read_test_image).map(lambda image,label,age: (normalization_layer(resize_layer(image)), label, age)).cache()
test_ds = test_ds.prefetch(buffer_size=AUTOTUNE)

test_iterator = test_ds.as_numpy_iterator()
N = 200 #number of samples
test_images = np.empty(shape=(N, IMG_SIZE[0], IMG_SIZE[1], 1), dtype=np.float32)
test_labels = np.empty(shape=(N,), dtype=np.float32)
test_ages = np.empty(shape=(N,), dtype=np.float32)
for i, item in enumerate(test_iterator):
    test_images[i] = item[0]
    test_labels[i] = item[1]
    test_ages[i] = item[2]
    
print(test_images.shape)
print(test_labels.shape)
print(test_ages.shape)
# Out:
# (200, 300, 300, 1)
# (200,)
# (200,)

# %%
bonageinception.load_weights('./ckpts/inception/best_val_inception_100ep.h5')

# %%
bonageinception_pred = bonageinception.predict((test_images, test_labels))

# %%
np.mean(np.abs(bonageinception_pred.squeeze() - test_ages.squeeze()))
# Out:
# 7.2804284

# %%
bonageinception.summary()
