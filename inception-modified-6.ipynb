# %%
import pandas as pd
import tensorflow as tf
import numpy as np
from tensorflow.python.keras.engine import data_adapter
from tensorflow.keras import backend as K
import os, sys
os.mkdir('/kaggle/working/ckpts/')
sys.path.append('../input/boneage-ckpts')
sys.path.append('../input/hdaproject2021-codes/')
sys.path.append('../input/temppp/')

# %%
train_csv_directory = '../input/hdadataset2021/Bone Age Datasets/Bone Age Training Set/'
train_directory = '../input/hdadataset2021/Bone Age Datasets/Bone Age Training Set/boneage-training-dataset/'
df_train = pd.read_csv(train_csv_directory + 'train.csv')

val_csv_directory = '../input/hdadataset2021/'
val_directory = '../input/hdadataset2021/boneage-validation-dataset/'
df_val = pd.read_csv(val_csv_directory + 'Validation Dataset.csv')

# %%
ids = df_train['id'].values.astype(str)
labels = df_train['male'].values.astype(float)
ages = df_train['boneage'].values.astype(float)
train_ds = tf.data.Dataset.from_tensor_slices((ids, labels, ages))


ids = df_val['Image ID'].values.astype(str)
labels = df_val['male'].values.astype(float)
ages = df_val['Bone Age (months)'].values.astype(float)
val_ds = tf.data.Dataset.from_tensor_slices((ids, labels, ages))

IMG_SIZE = (300, 300, 1)
BATCH_SIZE = 16

# %%
def read_train_image(image_file, label, age):
    image = tf.io.read_file(train_directory + image_file+ '.png')
    image = tf.io.decode_png(image, channels=1)
    return image, [label], [age] #lists are necessary for training the model (otherwise dims are unknown)

def read_val_image(image_file, label, age):
    image = tf.io.read_file(val_directory + image_file + '.png')
    image = tf.io.decode_png(image, channels=1)
    return image, [label], [age] #lists are necessary for training the model (otherwise dims are unknown)

resize_layer = tf.keras.layers.experimental.preprocessing.Resizing(height=IMG_SIZE[0], width=IMG_SIZE[1])
normalization_layer = tf.keras.layers.experimental.preprocessing.Rescaling(1/255.)
zoom_layer = tf.keras.layers.experimental.preprocessing.RandomZoom(height_factor=(0.2,-0.3),
                                                                   width_factor=(0.2,-0.3),
                                                                  fill_mode='constant')
flip_layer = tf.keras.layers.experimental.preprocessing.RandomFlip(mode='horizontal')
shift_layer = tf.keras.layers.experimental.preprocessing.RandomTranslation(height_factor=0.2, width_factor=0.2,
                                                                           fill_mode='constant')

def brightness_function(image):
    image = tf.image.random_brightness(image, max_delta=0.3)
    image = tf.math.maximum(image, 0.)
    image = tf.math.minimum(image, 1.)
    return image

def augment(image, label, age):
    # data augmentation here
    image = shift_layer(image)
    image = zoom_layer(image)
    image = flip_layer(image)
    #image = brightness_function(image)
    return image, label, age

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE #tf.data.AUTOTUNE
train_ds = train_ds.map(read_train_image).map(lambda image,label,age: (normalization_layer((resize_layer(image))), label, age)).cache('../input/hdaproject2021-codes/train_cache_300')
train_ds = train_ds.shuffle(buffer_size=1000).batch(BATCH_SIZE).map(augment,num_parallel_calls=AUTOTUNE)
train_ds = train_ds.prefetch(buffer_size=AUTOTUNE)

val_ds = val_ds.map(read_val_image).map(lambda image,label,age: (normalization_layer(resize_layer(image)), label, age)).cache('../input/hdaproject2021-codes/val_cache_300')
val_ds = val_ds.prefetch(buffer_size=AUTOTUNE).batch(BATCH_SIZE)

# %%
#image = list(val_ds.take(1).as_numpy_iterator())[0][0][1]

# %%
# %matplotlib inline
#import matplotlib.pyplot as plt
#_ = plt.imshow(image)

# %% [markdown]
# # Boneage Model

# %%
from InceptionV3_5 import InceptionV3
class BoneAgeInceptionNet(tf.keras.Model):  
    def __init__(self, gender=True, beta=1):
        super(BoneAgeInceptionNet, self).__init__()
        
        model = InceptionV3(
                                include_top=False,
                                weights=None,
                                input_shape=IMG_SIZE,
                                beta=beta)
                
        
        if gender:
            initializer = tf.keras.initializers.GlorotNormal()
            gender_input = tf.keras.Input(shape=(1))
            gender_output = tf.keras.layers.Dense(100, activation='relu', kernel_initializer=initializer)(gender_input)
            
            model_global_avg = tf.keras.layers.GlobalAveragePooling2D()(model.output)
            
            concat_output = tf.keras.layers.Concatenate(name='gender_and_feat._concat')([model_global_avg, gender_output])
            
            #dense_output = tf.keras.layers.Dense(2000,activation='relu', kernel_regularizer='l2', kernel_initializer=initializer)(concat_output)
            
            overall_output = tf.keras.layers.Dense(1,activation='relu', kernel_regularizer='l2', kernel_initializer=initializer)(concat_output)
            
            self.model = tf.keras.Model(inputs=[model.input, gender_input], outputs = overall_output)
        else:
            pass #COMPLETE!
                
        
        
    def call(self, x, training=False):
        imgs, labels = x
        
        y = self.model([imgs, labels],training)
       
        return y

    def train_step(self, data):
        
        data = data_adapter.expand_1d(data)
        imgs, labels, ages = data
        
        with tf.GradientTape() as tape:
            y_pred = self((imgs, labels), training=True)  # Forward pass

            loss = self.compiled_loss(ages, y_pred)

        trainable_vars = self.trainable_variables
        gradients = tape.gradient(loss, trainable_vars)
        
        # Update weights
        self.optimizer.apply_gradients(zip(gradients, trainable_vars))

        self.compiled_metrics.update_state(ages, y_pred)
        _dict = {m.name: m.result() for m in self.metrics}
        
        return _dict

    def test_step(self, data):
        
        data = data_adapter.expand_1d(data)
        imgs, labels, ages = data

        y_pred = self((imgs, labels), training=False)  # Forward pass

        loss = self.compiled_loss(ages, y_pred)

        self.compiled_metrics.update_state(ages, y_pred)
        _dict = {m.name: m.result() for m in self.metrics}
        
        return _dict
    
    def summary(self):
        print(self.model.summary())

# %%
boneageinception = BoneAgeInceptionNet(beta=1.1)
ckpt_callback = tf.keras.callbacks.ModelCheckpoint(
                filepath='./ckpts/best_val_inception_80ep.h5', monitor='val_mae', verbose=1, save_best_only=True,
                save_weights_only=True, mode='min')

def scheduler(epoch, lr):
    if epoch < 30:
        return lr
    elif epoch < 60:
        return 1e-3
    else:
        return 1e-4

lr_scheduler_callback = tf.keras.callbacks.LearningRateScheduler(scheduler, verbose=1)

optimizer = tf.keras.optimizers.Adam(learning_rate=1e-2)
metric = tf.keras.metrics.MeanAbsoluteError()
boneageinception.compile(optimizer=optimizer, loss='mse', metrics=['mae'])

boneageinception.fit(train_ds, validation_data=val_ds,callbacks = [ckpt_callback,lr_scheduler_callback],
                    epochs=80, verbose=2)
# Out:
# Epoch 1/80
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# 789/789 - 292s - loss: 1850.2042 - mae: 33.8682 - val_loss: 68615.3828 - val_mae: 57.9322
#
# Epoch 00001: val_mae improved from inf to 57.93216, saving model to ./ckpts/best_val_inception_80ep.h5
# Epoch 2/80
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# 789/789 - 262s - loss: 1647.8254 - mae: 32.5019 - val_loss: 17019642.0000 - val_mae: 331.2446
#
# Epoch 00002: val_mae did not improve from 57.93216
# Epoch 3/80
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# 789/789 - 263s - loss: 1660.4012 - mae: 32.6871 - val_loss: 702697049161728.0000 - val_mae: 17617790.0000
#
# Epoch 00003: val_mae did not improve from 57.93216
# Epoch 4/80
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# 789/789 - 262s - loss: 1666.9363 - mae: 32.6915 - val_loss: 4963856.5000 - val_mae: 1934.3242
#
# Epoch 00004: val_mae did not improve from 57.93216
# Epoch 5/80
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# 789/789 - 264s - loss: 1654.9445 - mae: 32.6325 - val_loss: 169696.8906 - val_mae: 130.6494
#
# Epoch 00005: val_mae did not improve from 57.93216
# Epoch 6/80
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# 789/789 - 263s - loss: 1639.1520 - mae: 32.4379 - val_loss: 1678.1918 - val_mae: 32.4894
#
# Epoch 00006: val_mae improved from 57.93216 to 32.48943, saving model to ./ckpts/best_val_inception_80ep.h5
# Epoch 7/80
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# 789/789 - 264s - loss: 1650.6705 - mae: 32.5864 - val_loss: 1459399552.0000 - val_mae: 13413.0059
#
# Epoch 00007: val_mae did not improve from 32.48943
# Epoch 8/80
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# 789/789 - 263s - loss: 1640.3224 - mae: 32.4904 - val_loss: 1774.1719 - val_mae: 34.3525
#
# Epoch 00008: val_mae did not improve from 32.48943
# Epoch 9/80
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# 789/789 - 263s - loss: 1654.8295 - mae: 32.6765 - val_loss: 1759.6217 - val_mae: 34.9621
#
# Epoch 00009: val_mae did not improve from 32.48943
# Epoch 10/80
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# 789/789 - 263s - loss: 1645.7139 - mae: 32.5360 - val_loss: 1674.7830 - val_mae: 33.1165
#
# Epoch 00010: val_mae did not improve from 32.48943
# Epoch 11/80
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# 789/789 - 263s - loss: 1646.8254 - mae: 32.5554 - val_loss: 1687.6140 - val_mae: 33.6287
#
# Epoch 00011: val_mae did not improve from 32.48943
# Epoch 12/80
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# 789/789 - 263s - loss: 1604.9349 - mae: 31.9915 - val_loss: 1761.4622 - val_mae: 34.2285
#
# Epoch 00012: val_mae did not improve from 32.48943
# Epoch 13/80
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# 789/789 - 263s - loss: 1621.9280 - mae: 32.2360 - val_loss: 1742.4622 - val_mae: 33.8121
#
# Epoch 00013: val_mae did not improve from 32.48943
# Epoch 14/80
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# 789/789 - 263s - loss: 1609.8834 - mae: 32.1933 - val_loss: 1678.5667 - val_mae: 32.2311
#
# Epoch 00014: val_mae improved from 32.48943 to 32.23109, saving model to ./ckpts/best_val_inception_80ep.h5
# Epoch 15/80
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# 789/789 - 263s - loss: 1584.2310 - mae: 31.8597 - val_loss: 10441.9541 - val_mae: 62.8694
#
# Epoch 00015: val_mae did not improve from 32.23109
# Epoch 16/80
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# 789/789 - 264s - loss: 1611.9109 - mae: 32.2245 - val_loss: 1933.8358 - val_mae: 37.1193
#
# Epoch 00016: val_mae did not improve from 32.23109
# Epoch 17/80
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# 789/789 - 263s - loss: 1511.4144 - mae: 30.9371 - val_loss: 1739.2520 - val_mae: 31.7914
#
# Epoch 00017: val_mae improved from 32.23109 to 31.79135, saving model to ./ckpts/best_val_inception_80ep.h5
# Epoch 18/80
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# 789/789 - 263s - loss: 1394.4110 - mae: 29.4197 - val_loss: 4896.4858 - val_mae: 61.8996
#
# Epoch 00018: val_mae did not improve from 31.79135
# Epoch 19/80
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# 789/789 - 263s - loss: 1136.1582 - mae: 25.7403 - val_loss: 1724.0557 - val_mae: 33.2783
#
# Epoch 00019: val_mae did not improve from 31.79135
# Epoch 20/80
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# 789/789 - 263s - loss: 937.8329 - mae: 22.9007 - val_loss: 2304.6003 - val_mae: 41.5403
#
# Epoch 00020: val_mae did not improve from 31.79135
# Epoch 21/80
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# 789/789 - 262s - loss: 771.2073 - mae: 20.5894 - val_loss: 1043.3711 - val_mae: 26.5037
#
# Epoch 00021: val_mae improved from 31.79135 to 26.50367, saving model to ./ckpts/best_val_inception_80ep.h5
# Epoch 22/80
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# 789/789 - 263s - loss: 631.6779 - mae: 18.8207 - val_loss: 1159.8527 - val_mae: 24.9125
#
# Epoch 00022: val_mae improved from 26.50367 to 24.91252, saving model to ./ckpts/best_val_inception_80ep.h5
# Epoch 23/80
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# 789/789 - 263s - loss: 526.2914 - mae: 17.2889 - val_loss: 432.9108 - val_mae: 15.6641
#
# Epoch 00023: val_mae improved from 24.91252 to 15.66412, saving model to ./ckpts/best_val_inception_80ep.h5
# Epoch 24/80
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# 789/789 - 263s - loss: 445.5326 - mae: 16.0346 - val_loss: 366.8281 - val_mae: 13.9559
#
# Epoch 00024: val_mae improved from 15.66412 to 13.95586, saving model to ./ckpts/best_val_inception_80ep.h5
# Epoch 25/80
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# 789/789 - 262s - loss: 394.1186 - mae: 15.1315 - val_loss: 897.5898 - val_mae: 25.7121
#
# Epoch 00025: val_mae did not improve from 13.95586
# Epoch 26/80
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# 789/789 - 263s - loss: 379.8276 - mae: 14.9039 - val_loss: 514.3302 - val_mae: 18.4057
#
# Epoch 00026: val_mae did not improve from 13.95586
# Epoch 27/80
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# 789/789 - 263s - loss: 334.0078 - mae: 14.0658 - val_loss: 331.2847 - val_mae: 14.3817
#
# Epoch 00027: val_mae did not improve from 13.95586
# Epoch 28/80
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# 789/789 - 263s - loss: 322.6889 - mae: 13.8806 - val_loss: 321.1052 - val_mae: 12.6921
#
# Epoch 00028: val_mae improved from 13.95586 to 12.69213, saving model to ./ckpts/best_val_inception_80ep.h5
# Epoch 29/80
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# 789/789 - 263s - loss: 330.5088 - mae: 13.8534 - val_loss: 645.5602 - val_mae: 21.1343
#
# Epoch 00029: val_mae did not improve from 12.69213
# Epoch 30/80
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# 789/789 - 262s - loss: 289.3550 - mae: 13.1135 - val_loss: 262.3588 - val_mae: 12.1346
#
# Epoch 00030: val_mae improved from 12.69213 to 12.13459, saving model to ./ckpts/best_val_inception_80ep.h5
# Epoch 31/80
#
# Epoch 00031: LearningRateScheduler reducing learning rate to 0.001.
# 789/789 - 263s - loss: 230.6943 - mae: 11.6775 - val_loss: 179.3237 - val_mae: 10.1199
#
# Epoch 00031: val_mae improved from 12.13459 to 10.11986, saving model to ./ckpts/best_val_inception_80ep.h5
# Epoch 32/80
#
# Epoch 00032: LearningRateScheduler reducing learning rate to 0.001.
# 789/789 - 263s - loss: 217.2397 - mae: 11.4275 - val_loss: 179.8636 - val_mae: 10.2300
#
# Epoch 00032: val_mae did not improve from 10.11986
# Epoch 33/80
#
# Epoch 00033: LearningRateScheduler reducing learning rate to 0.001.
# 789/789 - 262s - loss: 206.5123 - mae: 11.2067 - val_loss: 213.2722 - val_mae: 11.0275
#
# Epoch 00033: val_mae did not improve from 10.11986
# Epoch 34/80
#
# Epoch 00034: LearningRateScheduler reducing learning rate to 0.001.
# 789/789 - 262s - loss: 188.8145 - mae: 10.6845 - val_loss: 166.8841 - val_mae: 9.6856
#
# Epoch 00034: val_mae improved from 10.11986 to 9.68559, saving model to ./ckpts/best_val_inception_80ep.h5
# Epoch 35/80
#
# Epoch 00035: LearningRateScheduler reducing learning rate to 0.001.
# 789/789 - 262s - loss: 182.2947 - mae: 10.4633 - val_loss: 179.7791 - val_mae: 10.2441
#
# Epoch 00035: val_mae did not improve from 9.68559
# Epoch 36/80
#
# Epoch 00036: LearningRateScheduler reducing learning rate to 0.001.
# 789/789 - 262s - loss: 179.0603 - mae: 10.3345 - val_loss: 166.4111 - val_mae: 9.7421
#
# Epoch 00036: val_mae did not improve from 9.68559
# Epoch 37/80
#
# Epoch 00037: LearningRateScheduler reducing learning rate to 0.001.
# 789/789 - 262s - loss: 175.9748 - mae: 10.1927 - val_loss: 186.9985 - val_mae: 10.5391
#
# Epoch 00037: val_mae did not improve from 9.68559
# Epoch 38/80
#
# Epoch 00038: LearningRateScheduler reducing learning rate to 0.001.
# 789/789 - 263s - loss: 168.7689 - mae: 9.9974 - val_loss: 163.5474 - val_mae: 9.6352
#
# Epoch 00038: val_mae improved from 9.68559 to 9.63515, saving model to ./ckpts/best_val_inception_80ep.h5
# Epoch 39/80
#
# Epoch 00039: LearningRateScheduler reducing learning rate to 0.001.
# 789/789 - 262s - loss: 164.9445 - mae: 9.8940 - val_loss: 174.9536 - val_mae: 10.1588
#
# Epoch 00039: val_mae did not improve from 9.63515
# Epoch 40/80
#
# Epoch 00040: LearningRateScheduler reducing learning rate to 0.001.
# 789/789 - 262s - loss: 161.3335 - mae: 9.7564 - val_loss: 154.0815 - val_mae: 9.3662
#
# Epoch 00040: val_mae improved from 9.63515 to 9.36621, saving model to ./ckpts/best_val_inception_80ep.h5
# Epoch 41/80
#
# Epoch 00041: LearningRateScheduler reducing learning rate to 0.001.
# 789/789 - 263s - loss: 155.2282 - mae: 9.5768 - val_loss: 170.3669 - val_mae: 9.9982
#
# Epoch 00041: val_mae did not improve from 9.36621
# Epoch 42/80
#
# Epoch 00042: LearningRateScheduler reducing learning rate to 0.001.
# 789/789 - 262s - loss: 157.3114 - mae: 9.6247 - val_loss: 154.9710 - val_mae: 9.3487
#
# Epoch 00042: val_mae improved from 9.36621 to 9.34875, saving model to ./ckpts/best_val_inception_80ep.h5
# Epoch 43/80
#
# Epoch 00043: LearningRateScheduler reducing learning rate to 0.001.
# 789/789 - 262s - loss: 153.5906 - mae: 9.5176 - val_loss: 151.7970 - val_mae: 9.2782
#
# Epoch 00043: val_mae improved from 9.34875 to 9.27819, saving model to ./ckpts/best_val_inception_80ep.h5
# Epoch 44/80
#
# Epoch 00044: LearningRateScheduler reducing learning rate to 0.001.
# 789/789 - 262s - loss: 151.1299 - mae: 9.4473 - val_loss: 156.3085 - val_mae: 9.4335
#
# Epoch 00044: val_mae did not improve from 9.27819
# Epoch 45/80
#
# Epoch 00045: LearningRateScheduler reducing learning rate to 0.001.
# 789/789 - 263s - loss: 149.1234 - mae: 9.3306 - val_loss: 152.7358 - val_mae: 9.3332
#
# Epoch 00045: val_mae did not improve from 9.27819
# Epoch 46/80
#
# Epoch 00046: LearningRateScheduler reducing learning rate to 0.001.
# 789/789 - 262s - loss: 149.0522 - mae: 9.3902 - val_loss: 170.9753 - val_mae: 9.9744
#
# Epoch 00046: val_mae did not improve from 9.27819
# Epoch 47/80
#
# Epoch 00047: LearningRateScheduler reducing learning rate to 0.001.
# 789/789 - 263s - loss: 146.7873 - mae: 9.3347 - val_loss: 149.6402 - val_mae: 9.2481
#
# Epoch 00047: val_mae improved from 9.27819 to 9.24810, saving model to ./ckpts/best_val_inception_80ep.h5
# Epoch 48/80
#
# Epoch 00048: LearningRateScheduler reducing learning rate to 0.001.
# 789/789 - 263s - loss: 145.3084 - mae: 9.2528 - val_loss: 176.2020 - val_mae: 10.1061
#
# Epoch 00048: val_mae did not improve from 9.24810
# Epoch 49/80
#
# Epoch 00049: LearningRateScheduler reducing learning rate to 0.001.
# 789/789 - 262s - loss: 141.5140 - mae: 9.1466 - val_loss: 157.2448 - val_mae: 9.6134
#
# Epoch 00049: val_mae did not improve from 9.24810
# Epoch 50/80
#
# Epoch 00050: LearningRateScheduler reducing learning rate to 0.001.
# 789/789 - 262s - loss: 141.8169 - mae: 9.1621 - val_loss: 152.1111 - val_mae: 9.2789
#
# Epoch 00050: val_mae did not improve from 9.24810
# Epoch 51/80
#
# Epoch 00051: LearningRateScheduler reducing learning rate to 0.001.
# 789/789 - 262s - loss: 137.8136 - mae: 9.0750 - val_loss: 164.2377 - val_mae: 9.7711
#
# Epoch 00051: val_mae did not improve from 9.24810
# Epoch 52/80
#
# Epoch 00052: LearningRateScheduler reducing learning rate to 0.001.
# 789/789 - 262s - loss: 139.2399 - mae: 9.1024 - val_loss: 151.0157 - val_mae: 9.1982
#
# Epoch 00052: val_mae improved from 9.24810 to 9.19823, saving model to ./ckpts/best_val_inception_80ep.h5
# Epoch 53/80
#
# Epoch 00053: LearningRateScheduler reducing learning rate to 0.001.
# 789/789 - 263s - loss: 135.1477 - mae: 8.9620 - val_loss: 155.8805 - val_mae: 9.4824
#
# Epoch 00053: val_mae did not improve from 9.19823
# Epoch 54/80
#
# Epoch 00054: LearningRateScheduler reducing learning rate to 0.001.
# 789/789 - 262s - loss: 136.9253 - mae: 9.0328 - val_loss: 142.8504 - val_mae: 9.0056
#
# Epoch 00054: val_mae improved from 9.19823 to 9.00559, saving model to ./ckpts/best_val_inception_80ep.h5
# Epoch 55/80
#
# Epoch 00055: LearningRateScheduler reducing learning rate to 0.001.
# 789/789 - 262s - loss: 136.7882 - mae: 8.9762 - val_loss: 137.1758 - val_mae: 8.7989
#
# Epoch 00055: val_mae improved from 9.00559 to 8.79887, saving model to ./ckpts/best_val_inception_80ep.h5
# Epoch 56/80
#
# Epoch 00056: LearningRateScheduler reducing learning rate to 0.001.
# 789/789 - 262s - loss: 139.1915 - mae: 9.0127 - val_loss: 148.7843 - val_mae: 9.3242
#
# Epoch 00056: val_mae did not improve from 8.79887
# Epoch 57/80
#
# Epoch 00057: LearningRateScheduler reducing learning rate to 0.001.
# 789/789 - 263s - loss: 134.6330 - mae: 8.9019 - val_loss: 153.3702 - val_mae: 9.4244
#
# Epoch 00057: val_mae did not improve from 8.79887
# Epoch 58/80
#
# Epoch 00058: LearningRateScheduler reducing learning rate to 0.001.
# 789/789 - 262s - loss: 132.5155 - mae: 8.8618 - val_loss: 159.7392 - val_mae: 9.7076
#
# Epoch 00058: val_mae did not improve from 8.79887
# Epoch 59/80
#
# Epoch 00059: LearningRateScheduler reducing learning rate to 0.001.
# 789/789 - 262s - loss: 131.7463 - mae: 8.8866 - val_loss: 145.7284 - val_mae: 9.2306
#
# Epoch 00059: val_mae did not improve from 8.79887
# Epoch 60/80
#
# Epoch 00060: LearningRateScheduler reducing learning rate to 0.001.
# 789/789 - 262s - loss: 133.0892 - mae: 8.9070 - val_loss: 137.3119 - val_mae: 8.9009
#
# Epoch 00060: val_mae did not improve from 8.79887
# Epoch 61/80
#
# Epoch 00061: LearningRateScheduler reducing learning rate to 0.0001.
# 789/789 - 262s - loss: 124.8645 - mae: 8.5668 - val_loss: 139.8761 - val_mae: 9.0215
#
# Epoch 00061: val_mae did not improve from 8.79887
# Epoch 62/80
#
# Epoch 00062: LearningRateScheduler reducing learning rate to 0.0001.
# 789/789 - 262s - loss: 123.7809 - mae: 8.6004 - val_loss: 135.8727 - val_mae: 8.8650
#
# Epoch 00062: val_mae did not improve from 8.79887
# Epoch 63/80
#
# Epoch 00063: LearningRateScheduler reducing learning rate to 0.0001.
# 789/789 - 262s - loss: 123.8877 - mae: 8.5627 - val_loss: 135.8762 - val_mae: 8.8631
#
# Epoch 00063: val_mae did not improve from 8.79887
# Epoch 64/80
#
# Epoch 00064: LearningRateScheduler reducing learning rate to 0.0001.
# 789/789 - 263s - loss: 122.4177 - mae: 8.5430 - val_loss: 135.0167 - val_mae: 8.7993
#
# Epoch 00064: val_mae did not improve from 8.79887
# Epoch 65/80
#
# Epoch 00065: LearningRateScheduler reducing learning rate to 0.0001.
# 789/789 - 263s - loss: 123.4494 - mae: 8.5362 - val_loss: 137.1535 - val_mae: 8.8859
#
# Epoch 00065: val_mae did not improve from 8.79887
# Epoch 66/80
#
# Epoch 00066: LearningRateScheduler reducing learning rate to 0.0001.
# 789/789 - 262s - loss: 123.4992 - mae: 8.5586 - val_loss: 134.3057 - val_mae: 8.7816
#
# Epoch 00066: val_mae improved from 8.79887 to 8.78158, saving model to ./ckpts/best_val_inception_80ep.h5
# Epoch 67/80
#
# Epoch 00067: LearningRateScheduler reducing learning rate to 0.0001.
# 789/789 - 262s - loss: 121.7927 - mae: 8.5103 - val_loss: 137.4362 - val_mae: 8.8913
#
# Epoch 00067: val_mae did not improve from 8.78158
# Epoch 68/80
#
# Epoch 00068: LearningRateScheduler reducing learning rate to 0.0001.
# 789/789 - 262s - loss: 122.0528 - mae: 8.5034 - val_loss: 135.6187 - val_mae: 8.8411
#
# Epoch 00068: val_mae did not improve from 8.78158
# Epoch 69/80
#
# Epoch 00069: LearningRateScheduler reducing learning rate to 0.0001.
# 789/789 - 262s - loss: 121.6547 - mae: 8.4787 - val_loss: 140.4070 - val_mae: 8.9883
#
# Epoch 00069: val_mae did not improve from 8.78158
# Epoch 70/80
#
# Epoch 00070: LearningRateScheduler reducing learning rate to 0.0001.
# 789/789 - 262s - loss: 122.6667 - mae: 8.4878 - val_loss: 138.7421 - val_mae: 8.9242
#
# Epoch 00070: val_mae did not improve from 8.78158
# Epoch 71/80
#
# Epoch 00071: LearningRateScheduler reducing learning rate to 0.0001.
# 789/789 - 262s - loss: 121.5024 - mae: 8.5047 - val_loss: 136.5594 - val_mae: 8.8349
#
# Epoch 00071: val_mae did not improve from 8.78158
# Epoch 72/80
#
# Epoch 00072: LearningRateScheduler reducing learning rate to 0.0001.
# 789/789 - 262s - loss: 122.4753 - mae: 8.5257 - val_loss: 137.4172 - val_mae: 8.8833
#
# Epoch 00072: val_mae did not improve from 8.78158
# Epoch 73/80
#
# Epoch 00073: LearningRateScheduler reducing learning rate to 0.0001.
# 789/789 - 262s - loss: 122.4412 - mae: 8.5505 - val_loss: 138.8333 - val_mae: 8.9418
#
# Epoch 00073: val_mae did not improve from 8.78158
# Epoch 74/80
#
# Epoch 00074: LearningRateScheduler reducing learning rate to 0.0001.
# 789/789 - 262s - loss: 121.6946 - mae: 8.4835 - val_loss: 137.7585 - val_mae: 8.8988
#
# Epoch 00074: val_mae did not improve from 8.78158
# Epoch 75/80
#
# Epoch 00075: LearningRateScheduler reducing learning rate to 0.0001.
# 789/789 - 262s - loss: 121.7005 - mae: 8.5244 - val_loss: 135.9502 - val_mae: 8.8128
#
# Epoch 00075: val_mae did not improve from 8.78158
# Epoch 76/80
#
# Epoch 00076: LearningRateScheduler reducing learning rate to 0.0001.
# 789/789 - 262s - loss: 120.4987 - mae: 8.4813 - val_loss: 139.6646 - val_mae: 8.9831
#
# Epoch 00076: val_mae did not improve from 8.78158
# Epoch 77/80
#
# Epoch 00077: LearningRateScheduler reducing learning rate to 0.0001.
# 789/789 - 262s - loss: 118.6807 - mae: 8.4374 - val_loss: 137.8360 - val_mae: 8.8931
#
# Epoch 00077: val_mae did not improve from 8.78158
# Epoch 78/80
#
# Epoch 00078: LearningRateScheduler reducing learning rate to 0.0001.
# 789/789 - 262s - loss: 119.7617 - mae: 8.4554 - val_loss: 138.0368 - val_mae: 8.8997
#
# Epoch 00078: val_mae did not improve from 8.78158
# Epoch 79/80
#
# Epoch 00079: LearningRateScheduler reducing learning rate to 0.0001.
# 789/789 - 262s - loss: 120.6435 - mae: 8.4552 - val_loss: 137.4684 - val_mae: 8.8985
#
# Epoch 00079: val_mae did not improve from 8.78158
# Epoch 80/80
#
# Epoch 00080: LearningRateScheduler reducing learning rate to 0.0001.
# 789/789 - 262s - loss: 121.7672 - mae: 8.5056 - val_loss: 136.6858 - val_mae: 8.8418
#
# Epoch 00080: val_mae did not improve from 8.78158

# %% [markdown]
# ### test

# %%
test_directory = '../input/hdadataset2021/Bone Age Datasets/Bone Age Test Set/Test Set Images/'

df_test = pd.read_csv('../input/hdaproject2021-codes/test.csv')

ids = df_test['id'].values.astype(str)
labels = (df_test['Sex'].values == 'M').astype(float)

# replace ',' with '.' and convert to float
ages_str = df_test['boneage'].values
ages = np.empty_like(ages_str)
for i, item in enumerate(ages_str):
    replaced = item.replace(',','.')
    replaced_float = float(replaced)
    ages[i] = replaced_float
ages = ages.astype(float)

test_ds = tf.data.Dataset.from_tensor_slices((ids, labels, ages))

def read_test_image(image_file, label, age):
    image = tf.io.read_file(test_directory + image_file + '.png')
    image = tf.io.decode_png(image, channels=1)
    return image, [label], [age] #lists are necessary for training the model (otherwise dims are unknown)

test_ds = test_ds.map(read_test_image).map(lambda image,label,age: (normalization_layer(resize_layer(image)), label, age)).cache()
test_ds = test_ds.prefetch(buffer_size=AUTOTUNE)

test_iterator = test_ds.as_numpy_iterator()
N = 200 #number of samples
test_images = np.empty(shape=(N, IMG_SIZE[0], IMG_SIZE[1], 1), dtype=np.float32)
test_labels = np.empty(shape=(N,), dtype=np.float32)
test_ages = np.empty(shape=(N,), dtype=np.float32)
for i, item in enumerate(test_iterator):
    test_images[i] = item[0]
    test_labels[i] = item[1]
    test_ages[i] = item[2]
    
print(test_images.shape)
print(test_labels.shape)
print(test_ages.shape)
# Out:
# (200, 300, 300, 1)
# (200,)
# (200,)

# %%
boneageinception.load_weights('./ckpts/best_val_inception_80ep.h5')

# %%
boneageinception_pred = boneageinception.predict((test_images, test_labels))

# %%
np.mean(np.abs(boneageinception_pred.squeeze() - test_ages.squeeze()))
# Out:
# 7.4004

# %%
boneageinception.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 300, 300, 1) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 149, 149, 35) 315         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 149, 149, 35) 105         conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 149, 149, 35) 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 147, 147, 35) 11025       activation[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 147, 147, 35) 105         conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 147, 147, 35) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 147, 147, 70) 22050       activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 147, 147, 70) 210         conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 147, 147, 70) 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 73, 73, 70)   0           activation_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 73, 73, 88)   6160        max_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 73, 73, 88)   264         conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 73, 73, 88)   0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 71, 71, 211)  167112      activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 71, 71, 211)  633         conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 71, 71, 211)  0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 35, 35, 211)  0           activation_4[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 35, 35, 70)   14770       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 35, 35, 70)   210         conv2d_8[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 35, 35, 70)   0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 35, 35, 52)   10972       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 35, 35, 105)  66150       activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 35, 35, 52)   156         conv2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 35, 35, 105)  315         conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 35, 35, 52)   0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 35, 35, 105)  0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# average_pooling2d (AveragePooli (None, 35, 35, 211)  0           max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 35, 35, 70)   14770       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 35, 35, 70)   91000       activation_6[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 35, 35, 105)  99225       activation_9[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 35, 35, 35)   7385        average_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 35, 35, 70)   210         conv2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 35, 35, 70)   210         conv2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 35, 35, 105)  315         conv2d_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 35, 35, 35)   105         conv2d_11[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 35, 35, 70)   0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 35, 35, 70)   0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 35, 35, 105)  0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 35, 35, 35)   0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# mixed0-0 (Concatenate)          (None, 35, 35, 280)  0           activation_5[0][0]
#                                                                  activation_7[0][0]
#                                                                  activation_10[0][0]
#                                                                  activation_11[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 35, 35, 70)   19600       mixed0-0[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 35, 35, 70)   210         conv2d_15[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 35, 35, 70)   0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 35, 35, 52)   14560       mixed0-0[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 35, 35, 105)  66150       activation_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 35, 35, 52)   156         conv2d_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 35, 35, 105)  315         conv2d_16[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 35, 35, 52)   0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 35, 35, 105)  0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_1 (AveragePoo (None, 35, 35, 280)  0           mixed0-0[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 35, 35, 70)   19600       mixed0-0[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 35, 35, 70)   91000       activation_13[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 35, 35, 105)  99225       activation_16[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 35, 35, 70)   19600       average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 35, 35, 70)   210         conv2d_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 35, 35, 70)   210         conv2d_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 35, 35, 105)  315         conv2d_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 35, 35, 70)   210         conv2d_18[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 35, 35, 70)   0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 35, 35, 70)   0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 35, 35, 105)  0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 35, 35, 70)   0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# mixed1 (Concatenate)            (None, 35, 35, 315)  0           activation_12[0][0]
#                                                                  activation_14[0][0]
#                                                                  activation_17[0][0]
#                                                                  activation_18[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 35, 35, 70)   22050       mixed1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 35, 35, 70)   210         conv2d_22[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 35, 35, 70)   0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 35, 35, 52)   16380       mixed1[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 35, 35, 105)  66150       activation_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 35, 35, 52)   156         conv2d_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 35, 35, 105)  315         conv2d_23[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 35, 35, 52)   0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 35, 35, 105)  0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_2 (AveragePoo (None, 35, 35, 315)  0           mixed1[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 35, 35, 70)   22050       mixed1[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 35, 35, 70)   91000       activation_20[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 35, 35, 105)  99225       activation_23[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 35, 35, 70)   22050       average_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 35, 35, 70)   210         conv2d_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 35, 35, 70)   210         conv2d_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 35, 35, 105)  315         conv2d_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 35, 35, 70)   210         conv2d_25[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 35, 35, 70)   0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 35, 35, 70)   0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 35, 35, 105)  0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 35, 35, 70)   0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# mixed2 (Concatenate)            (None, 35, 35, 315)  0           activation_19[0][0]
#                                                                  activation_21[0][0]
#                                                                  activation_24[0][0]
#                                                                  activation_25[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 35, 35, 70)   22050       mixed2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 35, 35, 70)   210         conv2d_27[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 35, 35, 70)   0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 35, 35, 105)  66150       activation_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 35, 35, 105)  315         conv2d_28[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 35, 35, 105)  0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 17, 17, 422)  1196370     mixed2[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 17, 17, 105)  99225       activation_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 17, 17, 422)  1266        conv2d_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 17, 17, 105)  315         conv2d_29[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 17, 17, 422)  0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 17, 17, 105)  0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 17, 17, 315)  0           mixed2[0][0]
# __________________________________________________________________________________________________
# mixed3 (Concatenate)            (None, 17, 17, 842)  0           activation_26[0][0]
#                                                                  activation_29[0][0]
#                                                                  max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 17, 17, 140)  117880      mixed3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 17, 17, 140)  420         conv2d_34[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 17, 17, 140)  0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 17, 17, 140)  137200      activation_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 17, 17, 140)  420         conv2d_35[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 17, 17, 140)  0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 17, 17, 140)  117880      mixed3[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 17, 17, 140)  137200      activation_35[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 17, 17, 140)  420         conv2d_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 17, 17, 140)  420         conv2d_36[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 17, 17, 140)  0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 17, 17, 140)  0           batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 17, 17, 140)  137200      activation_31[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 17, 17, 140)  137200      activation_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 17, 17, 140)  420         conv2d_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 17, 17, 140)  420         conv2d_37[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 17, 17, 140)  0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 17, 17, 140)  0           batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_3 (AveragePoo (None, 17, 17, 842)  0           mixed3[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 17, 17, 211)  177662      mixed3[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 17, 17, 211)  206780      activation_32[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 17, 17, 211)  206780      activation_37[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 17, 17, 211)  177662      average_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 17, 17, 211)  633         conv2d_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 17, 17, 211)  633         conv2d_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 17, 17, 211)  633         conv2d_38[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 17, 17, 211)  633         conv2d_39[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 17, 17, 211)  0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 17, 17, 211)  0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 17, 17, 211)  0           batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 17, 17, 211)  0           batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# mixed4-0 (Concatenate)          (None, 17, 17, 844)  0           activation_30[0][0]
#                                                                  activation_33[0][0]
#                                                                  activation_38[0][0]
#                                                                  activation_39[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 17, 17, 176)  148544      mixed4-0[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 17, 17, 176)  528         conv2d_44[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 17, 17, 176)  0           batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 17, 17, 176)  216832      activation_44[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 17, 17, 176)  528         conv2d_45[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 17, 17, 176)  0           batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 17, 17, 176)  148544      mixed4-0[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 17, 17, 176)  216832      activation_45[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 17, 17, 176)  528         conv2d_41[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 17, 17, 176)  528         conv2d_46[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 17, 17, 176)  0           batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 17, 17, 176)  0           batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 17, 17, 176)  216832      activation_41[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 17, 17, 176)  216832      activation_46[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 17, 17, 176)  528         conv2d_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, 17, 17, 176)  528         conv2d_47[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 17, 17, 176)  0           batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 17, 17, 176)  0           batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_4 (AveragePoo (None, 17, 17, 844)  0           mixed4-0[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 17, 17, 211)  178084      mixed4-0[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 17, 17, 211)  259952      activation_42[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 17, 17, 211)  259952      activation_47[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 17, 17, 211)  178084      average_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 17, 17, 211)  633         conv2d_40[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 17, 17, 211)  633         conv2d_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 17, 17, 211)  633         conv2d_48[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, 17, 17, 211)  633         conv2d_49[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 17, 17, 211)  0           batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 17, 17, 211)  0           batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 17, 17, 211)  0           batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, 17, 17, 211)  0           batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# mixed5-0 (Concatenate)          (None, 17, 17, 844)  0           activation_40[0][0]
#                                                                  activation_43[0][0]
#                                                                  activation_48[0][0]
#                                                                  activation_49[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 17, 17, 176)  148544      mixed5-0[0][0]
# __________________________________________________________________________________________________
# batch_normalization_54 (BatchNo (None, 17, 17, 176)  528         conv2d_54[0][0]
# __________________________________________________________________________________________________
# activation_54 (Activation)      (None, 17, 17, 176)  0           batch_normalization_54[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 17, 17, 176)  216832      activation_54[0][0]
# __________________________________________________________________________________________________
# batch_normalization_55 (BatchNo (None, 17, 17, 176)  528         conv2d_55[0][0]
# __________________________________________________________________________________________________
# activation_55 (Activation)      (None, 17, 17, 176)  0           batch_normalization_55[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 17, 17, 176)  148544      mixed5-0[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 17, 17, 176)  216832      activation_55[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 17, 17, 176)  528         conv2d_51[0][0]
# __________________________________________________________________________________________________
# batch_normalization_56 (BatchNo (None, 17, 17, 176)  528         conv2d_56[0][0]
# __________________________________________________________________________________________________
# activation_51 (Activation)      (None, 17, 17, 176)  0           batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# activation_56 (Activation)      (None, 17, 17, 176)  0           batch_normalization_56[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 17, 17, 176)  216832      activation_51[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, 17, 17, 176)  216832      activation_56[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, 17, 17, 176)  528         conv2d_52[0][0]
# __________________________________________________________________________________________________
# batch_normalization_57 (BatchNo (None, 17, 17, 176)  528         conv2d_57[0][0]
# __________________________________________________________________________________________________
# activation_52 (Activation)      (None, 17, 17, 176)  0           batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# activation_57 (Activation)      (None, 17, 17, 176)  0           batch_normalization_57[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_5 (AveragePoo (None, 17, 17, 844)  0           mixed5-0[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 17, 17, 211)  178084      mixed5-0[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 17, 17, 211)  259952      activation_52[0][0]
# __________________________________________________________________________________________________
# conv2d_58 (Conv2D)              (None, 17, 17, 211)  259952      activation_57[0][0]
# __________________________________________________________________________________________________
# conv2d_59 (Conv2D)              (None, 17, 17, 211)  178084      average_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, 17, 17, 211)  633         conv2d_50[0][0]
# __________________________________________________________________________________________________
# batch_normalization_53 (BatchNo (None, 17, 17, 211)  633         conv2d_53[0][0]
# __________________________________________________________________________________________________
# batch_normalization_58 (BatchNo (None, 17, 17, 211)  633         conv2d_58[0][0]
# __________________________________________________________________________________________________
# batch_normalization_59 (BatchNo (None, 17, 17, 211)  633         conv2d_59[0][0]
# __________________________________________________________________________________________________
# activation_50 (Activation)      (None, 17, 17, 211)  0           batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# activation_53 (Activation)      (None, 17, 17, 211)  0           batch_normalization_53[0][0]
# __________________________________________________________________________________________________
# activation_58 (Activation)      (None, 17, 17, 211)  0           batch_normalization_58[0][0]
# __________________________________________________________________________________________________
# activation_59 (Activation)      (None, 17, 17, 211)  0           batch_normalization_59[0][0]
# __________________________________________________________________________________________________
# mixed5-1 (Concatenate)          (None, 17, 17, 844)  0           activation_50[0][0]
#                                                                  activation_53[0][0]
#                                                                  activation_58[0][0]
#                                                                  activation_59[0][0]
# __________________________________________________________________________________________________
# conv2d_64 (Conv2D)              (None, 17, 17, 176)  148544      mixed5-1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_64 (BatchNo (None, 17, 17, 176)  528         conv2d_64[0][0]
# __________________________________________________________________________________________________
# activation_64 (Activation)      (None, 17, 17, 176)  0           batch_normalization_64[0][0]
# __________________________________________________________________________________________________
# conv2d_65 (Conv2D)              (None, 17, 17, 176)  216832      activation_64[0][0]
# __________________________________________________________________________________________________
# batch_normalization_65 (BatchNo (None, 17, 17, 176)  528         conv2d_65[0][0]
# __________________________________________________________________________________________________
# activation_65 (Activation)      (None, 17, 17, 176)  0           batch_normalization_65[0][0]
# __________________________________________________________________________________________________
# conv2d_61 (Conv2D)              (None, 17, 17, 176)  148544      mixed5-1[0][0]
# __________________________________________________________________________________________________
# conv2d_66 (Conv2D)              (None, 17, 17, 176)  216832      activation_65[0][0]
# __________________________________________________________________________________________________
# batch_normalization_61 (BatchNo (None, 17, 17, 176)  528         conv2d_61[0][0]
# __________________________________________________________________________________________________
# batch_normalization_66 (BatchNo (None, 17, 17, 176)  528         conv2d_66[0][0]
# __________________________________________________________________________________________________
# activation_61 (Activation)      (None, 17, 17, 176)  0           batch_normalization_61[0][0]
# __________________________________________________________________________________________________
# activation_66 (Activation)      (None, 17, 17, 176)  0           batch_normalization_66[0][0]
# __________________________________________________________________________________________________
# conv2d_62 (Conv2D)              (None, 17, 17, 176)  216832      activation_61[0][0]
# __________________________________________________________________________________________________
# conv2d_67 (Conv2D)              (None, 17, 17, 176)  216832      activation_66[0][0]
# __________________________________________________________________________________________________
# batch_normalization_62 (BatchNo (None, 17, 17, 176)  528         conv2d_62[0][0]
# __________________________________________________________________________________________________
# batch_normalization_67 (BatchNo (None, 17, 17, 176)  528         conv2d_67[0][0]
# __________________________________________________________________________________________________
# activation_62 (Activation)      (None, 17, 17, 176)  0           batch_normalization_62[0][0]
# __________________________________________________________________________________________________
# activation_67 (Activation)      (None, 17, 17, 176)  0           batch_normalization_67[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_6 (AveragePoo (None, 17, 17, 844)  0           mixed5-1[0][0]
# __________________________________________________________________________________________________
# conv2d_60 (Conv2D)              (None, 17, 17, 211)  178084      mixed5-1[0][0]
# __________________________________________________________________________________________________
# conv2d_63 (Conv2D)              (None, 17, 17, 211)  259952      activation_62[0][0]
# __________________________________________________________________________________________________
# conv2d_68 (Conv2D)              (None, 17, 17, 211)  259952      activation_67[0][0]
# __________________________________________________________________________________________________
# conv2d_69 (Conv2D)              (None, 17, 17, 211)  178084      average_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_60 (BatchNo (None, 17, 17, 211)  633         conv2d_60[0][0]
# __________________________________________________________________________________________________
# batch_normalization_63 (BatchNo (None, 17, 17, 211)  633         conv2d_63[0][0]
# __________________________________________________________________________________________________
# batch_normalization_68 (BatchNo (None, 17, 17, 211)  633         conv2d_68[0][0]
# __________________________________________________________________________________________________
# batch_normalization_69 (BatchNo (None, 17, 17, 211)  633         conv2d_69[0][0]
# __________________________________________________________________________________________________
# activation_60 (Activation)      (None, 17, 17, 211)  0           batch_normalization_60[0][0]
# __________________________________________________________________________________________________
# activation_63 (Activation)      (None, 17, 17, 211)  0           batch_normalization_63[0][0]
# __________________________________________________________________________________________________
# activation_68 (Activation)      (None, 17, 17, 211)  0           batch_normalization_68[0][0]
# __________________________________________________________________________________________________
# activation_69 (Activation)      (None, 17, 17, 211)  0           batch_normalization_69[0][0]
# __________________________________________________________________________________________________
# mixed5-2 (Concatenate)          (None, 17, 17, 844)  0           activation_60[0][0]
#                                                                  activation_63[0][0]
#                                                                  activation_68[0][0]
#                                                                  activation_69[0][0]
# __________________________________________________________________________________________________
# ...
# __________________________________________________________________________________________________
# mixed8_2 (Concatenate)          (None, 8, 8, 844)    0           activation_176[0][0]
#                                                                  activation_177[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 8, 8, 844)    0           activation_180[0][0]
#                                                                  activation_181[0][0]
# __________________________________________________________________________________________________
# activation_182 (Activation)     (None, 8, 8, 211)    0           batch_normalization_182[0][0]
# __________________________________________________________________________________________________
# mixed8-2 (Concatenate)          (None, 8, 8, 2251)   0           activation_174[0][0]
#                                                                  mixed8_2[0][0]
#                                                                  concatenate_2[0][0]
#                                                                  activation_182[0][0]
# __________________________________________________________________________________________________
# conv2d_187 (Conv2D)             (None, 8, 8, 492)    1107492     mixed8-2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_187 (BatchN (None, 8, 8, 492)    1476        conv2d_187[0][0]
# __________________________________________________________________________________________________
# activation_187 (Activation)     (None, 8, 8, 492)    0           batch_normalization_187[0][0]
# __________________________________________________________________________________________________
# conv2d_184 (Conv2D)             (None, 8, 8, 422)    949922      mixed8-2[0][0]
# __________________________________________________________________________________________________
# conv2d_188 (Conv2D)             (None, 8, 8, 422)    1868616     activation_187[0][0]
# __________________________________________________________________________________________________
# batch_normalization_184 (BatchN (None, 8, 8, 422)    1266        conv2d_184[0][0]
# __________________________________________________________________________________________________
# batch_normalization_188 (BatchN (None, 8, 8, 422)    1266        conv2d_188[0][0]
# __________________________________________________________________________________________________
# activation_184 (Activation)     (None, 8, 8, 422)    0           batch_normalization_184[0][0]
# __________________________________________________________________________________________________
# activation_188 (Activation)     (None, 8, 8, 422)    0           batch_normalization_188[0][0]
# __________________________________________________________________________________________________
# conv2d_185 (Conv2D)             (None, 8, 8, 422)    534252      activation_184[0][0]
# __________________________________________________________________________________________________
# conv2d_186 (Conv2D)             (None, 8, 8, 422)    534252      activation_184[0][0]
# __________________________________________________________________________________________________
# conv2d_189 (Conv2D)             (None, 8, 8, 422)    534252      activation_188[0][0]
# __________________________________________________________________________________________________
# conv2d_190 (Conv2D)             (None, 8, 8, 422)    534252      activation_188[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_18 (AveragePo (None, 8, 8, 2251)   0           mixed8-2[0][0]
# __________________________________________________________________________________________________
# conv2d_183 (Conv2D)             (None, 8, 8, 352)    792352      mixed8-2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_185 (BatchN (None, 8, 8, 422)    1266        conv2d_185[0][0]
# __________________________________________________________________________________________________
# batch_normalization_186 (BatchN (None, 8, 8, 422)    1266        conv2d_186[0][0]
# __________________________________________________________________________________________________
# batch_normalization_189 (BatchN (None, 8, 8, 422)    1266        conv2d_189[0][0]
# __________________________________________________________________________________________________
# batch_normalization_190 (BatchN (None, 8, 8, 422)    1266        conv2d_190[0][0]
# __________________________________________________________________________________________________
# conv2d_191 (Conv2D)             (None, 8, 8, 211)    474961      average_pooling2d_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_183 (BatchN (None, 8, 8, 352)    1056        conv2d_183[0][0]
# __________________________________________________________________________________________________
# activation_185 (Activation)     (None, 8, 8, 422)    0           batch_normalization_185[0][0]
# __________________________________________________________________________________________________
# activation_186 (Activation)     (None, 8, 8, 422)    0           batch_normalization_186[0][0]
# __________________________________________________________________________________________________
# activation_189 (Activation)     (None, 8, 8, 422)    0           batch_normalization_189[0][0]
# __________________________________________________________________________________________________
# activation_190 (Activation)     (None, 8, 8, 422)    0           batch_normalization_190[0][0]
# __________________________________________________________________________________________________
# batch_normalization_191 (BatchN (None, 8, 8, 211)    633         conv2d_191[0][0]
# __________________________________________________________________________________________________
# activation_183 (Activation)     (None, 8, 8, 352)    0           batch_normalization_183[0][0]
# __________________________________________________________________________________________________
# mixed8_3 (Concatenate)          (None, 8, 8, 844)    0           activation_185[0][0]
#                                                                  activation_186[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 8, 8, 844)    0           activation_189[0][0]
#                                                                  activation_190[0][0]
# __________________________________________________________________________________________________
# activation_191 (Activation)     (None, 8, 8, 211)    0           batch_normalization_191[0][0]
# __________________________________________________________________________________________________
# mixed8-3 (Concatenate)          (None, 8, 8, 2251)   0           activation_183[0][0]
#                                                                  mixed8_3[0][0]
#                                                                  concatenate_3[0][0]
#                                                                  activation_191[0][0]
# __________________________________________________________________________________________________
# conv2d_196 (Conv2D)             (None, 8, 8, 492)    1107492     mixed8-3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_196 (BatchN (None, 8, 8, 492)    1476        conv2d_196[0][0]
# __________________________________________________________________________________________________
# activation_196 (Activation)     (None, 8, 8, 492)    0           batch_normalization_196[0][0]
# __________________________________________________________________________________________________
# conv2d_193 (Conv2D)             (None, 8, 8, 422)    949922      mixed8-3[0][0]
# __________________________________________________________________________________________________
# conv2d_197 (Conv2D)             (None, 8, 8, 422)    1868616     activation_196[0][0]
# __________________________________________________________________________________________________
# batch_normalization_193 (BatchN (None, 8, 8, 422)    1266        conv2d_193[0][0]
# __________________________________________________________________________________________________
# batch_normalization_197 (BatchN (None, 8, 8, 422)    1266        conv2d_197[0][0]
# __________________________________________________________________________________________________
# activation_193 (Activation)     (None, 8, 8, 422)    0           batch_normalization_193[0][0]
# __________________________________________________________________________________________________
# activation_197 (Activation)     (None, 8, 8, 422)    0           batch_normalization_197[0][0]
# __________________________________________________________________________________________________
# conv2d_194 (Conv2D)             (None, 8, 8, 422)    534252      activation_193[0][0]
# __________________________________________________________________________________________________
# conv2d_195 (Conv2D)             (None, 8, 8, 422)    534252      activation_193[0][0]
# __________________________________________________________________________________________________
# conv2d_198 (Conv2D)             (None, 8, 8, 422)    534252      activation_197[0][0]
# __________________________________________________________________________________________________
# conv2d_199 (Conv2D)             (None, 8, 8, 422)    534252      activation_197[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_19 (AveragePo (None, 8, 8, 2251)   0           mixed8-3[0][0]
# __________________________________________________________________________________________________
# conv2d_192 (Conv2D)             (None, 8, 8, 352)    792352      mixed8-3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_194 (BatchN (None, 8, 8, 422)    1266        conv2d_194[0][0]
# __________________________________________________________________________________________________
# batch_normalization_195 (BatchN (None, 8, 8, 422)    1266        conv2d_195[0][0]
# __________________________________________________________________________________________________
# batch_normalization_198 (BatchN (None, 8, 8, 422)    1266        conv2d_198[0][0]
# __________________________________________________________________________________________________
# batch_normalization_199 (BatchN (None, 8, 8, 422)    1266        conv2d_199[0][0]
# __________________________________________________________________________________________________
# conv2d_200 (Conv2D)             (None, 8, 8, 211)    474961      average_pooling2d_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_192 (BatchN (None, 8, 8, 352)    1056        conv2d_192[0][0]
# __________________________________________________________________________________________________
# activation_194 (Activation)     (None, 8, 8, 422)    0           batch_normalization_194[0][0]
# __________________________________________________________________________________________________
# activation_195 (Activation)     (None, 8, 8, 422)    0           batch_normalization_195[0][0]
# __________________________________________________________________________________________________
# activation_198 (Activation)     (None, 8, 8, 422)    0           batch_normalization_198[0][0]
# __________________________________________________________________________________________________
# activation_199 (Activation)     (None, 8, 8, 422)    0           batch_normalization_199[0][0]
# __________________________________________________________________________________________________
# batch_normalization_200 (BatchN (None, 8, 8, 211)    633         conv2d_200[0][0]
# __________________________________________________________________________________________________
# activation_192 (Activation)     (None, 8, 8, 352)    0           batch_normalization_192[0][0]
# __________________________________________________________________________________________________
# mixed8_4 (Concatenate)          (None, 8, 8, 844)    0           activation_194[0][0]
#                                                                  activation_195[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 8, 8, 844)    0           activation_198[0][0]
#                                                                  activation_199[0][0]
# __________________________________________________________________________________________________
# activation_200 (Activation)     (None, 8, 8, 211)    0           batch_normalization_200[0][0]
# __________________________________________________________________________________________________
# mixed8-4 (Concatenate)          (None, 8, 8, 2251)   0           activation_192[0][0]
#                                                                  mixed8_4[0][0]
#                                                                  concatenate_4[0][0]
#                                                                  activation_200[0][0]
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, 1)]          0
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 2251)         0           mixed8-4[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 100)          200         input_2[0][0]
# __________________________________________________________________________________________________
# gender_and_feat._concat (Concat (None, 2351)         0           global_average_pooling2d[0][0]
#                                                                  dense[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 1)            2352        gender_and_feat._concat[0][0]
# ==================================================================================================
# Total params: 66,864,273
# Trainable params: 66,772,857
# Non-trainable params: 91,416
# __________________________________________________________________________________________________
# None
