# %%
import pandas as pd
import tensorflow as tf
import numpy as np
from tensorflow.python.keras.engine import data_adapter
from tensorflow.keras import backend as K
import os, sys
os.mkdir('/kaggle/working/ckpts/')
sys.path.append('../input/boneage-ckpts')
sys.path.append('../input/hdaproject2021-codes/')
sys.path.append('../input/temppp/')

# %%
train_csv_directory = '../input/hdadataset2021/Bone Age Datasets/Bone Age Training Set/'
train_directory = '../input/hdadataset2021/Bone Age Datasets/Bone Age Training Set/boneage-training-dataset/'
df_train = pd.read_csv(train_csv_directory + 'train.csv')

val_csv_directory = '../input/hdadataset2021/'
val_directory = '../input/hdadataset2021/boneage-validation-dataset/'
df_val = pd.read_csv(val_csv_directory + 'Validation Dataset.csv')

# %%
ids = df_train['id'].values.astype(str)
labels = df_train['male'].values.astype(float)
ages = df_train['boneage'].values.astype(float)
train_ds = tf.data.Dataset.from_tensor_slices((ids, labels, ages))


ids = df_val['Image ID'].values.astype(str)
labels = df_val['male'].values.astype(float)
ages = df_val['Bone Age (months)'].values.astype(float)
val_ds = tf.data.Dataset.from_tensor_slices((ids, labels, ages))

IMG_SIZE = (300, 300, 1)
BATCH_SIZE = 16

# %%
def read_train_image(image_file, label, age):
    image = tf.io.read_file(train_directory + image_file+ '.png')
    image = tf.io.decode_png(image, channels=1)
    return image, [label], [age] #lists are necessary for training the model (otherwise dims are unknown)

def read_val_image(image_file, label, age):
    image = tf.io.read_file(val_directory + image_file + '.png')
    image = tf.io.decode_png(image, channels=1)
    return image, [label], [age] #lists are necessary for training the model (otherwise dims are unknown)

resize_layer = tf.keras.layers.experimental.preprocessing.Resizing(height=IMG_SIZE[0], width=IMG_SIZE[1])
normalization_layer = tf.keras.layers.experimental.preprocessing.Rescaling(1/255.)
zoom_layer = tf.keras.layers.experimental.preprocessing.RandomZoom(height_factor=(0.2,-0.3),
                                                                   width_factor=(0.2,-0.3),
                                                                  fill_mode='constant')
flip_layer = tf.keras.layers.experimental.preprocessing.RandomFlip(mode='horizontal')
shift_layer = tf.keras.layers.experimental.preprocessing.RandomTranslation(height_factor=0.2, width_factor=0.2,
                                                                           fill_mode='constant')

def brightness_function(image):
    image = tf.image.random_brightness(image, max_delta=0.3)
    image = tf.math.maximum(image, 0.)
    image = tf.math.minimum(image, 1.)
    return image

def augment(image, label, age):
    # data augmentation here
    image = shift_layer(image)
    image = zoom_layer(image)
    image = flip_layer(image)
    #image = brightness_function(image)
    return image, label, age

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE #tf.data.AUTOTUNE
train_ds = train_ds.map(read_train_image).map(lambda image,label,age: (normalization_layer((resize_layer(image))), label, age)).cache('../input/hdaproject2021-codes/train_cache_300')
train_ds = train_ds.shuffle(buffer_size=1000).batch(BATCH_SIZE).map(augment,num_parallel_calls=AUTOTUNE)
train_ds = train_ds.prefetch(buffer_size=AUTOTUNE)

val_ds = val_ds.map(read_val_image).map(lambda image,label,age: (normalization_layer(resize_layer(image)), label, age)).cache('../input/hdaproject2021-codes/val_cache_300')
val_ds = val_ds.prefetch(buffer_size=AUTOTUNE).batch(BATCH_SIZE)

# %%
#image = list(val_ds.take(1).as_numpy_iterator())[0][0][1]

# %%
# %matplotlib inline
#import matplotlib.pyplot as plt
#_ = plt.imshow(image)

# %% [markdown]
# # Boneage Model

# %%
from InceptionV3_4 import InceptionV3
class BoneAgeInceptionNet(tf.keras.Model):  
    def __init__(self, gender=True, beta=1):
        super(BoneAgeInceptionNet, self).__init__()
        
        model = InceptionV3(
                                include_top=False,
                                weights=None,
                                input_shape=IMG_SIZE,
                                beta=beta)
                
        
        if gender:
            initializer = tf.keras.initializers.GlorotNormal()
            gender_input = tf.keras.Input(shape=(1))
            gender_output = tf.keras.layers.Dense(100, activation='relu', kernel_initializer=initializer)(gender_input)
            
            model_global_avg = tf.keras.layers.GlobalAveragePooling2D()(model.output)
            
            concat_output = tf.keras.layers.Concatenate(name='gender_and_feat._concat')([model_global_avg, gender_output])
            
            #dense_output = tf.keras.layers.Dense(2000,activation='relu', kernel_regularizer='l2', kernel_initializer=initializer)(concat_output)
            
            overall_output = tf.keras.layers.Dense(1,activation='relu', kernel_regularizer='l2', kernel_initializer=initializer)(concat_output)
            
            self.model = tf.keras.Model(inputs=[model.input, gender_input], outputs = overall_output)
        else:
            pass #COMPLETE!
                
        
        
    def call(self, x, training=False):
        imgs, labels = x
        
        y = self.model([imgs, labels],training)
       
        return y

    def train_step(self, data):
        
        data = data_adapter.expand_1d(data)
        imgs, labels, ages = data
        
        with tf.GradientTape() as tape:
            y_pred = self((imgs, labels), training=True)  # Forward pass

            loss = self.compiled_loss(ages, y_pred)

        trainable_vars = self.trainable_variables
        gradients = tape.gradient(loss, trainable_vars)
        
        # Update weights
        self.optimizer.apply_gradients(zip(gradients, trainable_vars))

        self.compiled_metrics.update_state(ages, y_pred)
        _dict = {m.name: m.result() for m in self.metrics}
        
        return _dict

    def test_step(self, data):
        
        data = data_adapter.expand_1d(data)
        imgs, labels, ages = data

        y_pred = self((imgs, labels), training=False)  # Forward pass

        loss = self.compiled_loss(ages, y_pred)

        self.compiled_metrics.update_state(ages, y_pred)
        _dict = {m.name: m.result() for m in self.metrics}
        
        return _dict
    
    def summary(self):
        print(self.model.summary())

# %%
boneageinception = BoneAgeInceptionNet(beta=1.2)
ckpt_callback = tf.keras.callbacks.ModelCheckpoint(
                filepath='./ckpts/best_val_inception_80ep.h5', monitor='val_mae', verbose=1, save_best_only=True,
                save_weights_only=True, mode='min')

def scheduler(epoch, lr):
    if epoch < 30:
        return lr
    elif epoch < 60:
        return 1e-3
    else:
        return 1e-4

lr_scheduler_callback = tf.keras.callbacks.LearningRateScheduler(scheduler, verbose=1)

optimizer = tf.keras.optimizers.Adam(learning_rate=1e-2)
metric = tf.keras.metrics.MeanAbsoluteError()
boneageinception.compile(optimizer=optimizer, loss='mse', metrics=['mae'])

boneageinception.fit(train_ds, validation_data=val_ds,callbacks = [ckpt_callback,lr_scheduler_callback],
                    epochs=80, verbose=2)
# Out:
# Epoch 1/80
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# 789/789 - 275s - loss: 1826.7522 - mae: 33.7530 - val_loss: 1724.2921 - val_mae: 34.2402
#
# Epoch 00001: val_mae improved from inf to 34.24017, saving model to ./ckpts/best_val_inception_80ep.h5
# Epoch 2/80
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# 789/789 - 252s - loss: 1647.8315 - mae: 32.5107 - val_loss: 4862.4932 - val_mae: 57.7169
#
# Epoch 00002: val_mae did not improve from 34.24017
# Epoch 3/80
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# 789/789 - 251s - loss: 1663.8029 - mae: 32.6267 - val_loss: 1718.6093 - val_mae: 33.3208
#
# Epoch 00003: val_mae improved from 34.24017 to 33.32082, saving model to ./ckpts/best_val_inception_80ep.h5
# Epoch 4/80
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# 789/789 - 251s - loss: 1627.3619 - mae: 32.1971 - val_loss: 2267.6943 - val_mae: 40.0260
#
# Epoch 00004: val_mae did not improve from 33.32082
# Epoch 5/80
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# 789/789 - 251s - loss: 1590.9309 - mae: 31.9131 - val_loss: 1690.4547 - val_mae: 32.0389
#
# Epoch 00005: val_mae improved from 33.32082 to 32.03891, saving model to ./ckpts/best_val_inception_80ep.h5
# Epoch 6/80
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# 789/789 - 251s - loss: 1577.1179 - mae: 31.7391 - val_loss: 1726.9827 - val_mae: 32.0265
#
# Epoch 00006: val_mae improved from 32.03891 to 32.02653, saving model to ./ckpts/best_val_inception_80ep.h5
# Epoch 7/80
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# 789/789 - 251s - loss: 1550.6458 - mae: 31.3898 - val_loss: 1707.7190 - val_mae: 31.8485
#
# Epoch 00007: val_mae improved from 32.02653 to 31.84849, saving model to ./ckpts/best_val_inception_80ep.h5
# Epoch 8/80
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# 789/789 - 251s - loss: 1469.7847 - mae: 30.4859 - val_loss: 1791.4172 - val_mae: 35.0756
#
# Epoch 00008: val_mae did not improve from 31.84849
# Epoch 9/80
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# 789/789 - 251s - loss: 1319.1841 - mae: 28.2362 - val_loss: 2715.2991 - val_mae: 43.0940
#
# Epoch 00009: val_mae did not improve from 31.84849
# Epoch 10/80
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# 789/789 - 251s - loss: 1580.0717 - mae: 31.7840 - val_loss: 1743.4347 - val_mae: 34.1806
#
# Epoch 00010: val_mae did not improve from 31.84849
# Epoch 11/80
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# 789/789 - 251s - loss: 1370.3711 - mae: 28.8500 - val_loss: 4028.6943 - val_mae: 56.0957
#
# Epoch 00011: val_mae did not improve from 31.84849
# Epoch 12/80
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# 789/789 - 252s - loss: 985.9247 - mae: 23.3790 - val_loss: 1117.6006 - val_mae: 24.5298
#
# Epoch 00012: val_mae improved from 31.84849 to 24.52982, saving model to ./ckpts/best_val_inception_80ep.h5
# Epoch 13/80
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# 789/789 - 251s - loss: 757.8652 - mae: 20.3566 - val_loss: 649.6547 - val_mae: 18.3793
#
# Epoch 00013: val_mae improved from 24.52982 to 18.37930, saving model to ./ckpts/best_val_inception_80ep.h5
# Epoch 14/80
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# 789/789 - 251s - loss: 641.7026 - mae: 18.8220 - val_loss: 754.8729 - val_mae: 20.9379
#
# Epoch 00014: val_mae did not improve from 18.37930
# Epoch 15/80
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# 789/789 - 251s - loss: 549.5760 - mae: 17.5614 - val_loss: 496.3249 - val_mae: 15.8228
#
# Epoch 00015: val_mae improved from 18.37930 to 15.82280, saving model to ./ckpts/best_val_inception_80ep.h5
# Epoch 16/80
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# 789/789 - 251s - loss: 451.8982 - mae: 16.1252 - val_loss: 435.7203 - val_mae: 16.1226
#
# Epoch 00016: val_mae did not improve from 15.82280
# Epoch 17/80
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# 789/789 - 251s - loss: 413.3692 - mae: 15.4514 - val_loss: 460.5123 - val_mae: 15.0175
#
# Epoch 00017: val_mae improved from 15.82280 to 15.01752, saving model to ./ckpts/best_val_inception_80ep.h5
# Epoch 18/80
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# 789/789 - 251s - loss: 410.4356 - mae: 15.2812 - val_loss: 324.1509 - val_mae: 13.1507
#
# Epoch 00018: val_mae improved from 15.01752 to 13.15065, saving model to ./ckpts/best_val_inception_80ep.h5
# Epoch 19/80
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# 789/789 - 251s - loss: 322.6759 - mae: 13.6721 - val_loss: 525.6081 - val_mae: 15.8442
#
# Epoch 00019: val_mae did not improve from 13.15065
# Epoch 20/80
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# 789/789 - 251s - loss: 308.3299 - mae: 13.3527 - val_loss: 247.6166 - val_mae: 11.5166
#
# Epoch 00020: val_mae improved from 13.15065 to 11.51663, saving model to ./ckpts/best_val_inception_80ep.h5
# Epoch 21/80
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# 789/789 - 251s - loss: 282.5912 - mae: 12.7799 - val_loss: 434.8504 - val_mae: 14.9074
#
# Epoch 00021: val_mae did not improve from 11.51663
# Epoch 22/80
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# 789/789 - 251s - loss: 258.6832 - mae: 12.1525 - val_loss: 282.0105 - val_mae: 13.2797
#
# Epoch 00022: val_mae did not improve from 11.51663
# Epoch 23/80
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# 789/789 - 251s - loss: 229.1282 - mae: 11.5098 - val_loss: 492.9444 - val_mae: 18.7183
#
# Epoch 00023: val_mae did not improve from 11.51663
# Epoch 24/80
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# 789/789 - 251s - loss: 222.2916 - mae: 11.3168 - val_loss: 230.1101 - val_mae: 11.1354
#
# Epoch 00024: val_mae improved from 11.51663 to 11.13541, saving model to ./ckpts/best_val_inception_80ep.h5
# Epoch 25/80
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# 789/789 - 251s - loss: 197.5561 - mae: 10.7814 - val_loss: 183.1671 - val_mae: 10.4161
#
# Epoch 00025: val_mae improved from 11.13541 to 10.41611, saving model to ./ckpts/best_val_inception_80ep.h5
# Epoch 26/80
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# 789/789 - 251s - loss: 199.8864 - mae: 10.8218 - val_loss: 390.2055 - val_mae: 15.2090
#
# Epoch 00026: val_mae did not improve from 10.41611
# Epoch 27/80
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# 789/789 - 251s - loss: 230.5531 - mae: 11.3362 - val_loss: 321.5363 - val_mae: 14.4531
#
# Epoch 00027: val_mae did not improve from 10.41611
# Epoch 28/80
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# 789/789 - 251s - loss: 199.3143 - mae: 10.5956 - val_loss: 305.1562 - val_mae: 14.2232
#
# Epoch 00028: val_mae did not improve from 10.41611
# Epoch 29/80
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# 789/789 - 251s - loss: 173.7368 - mae: 10.1172 - val_loss: 364.5359 - val_mae: 15.6003
#
# Epoch 00029: val_mae did not improve from 10.41611
# Epoch 30/80
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# 789/789 - 251s - loss: 181.6953 - mae: 10.2368 - val_loss: 157.0386 - val_mae: 9.4181
#
# Epoch 00030: val_mae improved from 10.41611 to 9.41810, saving model to ./ckpts/best_val_inception_80ep.h5
# Epoch 31/80
#
# Epoch 00031: LearningRateScheduler reducing learning rate to 0.001.
# 789/789 - 251s - loss: 138.8137 - mae: 9.0168 - val_loss: 135.8422 - val_mae: 8.8327
#
# Epoch 00031: val_mae improved from 9.41810 to 8.83275, saving model to ./ckpts/best_val_inception_80ep.h5
# Epoch 32/80
#
# Epoch 00032: LearningRateScheduler reducing learning rate to 0.001.
# 789/789 - 252s - loss: 133.7823 - mae: 8.8978 - val_loss: 138.8187 - val_mae: 8.9399
#
# Epoch 00032: val_mae did not improve from 8.83275
# Epoch 33/80
#
# Epoch 00033: LearningRateScheduler reducing learning rate to 0.001.
# 789/789 - 251s - loss: 132.9778 - mae: 8.8446 - val_loss: 147.4086 - val_mae: 9.3107
#
# Epoch 00033: val_mae did not improve from 8.83275
# Epoch 34/80
#
# Epoch 00034: LearningRateScheduler reducing learning rate to 0.001.
# 789/789 - 251s - loss: 130.6354 - mae: 8.7899 - val_loss: 135.8799 - val_mae: 8.8397
#
# Epoch 00034: val_mae did not improve from 8.83275
# Epoch 35/80
#
# Epoch 00035: LearningRateScheduler reducing learning rate to 0.001.
# 789/789 - 252s - loss: 129.7652 - mae: 8.7263 - val_loss: 132.4102 - val_mae: 8.6811
#
# Epoch 00035: val_mae improved from 8.83275 to 8.68106, saving model to ./ckpts/best_val_inception_80ep.h5
# Epoch 36/80
#
# Epoch 00036: LearningRateScheduler reducing learning rate to 0.001.
# 789/789 - 252s - loss: 126.4632 - mae: 8.6258 - val_loss: 132.5018 - val_mae: 8.7147
#
# Epoch 00036: val_mae did not improve from 8.68106
# Epoch 37/80
#
# Epoch 00037: LearningRateScheduler reducing learning rate to 0.001.
# 789/789 - 251s - loss: 124.8871 - mae: 8.5913 - val_loss: 128.6039 - val_mae: 8.6126
#
# Epoch 00037: val_mae improved from 8.68106 to 8.61261, saving model to ./ckpts/best_val_inception_80ep.h5
# Epoch 38/80
#
# Epoch 00038: LearningRateScheduler reducing learning rate to 0.001.
# 789/789 - 251s - loss: 125.3209 - mae: 8.6212 - val_loss: 133.6134 - val_mae: 8.8075
#
# Epoch 00038: val_mae did not improve from 8.61261
# Epoch 39/80
#
# Epoch 00039: LearningRateScheduler reducing learning rate to 0.001.
# 789/789 - 251s - loss: 123.8392 - mae: 8.5747 - val_loss: 132.1432 - val_mae: 8.7452
#
# Epoch 00039: val_mae did not improve from 8.61261
# Epoch 40/80
#
# Epoch 00040: LearningRateScheduler reducing learning rate to 0.001.
# 789/789 - 252s - loss: 123.1283 - mae: 8.5362 - val_loss: 131.3075 - val_mae: 8.6675
#
# Epoch 00040: val_mae did not improve from 8.61261
# Epoch 41/80
#
# Epoch 00041: LearningRateScheduler reducing learning rate to 0.001.
# 789/789 - 251s - loss: 122.0489 - mae: 8.5199 - val_loss: 143.1401 - val_mae: 9.1310
#
# Epoch 00041: val_mae did not improve from 8.61261
# Epoch 42/80
#
# Epoch 00042: LearningRateScheduler reducing learning rate to 0.001.
# 789/789 - 252s - loss: 120.3887 - mae: 8.4376 - val_loss: 127.4326 - val_mae: 8.4802
#
# Epoch 00042: val_mae improved from 8.61261 to 8.48016, saving model to ./ckpts/best_val_inception_80ep.h5
# Epoch 43/80
#
# Epoch 00043: LearningRateScheduler reducing learning rate to 0.001.
# 789/789 - 251s - loss: 121.3990 - mae: 8.4725 - val_loss: 128.4274 - val_mae: 8.5422
#
# Epoch 00043: val_mae did not improve from 8.48016
# Epoch 44/80
#
# Epoch 00044: LearningRateScheduler reducing learning rate to 0.001.
# 789/789 - 251s - loss: 121.1676 - mae: 8.4301 - val_loss: 123.6066 - val_mae: 8.4687
#
# Epoch 00044: val_mae improved from 8.48016 to 8.46865, saving model to ./ckpts/best_val_inception_80ep.h5
# Epoch 45/80
#
# Epoch 00045: LearningRateScheduler reducing learning rate to 0.001.
# 789/789 - 251s - loss: 121.1229 - mae: 8.4315 - val_loss: 127.4846 - val_mae: 8.4790
#
# Epoch 00045: val_mae did not improve from 8.46865
# Epoch 46/80
#
# Epoch 00046: LearningRateScheduler reducing learning rate to 0.001.
# 789/789 - 251s - loss: 119.5026 - mae: 8.4159 - val_loss: 132.8378 - val_mae: 8.8049
#
# Epoch 00046: val_mae did not improve from 8.46865
# Epoch 47/80
#
# Epoch 00047: LearningRateScheduler reducing learning rate to 0.001.
# 789/789 - 252s - loss: 117.7429 - mae: 8.3324 - val_loss: 137.8643 - val_mae: 8.9848
#
# Epoch 00047: val_mae did not improve from 8.46865
# Epoch 48/80
#
# Epoch 00048: LearningRateScheduler reducing learning rate to 0.001.
# 789/789 - 251s - loss: 116.2601 - mae: 8.3030 - val_loss: 130.8683 - val_mae: 8.7105
#
# Epoch 00048: val_mae did not improve from 8.46865
# Epoch 49/80
#
# Epoch 00049: LearningRateScheduler reducing learning rate to 0.001.
# 789/789 - 252s - loss: 116.8437 - mae: 8.3148 - val_loss: 122.0075 - val_mae: 8.3489
#
# Epoch 00049: val_mae improved from 8.46865 to 8.34889, saving model to ./ckpts/best_val_inception_80ep.h5
# Epoch 50/80
#
# Epoch 00050: LearningRateScheduler reducing learning rate to 0.001.
# 789/789 - 251s - loss: 117.0613 - mae: 8.3070 - val_loss: 126.1314 - val_mae: 8.5848
#
# Epoch 00050: val_mae did not improve from 8.34889
# Epoch 51/80
#
# Epoch 00051: LearningRateScheduler reducing learning rate to 0.001.
# 789/789 - 251s - loss: 114.6953 - mae: 8.2609 - val_loss: 126.4341 - val_mae: 8.5769
#
# Epoch 00051: val_mae did not improve from 8.34889
# Epoch 52/80
#
# Epoch 00052: LearningRateScheduler reducing learning rate to 0.001.
# 789/789 - 251s - loss: 115.1772 - mae: 8.2698 - val_loss: 135.1747 - val_mae: 8.9768
#
# Epoch 00052: val_mae did not improve from 8.34889
# Epoch 53/80
#
# Epoch 00053: LearningRateScheduler reducing learning rate to 0.001.
# 789/789 - 251s - loss: 115.3971 - mae: 8.2424 - val_loss: 119.0451 - val_mae: 8.2809
#
# Epoch 00053: val_mae improved from 8.34889 to 8.28090, saving model to ./ckpts/best_val_inception_80ep.h5
# Epoch 54/80
#
# Epoch 00054: LearningRateScheduler reducing learning rate to 0.001.
# 789/789 - 251s - loss: 113.9149 - mae: 8.2278 - val_loss: 126.3429 - val_mae: 8.5103
#
# Epoch 00054: val_mae did not improve from 8.28090
# Epoch 55/80
#
# Epoch 00055: LearningRateScheduler reducing learning rate to 0.001.
# 789/789 - 251s - loss: 112.2559 - mae: 8.1754 - val_loss: 125.4003 - val_mae: 8.4554
#
# Epoch 00055: val_mae did not improve from 8.28090
# Epoch 56/80
#
# Epoch 00056: LearningRateScheduler reducing learning rate to 0.001.
# 789/789 - 251s - loss: 113.3172 - mae: 8.1773 - val_loss: 126.5302 - val_mae: 8.5355
#
# Epoch 00056: val_mae did not improve from 8.28090
# Epoch 57/80
#
# Epoch 00057: LearningRateScheduler reducing learning rate to 0.001.
# 789/789 - 251s - loss: 113.2274 - mae: 8.1960 - val_loss: 122.9109 - val_mae: 8.3673
#
# Epoch 00057: val_mae did not improve from 8.28090
# Epoch 58/80
#
# Epoch 00058: LearningRateScheduler reducing learning rate to 0.001.
# 789/789 - 251s - loss: 110.3391 - mae: 8.1273 - val_loss: 124.9673 - val_mae: 8.4893
#
# Epoch 00058: val_mae did not improve from 8.28090
# Epoch 59/80
#
# Epoch 00059: LearningRateScheduler reducing learning rate to 0.001.
# 789/789 - 251s - loss: 111.3623 - mae: 8.1412 - val_loss: 130.0451 - val_mae: 8.6546
#
# Epoch 00059: val_mae did not improve from 8.28090
# Epoch 60/80
#
# Epoch 00060: LearningRateScheduler reducing learning rate to 0.001.
# 789/789 - 252s - loss: 111.0427 - mae: 8.1484 - val_loss: 127.6770 - val_mae: 8.5758
#
# Epoch 00060: val_mae did not improve from 8.28090
# Epoch 61/80
#
# Epoch 00061: LearningRateScheduler reducing learning rate to 0.0001.
# 789/789 - 251s - loss: 107.9403 - mae: 7.9825 - val_loss: 123.7126 - val_mae: 8.4464
#
# Epoch 00061: val_mae did not improve from 8.28090
# Epoch 62/80
#
# Epoch 00062: LearningRateScheduler reducing learning rate to 0.0001.
# 789/789 - 251s - loss: 107.7181 - mae: 8.0072 - val_loss: 122.9293 - val_mae: 8.4140
#
# Epoch 00062: val_mae did not improve from 8.28090
# Epoch 63/80
#
# Epoch 00063: LearningRateScheduler reducing learning rate to 0.0001.
# 789/789 - 251s - loss: 106.3578 - mae: 7.9586 - val_loss: 121.6602 - val_mae: 8.3781
#
# Epoch 00063: val_mae did not improve from 8.28090
# Epoch 64/80
#
# Epoch 00064: LearningRateScheduler reducing learning rate to 0.0001.
# 789/789 - 251s - loss: 106.3679 - mae: 7.9860 - val_loss: 121.2640 - val_mae: 8.3518
#
# Epoch 00064: val_mae did not improve from 8.28090
# Epoch 65/80
#
# Epoch 00065: LearningRateScheduler reducing learning rate to 0.0001.
# 789/789 - 251s - loss: 106.4697 - mae: 7.9675 - val_loss: 122.4983 - val_mae: 8.4172
#
# Epoch 00065: val_mae did not improve from 8.28090
# Epoch 66/80
#
# Epoch 00066: LearningRateScheduler reducing learning rate to 0.0001.
# 789/789 - 251s - loss: 108.3264 - mae: 8.0051 - val_loss: 122.8386 - val_mae: 8.4150
#
# Epoch 00066: val_mae did not improve from 8.28090
# Epoch 67/80
#
# Epoch 00067: LearningRateScheduler reducing learning rate to 0.0001.
# 789/789 - 251s - loss: 107.2515 - mae: 7.9505 - val_loss: 120.6874 - val_mae: 8.3230
#
# Epoch 00067: val_mae did not improve from 8.28090
# Epoch 68/80
#
# Epoch 00068: LearningRateScheduler reducing learning rate to 0.0001.
# 789/789 - 251s - loss: 106.6728 - mae: 7.9507 - val_loss: 121.3321 - val_mae: 8.3449
#
# Epoch 00068: val_mae did not improve from 8.28090
# Epoch 69/80
#
# Epoch 00069: LearningRateScheduler reducing learning rate to 0.0001.
# 789/789 - 251s - loss: 106.6341 - mae: 7.9891 - val_loss: 121.6108 - val_mae: 8.3537
#
# Epoch 00069: val_mae did not improve from 8.28090
# Epoch 70/80
#
# Epoch 00070: LearningRateScheduler reducing learning rate to 0.0001.
# 789/789 - 252s - loss: 106.2515 - mae: 7.9549 - val_loss: 119.8348 - val_mae: 8.2862
#
# Epoch 00070: val_mae did not improve from 8.28090
# Epoch 71/80
#
# Epoch 00071: LearningRateScheduler reducing learning rate to 0.0001.
# 789/789 - 251s - loss: 106.6362 - mae: 7.9566 - val_loss: 121.0857 - val_mae: 8.3330
#
# Epoch 00071: val_mae did not improve from 8.28090
# Epoch 72/80
#
# Epoch 00072: LearningRateScheduler reducing learning rate to 0.0001.
# 789/789 - 252s - loss: 106.2516 - mae: 7.9184 - val_loss: 123.0648 - val_mae: 8.4237
#
# Epoch 00072: val_mae did not improve from 8.28090
# Epoch 73/80
#
# Epoch 00073: LearningRateScheduler reducing learning rate to 0.0001.
# 789/789 - 251s - loss: 107.1325 - mae: 7.9665 - val_loss: 121.1581 - val_mae: 8.3403
#
# Epoch 00073: val_mae did not improve from 8.28090
# Epoch 74/80
#
# Epoch 00074: LearningRateScheduler reducing learning rate to 0.0001.
# 789/789 - 251s - loss: 106.0104 - mae: 7.9262 - val_loss: 120.7591 - val_mae: 8.3264
#
# Epoch 00074: val_mae did not improve from 8.28090
# Epoch 75/80
#
# Epoch 00075: LearningRateScheduler reducing learning rate to 0.0001.
# 789/789 - 251s - loss: 105.1253 - mae: 7.9186 - val_loss: 122.8926 - val_mae: 8.4127
#
# Epoch 00075: val_mae did not improve from 8.28090
# Epoch 76/80
#
# Epoch 00076: LearningRateScheduler reducing learning rate to 0.0001.
# 789/789 - 251s - loss: 105.0140 - mae: 7.9030 - val_loss: 121.6092 - val_mae: 8.3603
#
# Epoch 00076: val_mae did not improve from 8.28090
# Epoch 77/80
#
# Epoch 00077: LearningRateScheduler reducing learning rate to 0.0001.
# 789/789 - 251s - loss: 103.6308 - mae: 7.8618 - val_loss: 124.1604 - val_mae: 8.4734
#
# Epoch 00077: val_mae did not improve from 8.28090
# Epoch 78/80
#
# Epoch 00078: LearningRateScheduler reducing learning rate to 0.0001.
# 789/789 - 251s - loss: 105.2529 - mae: 7.9220 - val_loss: 120.1950 - val_mae: 8.3091
#
# Epoch 00078: val_mae did not improve from 8.28090
# Epoch 79/80
#
# Epoch 00079: LearningRateScheduler reducing learning rate to 0.0001.
# 789/789 - 251s - loss: 106.0908 - mae: 7.9374 - val_loss: 121.6984 - val_mae: 8.3603
#
# Epoch 00079: val_mae did not improve from 8.28090
# Epoch 80/80
#
# Epoch 00080: LearningRateScheduler reducing learning rate to 0.0001.
# 789/789 - 251s - loss: 107.3302 - mae: 7.9463 - val_loss: 121.9301 - val_mae: 8.3623
#
# Epoch 00080: val_mae did not improve from 8.28090

# %% [markdown]
# ### test

# %%
test_directory = '../input/hdadataset2021/Bone Age Datasets/Bone Age Test Set/Test Set Images/'

df_test = pd.read_csv('../input/hdaproject2021-codes/test.csv')

ids = df_test['id'].values.astype(str)
labels = (df_test['Sex'].values == 'M').astype(float)

# replace ',' with '.' and convert to float
ages_str = df_test['boneage'].values
ages = np.empty_like(ages_str)
for i, item in enumerate(ages_str):
    replaced = item.replace(',','.')
    replaced_float = float(replaced)
    ages[i] = replaced_float
ages = ages.astype(float)

test_ds = tf.data.Dataset.from_tensor_slices((ids, labels, ages))

def read_test_image(image_file, label, age):
    image = tf.io.read_file(test_directory + image_file + '.png')
    image = tf.io.decode_png(image, channels=1)
    return image, [label], [age] #lists are necessary for training the model (otherwise dims are unknown)

test_ds = test_ds.map(read_test_image).map(lambda image,label,age: (normalization_layer(resize_layer(image)), label, age)).cache()
test_ds = test_ds.prefetch(buffer_size=AUTOTUNE)

test_iterator = test_ds.as_numpy_iterator()
N = 200 #number of samples
test_images = np.empty(shape=(N, IMG_SIZE[0], IMG_SIZE[1], 1), dtype=np.float32)
test_labels = np.empty(shape=(N,), dtype=np.float32)
test_ages = np.empty(shape=(N,), dtype=np.float32)
for i, item in enumerate(test_iterator):
    test_images[i] = item[0]
    test_labels[i] = item[1]
    test_ages[i] = item[2]
    
print(test_images.shape)
print(test_labels.shape)
print(test_ages.shape)
# Out:
# (200, 300, 300, 1)
# (200,)
# (200,)

# %%
boneageinception.load_weights('./ckpts/best_val_inception_80ep.h5')

# %%
boneageinception_pred = boneageinception.predict((test_images, test_labels))

# %%
np.mean(np.abs(boneageinception_pred.squeeze() - test_ages.squeeze()))
# Out:
# 7.276188

# %%
boneageinception.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 300, 300, 1) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 149, 149, 38) 342         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 149, 149, 38) 114         conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 149, 149, 38) 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 147, 147, 38) 12996       activation[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 147, 147, 38) 114         conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 147, 147, 38) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 147, 147, 76) 25992       activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 147, 147, 76) 228         conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 147, 147, 76) 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 73, 73, 76)   0           activation_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 73, 73, 96)   7296        max_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 73, 73, 96)   288         conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 73, 73, 96)   0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 71, 71, 230)  198720      activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 71, 71, 230)  690         conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 71, 71, 230)  0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 35, 35, 230)  0           activation_4[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 35, 35, 76)   17480       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 35, 35, 76)   228         conv2d_8[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 35, 35, 76)   0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 35, 35, 57)   13110       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 35, 35, 115)  78660       activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 35, 35, 57)   171         conv2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 35, 35, 115)  345         conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 35, 35, 57)   0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 35, 35, 115)  0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# average_pooling2d (AveragePooli (None, 35, 35, 230)  0           max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 35, 35, 76)   17480       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 35, 35, 76)   108300      activation_6[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 35, 35, 115)  119025      activation_9[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 35, 35, 38)   8740        average_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 35, 35, 76)   228         conv2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 35, 35, 76)   228         conv2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 35, 35, 115)  345         conv2d_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 35, 35, 38)   114         conv2d_11[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 35, 35, 76)   0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 35, 35, 76)   0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 35, 35, 115)  0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 35, 35, 38)   0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# mixed0-0 (Concatenate)          (None, 35, 35, 305)  0           activation_5[0][0]
#                                                                  activation_7[0][0]
#                                                                  activation_10[0][0]
#                                                                  activation_11[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 35, 35, 76)   23180       mixed0-0[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 35, 35, 76)   228         conv2d_15[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 35, 35, 76)   0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 35, 35, 57)   17385       mixed0-0[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 35, 35, 115)  78660       activation_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 35, 35, 57)   171         conv2d_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 35, 35, 115)  345         conv2d_16[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 35, 35, 57)   0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 35, 35, 115)  0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_1 (AveragePoo (None, 35, 35, 305)  0           mixed0-0[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 35, 35, 76)   23180       mixed0-0[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 35, 35, 76)   108300      activation_13[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 35, 35, 115)  119025      activation_16[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 35, 35, 76)   23180       average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 35, 35, 76)   228         conv2d_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 35, 35, 76)   228         conv2d_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 35, 35, 115)  345         conv2d_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 35, 35, 76)   228         conv2d_18[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 35, 35, 76)   0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 35, 35, 76)   0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 35, 35, 115)  0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 35, 35, 76)   0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# mixed1 (Concatenate)            (None, 35, 35, 343)  0           activation_12[0][0]
#                                                                  activation_14[0][0]
#                                                                  activation_17[0][0]
#                                                                  activation_18[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 35, 35, 76)   26068       mixed1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 35, 35, 76)   228         conv2d_22[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 35, 35, 76)   0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 35, 35, 57)   19551       mixed1[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 35, 35, 115)  78660       activation_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 35, 35, 57)   171         conv2d_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 35, 35, 115)  345         conv2d_23[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 35, 35, 57)   0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 35, 35, 115)  0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_2 (AveragePoo (None, 35, 35, 343)  0           mixed1[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 35, 35, 76)   26068       mixed1[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 35, 35, 76)   108300      activation_20[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 35, 35, 115)  119025      activation_23[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 35, 35, 76)   26068       average_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 35, 35, 76)   228         conv2d_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 35, 35, 76)   228         conv2d_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 35, 35, 115)  345         conv2d_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 35, 35, 76)   228         conv2d_25[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 35, 35, 76)   0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 35, 35, 76)   0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 35, 35, 115)  0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 35, 35, 76)   0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# mixed2 (Concatenate)            (None, 35, 35, 343)  0           activation_19[0][0]
#                                                                  activation_21[0][0]
#                                                                  activation_24[0][0]
#                                                                  activation_25[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 35, 35, 76)   26068       mixed2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 35, 35, 76)   228         conv2d_27[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 35, 35, 76)   0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 35, 35, 115)  78660       activation_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 35, 35, 115)  345         conv2d_28[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 35, 35, 115)  0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 17, 17, 460)  1420020     mixed2[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 17, 17, 115)  119025      activation_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 17, 17, 460)  1380        conv2d_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 17, 17, 115)  345         conv2d_29[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 17, 17, 460)  0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 17, 17, 115)  0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 17, 17, 343)  0           mixed2[0][0]
# __________________________________________________________________________________________________
# mixed3 (Concatenate)            (None, 17, 17, 918)  0           activation_26[0][0]
#                                                                  activation_29[0][0]
#                                                                  max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 17, 17, 153)  140454      mixed3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 17, 17, 153)  459         conv2d_34[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 17, 17, 153)  0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 17, 17, 153)  163863      activation_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 17, 17, 153)  459         conv2d_35[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 17, 17, 153)  0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 17, 17, 153)  140454      mixed3[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 17, 17, 153)  163863      activation_35[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 17, 17, 153)  459         conv2d_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 17, 17, 153)  459         conv2d_36[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 17, 17, 153)  0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 17, 17, 153)  0           batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 17, 17, 153)  163863      activation_31[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 17, 17, 153)  163863      activation_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 17, 17, 153)  459         conv2d_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 17, 17, 153)  459         conv2d_37[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 17, 17, 153)  0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 17, 17, 153)  0           batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_3 (AveragePoo (None, 17, 17, 918)  0           mixed3[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 17, 17, 230)  211140      mixed3[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 17, 17, 230)  246330      activation_32[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 17, 17, 230)  246330      activation_37[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 17, 17, 230)  211140      average_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 17, 17, 230)  690         conv2d_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 17, 17, 230)  690         conv2d_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 17, 17, 230)  690         conv2d_38[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 17, 17, 230)  690         conv2d_39[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 17, 17, 230)  0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 17, 17, 230)  0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 17, 17, 230)  0           batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 17, 17, 230)  0           batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# mixed4-0 (Concatenate)          (None, 17, 17, 920)  0           activation_30[0][0]
#                                                                  activation_33[0][0]
#                                                                  activation_38[0][0]
#                                                                  activation_39[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 17, 17, 192)  176640      mixed4-0[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 17, 17, 192)  576         conv2d_44[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 17, 17, 192)  0           batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 17, 17, 192)  258048      activation_44[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 17, 17, 192)  576         conv2d_45[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 17, 17, 192)  0           batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 17, 17, 192)  176640      mixed4-0[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 17, 17, 192)  258048      activation_45[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 17, 17, 192)  576         conv2d_41[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 17, 17, 192)  576         conv2d_46[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 17, 17, 192)  0           batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 17, 17, 192)  0           batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 17, 17, 192)  258048      activation_41[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 17, 17, 192)  258048      activation_46[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 17, 17, 192)  576         conv2d_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, 17, 17, 192)  576         conv2d_47[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 17, 17, 192)  0           batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 17, 17, 192)  0           batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_4 (AveragePoo (None, 17, 17, 920)  0           mixed4-0[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 17, 17, 230)  211600      mixed4-0[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 17, 17, 230)  309120      activation_42[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 17, 17, 230)  309120      activation_47[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 17, 17, 230)  211600      average_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 17, 17, 230)  690         conv2d_40[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 17, 17, 230)  690         conv2d_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 17, 17, 230)  690         conv2d_48[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, 17, 17, 230)  690         conv2d_49[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 17, 17, 230)  0           batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 17, 17, 230)  0           batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 17, 17, 230)  0           batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, 17, 17, 230)  0           batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# mixed5-0 (Concatenate)          (None, 17, 17, 920)  0           activation_40[0][0]
#                                                                  activation_43[0][0]
#                                                                  activation_48[0][0]
#                                                                  activation_49[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 17, 17, 192)  176640      mixed5-0[0][0]
# __________________________________________________________________________________________________
# batch_normalization_54 (BatchNo (None, 17, 17, 192)  576         conv2d_54[0][0]
# __________________________________________________________________________________________________
# activation_54 (Activation)      (None, 17, 17, 192)  0           batch_normalization_54[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 17, 17, 192)  258048      activation_54[0][0]
# __________________________________________________________________________________________________
# batch_normalization_55 (BatchNo (None, 17, 17, 192)  576         conv2d_55[0][0]
# __________________________________________________________________________________________________
# activation_55 (Activation)      (None, 17, 17, 192)  0           batch_normalization_55[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 17, 17, 192)  176640      mixed5-0[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 17, 17, 192)  258048      activation_55[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 17, 17, 192)  576         conv2d_51[0][0]
# __________________________________________________________________________________________________
# batch_normalization_56 (BatchNo (None, 17, 17, 192)  576         conv2d_56[0][0]
# __________________________________________________________________________________________________
# activation_51 (Activation)      (None, 17, 17, 192)  0           batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# activation_56 (Activation)      (None, 17, 17, 192)  0           batch_normalization_56[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 17, 17, 192)  258048      activation_51[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, 17, 17, 192)  258048      activation_56[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, 17, 17, 192)  576         conv2d_52[0][0]
# __________________________________________________________________________________________________
# batch_normalization_57 (BatchNo (None, 17, 17, 192)  576         conv2d_57[0][0]
# __________________________________________________________________________________________________
# activation_52 (Activation)      (None, 17, 17, 192)  0           batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# activation_57 (Activation)      (None, 17, 17, 192)  0           batch_normalization_57[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_5 (AveragePoo (None, 17, 17, 920)  0           mixed5-0[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 17, 17, 230)  211600      mixed5-0[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 17, 17, 230)  309120      activation_52[0][0]
# __________________________________________________________________________________________________
# conv2d_58 (Conv2D)              (None, 17, 17, 230)  309120      activation_57[0][0]
# __________________________________________________________________________________________________
# conv2d_59 (Conv2D)              (None, 17, 17, 230)  211600      average_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, 17, 17, 230)  690         conv2d_50[0][0]
# __________________________________________________________________________________________________
# batch_normalization_53 (BatchNo (None, 17, 17, 230)  690         conv2d_53[0][0]
# __________________________________________________________________________________________________
# batch_normalization_58 (BatchNo (None, 17, 17, 230)  690         conv2d_58[0][0]
# __________________________________________________________________________________________________
# batch_normalization_59 (BatchNo (None, 17, 17, 230)  690         conv2d_59[0][0]
# __________________________________________________________________________________________________
# activation_50 (Activation)      (None, 17, 17, 230)  0           batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# activation_53 (Activation)      (None, 17, 17, 230)  0           batch_normalization_53[0][0]
# __________________________________________________________________________________________________
# activation_58 (Activation)      (None, 17, 17, 230)  0           batch_normalization_58[0][0]
# __________________________________________________________________________________________________
# activation_59 (Activation)      (None, 17, 17, 230)  0           batch_normalization_59[0][0]
# __________________________________________________________________________________________________
# mixed5-1 (Concatenate)          (None, 17, 17, 920)  0           activation_50[0][0]
#                                                                  activation_53[0][0]
#                                                                  activation_58[0][0]
#                                                                  activation_59[0][0]
# __________________________________________________________________________________________________
# conv2d_64 (Conv2D)              (None, 17, 17, 192)  176640      mixed5-1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_64 (BatchNo (None, 17, 17, 192)  576         conv2d_64[0][0]
# __________________________________________________________________________________________________
# activation_64 (Activation)      (None, 17, 17, 192)  0           batch_normalization_64[0][0]
# __________________________________________________________________________________________________
# conv2d_65 (Conv2D)              (None, 17, 17, 192)  258048      activation_64[0][0]
# __________________________________________________________________________________________________
# batch_normalization_65 (BatchNo (None, 17, 17, 192)  576         conv2d_65[0][0]
# __________________________________________________________________________________________________
# activation_65 (Activation)      (None, 17, 17, 192)  0           batch_normalization_65[0][0]
# __________________________________________________________________________________________________
# conv2d_61 (Conv2D)              (None, 17, 17, 192)  176640      mixed5-1[0][0]
# __________________________________________________________________________________________________
# conv2d_66 (Conv2D)              (None, 17, 17, 192)  258048      activation_65[0][0]
# __________________________________________________________________________________________________
# batch_normalization_61 (BatchNo (None, 17, 17, 192)  576         conv2d_61[0][0]
# __________________________________________________________________________________________________
# batch_normalization_66 (BatchNo (None, 17, 17, 192)  576         conv2d_66[0][0]
# __________________________________________________________________________________________________
# activation_61 (Activation)      (None, 17, 17, 192)  0           batch_normalization_61[0][0]
# __________________________________________________________________________________________________
# activation_66 (Activation)      (None, 17, 17, 192)  0           batch_normalization_66[0][0]
# __________________________________________________________________________________________________
# conv2d_62 (Conv2D)              (None, 17, 17, 192)  258048      activation_61[0][0]
# __________________________________________________________________________________________________
# conv2d_67 (Conv2D)              (None, 17, 17, 192)  258048      activation_66[0][0]
# __________________________________________________________________________________________________
# batch_normalization_62 (BatchNo (None, 17, 17, 192)  576         conv2d_62[0][0]
# __________________________________________________________________________________________________
# batch_normalization_67 (BatchNo (None, 17, 17, 192)  576         conv2d_67[0][0]
# __________________________________________________________________________________________________
# activation_62 (Activation)      (None, 17, 17, 192)  0           batch_normalization_62[0][0]
# __________________________________________________________________________________________________
# activation_67 (Activation)      (None, 17, 17, 192)  0           batch_normalization_67[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_6 (AveragePoo (None, 17, 17, 920)  0           mixed5-1[0][0]
# __________________________________________________________________________________________________
# conv2d_60 (Conv2D)              (None, 17, 17, 230)  211600      mixed5-1[0][0]
# __________________________________________________________________________________________________
# conv2d_63 (Conv2D)              (None, 17, 17, 230)  309120      activation_62[0][0]
# __________________________________________________________________________________________________
# conv2d_68 (Conv2D)              (None, 17, 17, 230)  309120      activation_67[0][0]
# __________________________________________________________________________________________________
# conv2d_69 (Conv2D)              (None, 17, 17, 230)  211600      average_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_60 (BatchNo (None, 17, 17, 230)  690         conv2d_60[0][0]
# __________________________________________________________________________________________________
# batch_normalization_63 (BatchNo (None, 17, 17, 230)  690         conv2d_63[0][0]
# __________________________________________________________________________________________________
# batch_normalization_68 (BatchNo (None, 17, 17, 230)  690         conv2d_68[0][0]
# __________________________________________________________________________________________________
# batch_normalization_69 (BatchNo (None, 17, 17, 230)  690         conv2d_69[0][0]
# __________________________________________________________________________________________________
# activation_60 (Activation)      (None, 17, 17, 230)  0           batch_normalization_60[0][0]
# __________________________________________________________________________________________________
# activation_63 (Activation)      (None, 17, 17, 230)  0           batch_normalization_63[0][0]
# __________________________________________________________________________________________________
# activation_68 (Activation)      (None, 17, 17, 230)  0           batch_normalization_68[0][0]
# __________________________________________________________________________________________________
# activation_69 (Activation)      (None, 17, 17, 230)  0           batch_normalization_69[0][0]
# __________________________________________________________________________________________________
# mixed5-2 (Concatenate)          (None, 17, 17, 920)  0           activation_60[0][0]
#                                                                  activation_63[0][0]
#                                                                  activation_68[0][0]
#                                                                  activation_69[0][0]
# __________________________________________________________________________________________________
# ...
# __________________________________________________________________________________________________
# mixed8_1 (Concatenate)          (None, 8, 8, 920)    0           activation_147[0][0]
#                                                                  activation_148[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 8, 8, 920)    0           activation_151[0][0]
#                                                                  activation_152[0][0]
# __________________________________________________________________________________________________
# activation_153 (Activation)     (None, 8, 8, 230)    0           batch_normalization_153[0][0]
# __________________________________________________________________________________________________
# mixed8-1 (Concatenate)          (None, 8, 8, 2454)   0           activation_145[0][0]
#                                                                  mixed8_1[0][0]
#                                                                  concatenate_1[0][0]
#                                                                  activation_153[0][0]
# __________________________________________________________________________________________________
# conv2d_158 (Conv2D)             (None, 8, 8, 537)    1317798     mixed8-1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_158 (BatchN (None, 8, 8, 537)    1611        conv2d_158[0][0]
# __________________________________________________________________________________________________
# activation_158 (Activation)     (None, 8, 8, 537)    0           batch_normalization_158[0][0]
# __________________________________________________________________________________________________
# conv2d_155 (Conv2D)             (None, 8, 8, 460)    1128840     mixed8-1[0][0]
# __________________________________________________________________________________________________
# conv2d_159 (Conv2D)             (None, 8, 8, 460)    2223180     activation_158[0][0]
# __________________________________________________________________________________________________
# batch_normalization_155 (BatchN (None, 8, 8, 460)    1380        conv2d_155[0][0]
# __________________________________________________________________________________________________
# batch_normalization_159 (BatchN (None, 8, 8, 460)    1380        conv2d_159[0][0]
# __________________________________________________________________________________________________
# activation_155 (Activation)     (None, 8, 8, 460)    0           batch_normalization_155[0][0]
# __________________________________________________________________________________________________
# activation_159 (Activation)     (None, 8, 8, 460)    0           batch_normalization_159[0][0]
# __________________________________________________________________________________________________
# conv2d_156 (Conv2D)             (None, 8, 8, 460)    634800      activation_155[0][0]
# __________________________________________________________________________________________________
# conv2d_157 (Conv2D)             (None, 8, 8, 460)    634800      activation_155[0][0]
# __________________________________________________________________________________________________
# conv2d_160 (Conv2D)             (None, 8, 8, 460)    634800      activation_159[0][0]
# __________________________________________________________________________________________________
# conv2d_161 (Conv2D)             (None, 8, 8, 460)    634800      activation_159[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_15 (AveragePo (None, 8, 8, 2454)   0           mixed8-1[0][0]
# __________________________________________________________________________________________________
# conv2d_154 (Conv2D)             (None, 8, 8, 384)    942336      mixed8-1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_156 (BatchN (None, 8, 8, 460)    1380        conv2d_156[0][0]
# __________________________________________________________________________________________________
# batch_normalization_157 (BatchN (None, 8, 8, 460)    1380        conv2d_157[0][0]
# __________________________________________________________________________________________________
# batch_normalization_160 (BatchN (None, 8, 8, 460)    1380        conv2d_160[0][0]
# __________________________________________________________________________________________________
# batch_normalization_161 (BatchN (None, 8, 8, 460)    1380        conv2d_161[0][0]
# __________________________________________________________________________________________________
# conv2d_162 (Conv2D)             (None, 8, 8, 230)    564420      average_pooling2d_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_154 (BatchN (None, 8, 8, 384)    1152        conv2d_154[0][0]
# __________________________________________________________________________________________________
# activation_156 (Activation)     (None, 8, 8, 460)    0           batch_normalization_156[0][0]
# __________________________________________________________________________________________________
# activation_157 (Activation)     (None, 8, 8, 460)    0           batch_normalization_157[0][0]
# __________________________________________________________________________________________________
# activation_160 (Activation)     (None, 8, 8, 460)    0           batch_normalization_160[0][0]
# __________________________________________________________________________________________________
# activation_161 (Activation)     (None, 8, 8, 460)    0           batch_normalization_161[0][0]
# __________________________________________________________________________________________________
# batch_normalization_162 (BatchN (None, 8, 8, 230)    690         conv2d_162[0][0]
# __________________________________________________________________________________________________
# activation_154 (Activation)     (None, 8, 8, 384)    0           batch_normalization_154[0][0]
# __________________________________________________________________________________________________
# mixed8_2 (Concatenate)          (None, 8, 8, 920)    0           activation_156[0][0]
#                                                                  activation_157[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 8, 8, 920)    0           activation_160[0][0]
#                                                                  activation_161[0][0]
# __________________________________________________________________________________________________
# activation_162 (Activation)     (None, 8, 8, 230)    0           batch_normalization_162[0][0]
# __________________________________________________________________________________________________
# mixed8-2 (Concatenate)          (None, 8, 8, 2454)   0           activation_154[0][0]
#                                                                  mixed8_2[0][0]
#                                                                  concatenate_2[0][0]
#                                                                  activation_162[0][0]
# __________________________________________________________________________________________________
# conv2d_167 (Conv2D)             (None, 8, 8, 537)    1317798     mixed8-2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_167 (BatchN (None, 8, 8, 537)    1611        conv2d_167[0][0]
# __________________________________________________________________________________________________
# activation_167 (Activation)     (None, 8, 8, 537)    0           batch_normalization_167[0][0]
# __________________________________________________________________________________________________
# conv2d_164 (Conv2D)             (None, 8, 8, 460)    1128840     mixed8-2[0][0]
# __________________________________________________________________________________________________
# conv2d_168 (Conv2D)             (None, 8, 8, 460)    2223180     activation_167[0][0]
# __________________________________________________________________________________________________
# batch_normalization_164 (BatchN (None, 8, 8, 460)    1380        conv2d_164[0][0]
# __________________________________________________________________________________________________
# batch_normalization_168 (BatchN (None, 8, 8, 460)    1380        conv2d_168[0][0]
# __________________________________________________________________________________________________
# activation_164 (Activation)     (None, 8, 8, 460)    0           batch_normalization_164[0][0]
# __________________________________________________________________________________________________
# activation_168 (Activation)     (None, 8, 8, 460)    0           batch_normalization_168[0][0]
# __________________________________________________________________________________________________
# conv2d_165 (Conv2D)             (None, 8, 8, 460)    634800      activation_164[0][0]
# __________________________________________________________________________________________________
# conv2d_166 (Conv2D)             (None, 8, 8, 460)    634800      activation_164[0][0]
# __________________________________________________________________________________________________
# conv2d_169 (Conv2D)             (None, 8, 8, 460)    634800      activation_168[0][0]
# __________________________________________________________________________________________________
# conv2d_170 (Conv2D)             (None, 8, 8, 460)    634800      activation_168[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_16 (AveragePo (None, 8, 8, 2454)   0           mixed8-2[0][0]
# __________________________________________________________________________________________________
# conv2d_163 (Conv2D)             (None, 8, 8, 384)    942336      mixed8-2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_165 (BatchN (None, 8, 8, 460)    1380        conv2d_165[0][0]
# __________________________________________________________________________________________________
# batch_normalization_166 (BatchN (None, 8, 8, 460)    1380        conv2d_166[0][0]
# __________________________________________________________________________________________________
# batch_normalization_169 (BatchN (None, 8, 8, 460)    1380        conv2d_169[0][0]
# __________________________________________________________________________________________________
# batch_normalization_170 (BatchN (None, 8, 8, 460)    1380        conv2d_170[0][0]
# __________________________________________________________________________________________________
# conv2d_171 (Conv2D)             (None, 8, 8, 230)    564420      average_pooling2d_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_163 (BatchN (None, 8, 8, 384)    1152        conv2d_163[0][0]
# __________________________________________________________________________________________________
# activation_165 (Activation)     (None, 8, 8, 460)    0           batch_normalization_165[0][0]
# __________________________________________________________________________________________________
# activation_166 (Activation)     (None, 8, 8, 460)    0           batch_normalization_166[0][0]
# __________________________________________________________________________________________________
# activation_169 (Activation)     (None, 8, 8, 460)    0           batch_normalization_169[0][0]
# __________________________________________________________________________________________________
# activation_170 (Activation)     (None, 8, 8, 460)    0           batch_normalization_170[0][0]
# __________________________________________________________________________________________________
# batch_normalization_171 (BatchN (None, 8, 8, 230)    690         conv2d_171[0][0]
# __________________________________________________________________________________________________
# activation_163 (Activation)     (None, 8, 8, 384)    0           batch_normalization_163[0][0]
# __________________________________________________________________________________________________
# mixed8_3 (Concatenate)          (None, 8, 8, 920)    0           activation_165[0][0]
#                                                                  activation_166[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 8, 8, 920)    0           activation_169[0][0]
#                                                                  activation_170[0][0]
# __________________________________________________________________________________________________
# activation_171 (Activation)     (None, 8, 8, 230)    0           batch_normalization_171[0][0]
# __________________________________________________________________________________________________
# mixed8-3 (Concatenate)          (None, 8, 8, 2454)   0           activation_163[0][0]
#                                                                  mixed8_3[0][0]
#                                                                  concatenate_3[0][0]
#                                                                  activation_171[0][0]
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, 1)]          0
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 2454)         0           mixed8-3[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 100)          200         input_2[0][0]
# __________________________________________________________________________________________________
# gender_and_feat._concat (Concat (None, 2554)         0           global_average_pooling2d[0][0]
#                                                                  dense[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 1)            2555        gender_and_feat._concat[0][0]
# ==================================================================================================
# Total params: 65,250,400
# Trainable params: 65,167,290
# Non-trainable params: 83,110
# __________________________________________________________________________________________________
# None
